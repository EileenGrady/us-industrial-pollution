# %% [markdown]
# # Visualize and explore TRI data

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
from shapely.geometry import Polygon
from shapely.geometry import mapping
import folium

# %%
tri = gpd.read_file('data/TRI-facilities.geojson')

# %%
tri.head()
# Out:
#              TRIFD  YEAR                                      FACILITY NAME  \
# 0  00608DCRBNRD3KM  2018                                     IDI CARIBE INC
# 1  0060WHPNTRCARR1  2018  HP INTERNATIONAL TRADING BV (PUERTO RICO BRANC...
# 2  00610BXTRHROAD4  2018               EDWARDS LIFESCIENCES TECHNOLOGY SARL
# 3  00610CRBGNCARR4  2018                         GE INTERNATIONAL OF PR LLC
# 4  00612PRPCMPR681  2018          PREPA-CAMBALACHE COMBUSTION TURBINE PLANT
#
#                                       STREET ADDRESS       CITY     COUNTY  \
# 0                               PR3 KM 151.8 AGUIRRE    SALINAS    SALINAS
# 1                                  CARR 110, KM. 5.1  AGUADILLA  AGUADILLA
# 2  STATE RD 402 KM 1.4 N LAS MARIAS IND US TRIAL ...     ANASCO     ANASCO
# 3                STATE RD 402 KM 1.5 INDUSTRIAL ZONE     ANASCO     ANASCO
# 4                                      PR-681 KM 0.5    ARECIBO    ARECIBO
#
#    ST  ZIP BIA TRIBE  ...  OFF_SITE_RELEASE_TOTAL_PBTs  TOTAL_RELEASES_PBTs  \
# 0  PR  751            ...                          NaN                  NaN
# 1  PR  603            ...                          NaN                  NaN
# 2  PR  610            ...                          NaN                  NaN
# 3  PR  610            ...                       1.0000               1.2000
# 4  PR  612            ...                       1.8612              44.0612
#
#   WATER_RELEASE_CARCINOGEN AIR_RELEASE_CARCINOGEN LAND_RELEASE_CARCINOGEN  \
# 0                      0.0                13143.0                     0.0
# 1                      NaN                    NaN                     NaN
# 2                      0.0                  580.0                     0.0
# 3                      0.0                    0.2                     0.0
# 4                      0.0                   42.2                     0.0
#
#    LAND_RELEASE_EXCLUDED_CARCINOGEN  ON_SITE_RELEASE_TOTAL_CARCINOGEN  \
# 0                               0.0                           13143.0
# 1                               NaN                               NaN
# 2                               0.0                             580.0
# 3                               0.0                               0.2
# 4                               0.0                              42.2
#
#    OFF_SITE_RELEASE_TOTAL_CARCINOGEN  TOTAL_RELEASES_CARCINOGEN  \
# 0                             0.0000                 13143.0000
# 1                                NaN                        NaN
# 2                             0.0000                   580.0000
# 3                             1.0000                     1.2000
# 4                             1.8612                    44.0612
#
#                      geometry
# 0  POINT (-66.23194 17.97278)
# 1  POINT (-67.13655 18.45647)
# 2  POINT (-67.13682 18.29298)
# 3  POINT (-67.14019 18.29244)
# 4  POINT (-66.69940 18.47110)
#
# [5 rows x 44 columns]

# %% [markdown]
# TRI facilities tend to be located in populated areas, but are there areas that stand out more than others?
