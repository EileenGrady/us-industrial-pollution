# %% [markdown]
# # Explore TRI facility releases over time
#
# I want to explore trends over time. I downloaded each TRI basic data file for the US for all years available, 1987-2018 to retrieve facility location information and release amounts. RSEI scores and modeled hazards were downloaded for years available, 2007-2018.

# %%
# import packages
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from shapely.geometry import Polygon
from shapely.geometry import mapping
from functools import reduce
import os
import re
import numpy as np

import warnings
warnings.simplefilter(action='ignore')

# supress scientific notation
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %% [markdown]
# ### Wrangle TRI facility location information
#
# First I want to combine all the TRI data files for each year into one dataframe.

# %%
# define folder containing all tri files
folder = "../data/tri-data"

# create empty list to hold dataframes
fileList = list()

# add each file to the dataframe list
for file in os.listdir(folder):
    df = pd.read_csv(os.path.join(folder, file))
    fileList.append(df)
    
# concatenate all list of dataframes
combined = pd.concat(fileList, axis=0, ignore_index=True)
combined
# Out:
#          1. YEAR         2. TRIFD     3. FRS ID  \
# 0           1987  94304QLTYT3400H  110000609887
# 1           1987  45377NLNDD480ND  110000394467
# 2           1987  27215PRKVN1821N  110043582101
# 3           1987  70058VNSCP1255P  110000448757
# 4           1987  55425VTCNC2401E  110002123158
# ...          ...              ...           ...
# 2739472     2018  42366PRMML5680O  110000380971
# 2739473     2018  37066STVGL1499S  110000493136
# 2739474     2018  6416WPNNYS861NE  110020834276
# 2739475     2018  46368BTSTL6500S  110000398212
# 2739476     2018  63115KLLRK3940M  110001452357
#
#                                     4. FACILITY NAME  \
# 0                                       QUALITY TECH
# 1        DELPHI ENERGY & CHASSIS VANDALIA OPERATIONS
# 2                   GLEN RAVEN TECHNICAL FABRICS LLC
# 3            GREIF USA (DBA GREIF HARVEY DCS HARVEY)
# 4                                VTC INC RIVER RIDGE
# ...                                              ...
# 2739472                          HINES PRECISION INC
# 2739473                 US TVA GALLATIN FOSSIL PLANT
# 2739474                              PENNYS CONCRETE
# 2739475                                 NLMK INDIANA
# 2739476                                      KILLARK
#
#                   5. STREET ADDRESS      6. CITY         7. COUNTY 8. ST  \
# 0                 3400 HILLVIEW AVE    PALO ALTO       SANTA CLARA    CA
# 1                    480 N DIXIE DR     VANDALIA        MONTGOMERY    OH
# 2                   1821 N PARK AVE   BURLINGTON          ALAMANCE    NC
# 3                    1255 PETERS RD       HARVEY  JEFFERSON PARISH    LA
# 4                    2401 E 28TH ST  BLOOMINGTON          HENNEPIN    MN
# ...                             ...          ...               ...   ...
# 2739472              5680 OLD KY 54      PHILPOT           DAVIESS    KY
# 2739473         1499 STEAM PLANT RD     GALLATIN            SUMNER    TN
# 2739474         8601 NE 38TH STREET  KANSAS CITY              CLAY    MO
# 2739475          6500 S BOUNDARY RD      PORTAGE            PORTER    IN
# 2739476  3940 MARTIN LUTHER KING DR  SAINT LOUIS   ST LOUIS (CITY)    MO
#
#         9. ZIP  10. BIA  ... 107. 8.3 - ENERGY RECOVER OF  \
# 0        94304      nan  ...                      0.00000
# 1        45377      nan  ...                      0.00000
# 2        27217      nan  ...                      0.00000
# 3        70058      nan  ...                      0.00000
# 4        55425      nan  ...                      0.00000
# ...        ...      ...  ...                          ...
# 2739472  42366      nan  ...                      0.00000
# 2739473  37066      nan  ...                      0.00000
# 2739474  64161      nan  ...                      0.00000
# 2739475  46368      nan  ...                      0.00000
# 2739476  63113      nan  ...                      0.00000
#
#          108. 8.4 - RECYCLING ON SITE  109. 8.5 - RECYCLING OFF SIT  \
# 0                             0.00000                       0.00000
# 1                             0.00000                       0.00000
# 2                             0.00000                       0.00000
# 3                             0.00000                       0.00000
# 4                             0.00000                       0.00000
# ...                               ...                           ...
# 2739472                       0.00000                       0.00000
# 2739473                       0.00000                       0.00000
# 2739474                       0.00000                       0.00000
# 2739475                       0.00000                   53429.00000
# 2739476                       0.00000                       0.00000
#
#         110. 8.6 - TREATMENT ON SITE 111. 8.7 - TREATMENT OFF SITE  \
# 0                            0.00000                       0.00000
# 1                            0.00000                       0.00000
# 2                            0.00000                       0.00000
# 3                            0.00000                       0.00000
# 4                            0.00000                       0.00000
# ...                              ...                           ...
# 2739472                      0.00000                       0.00000
# 2739473                      0.00000                       0.00000
# 2739474                      0.00000                       0.00000
# 2739475                      0.00000                       0.00000
# 2739476                      0.00000                       0.00000
#
#         112. PRODUCTION WSTE (8.1-8.7) 113. 8.8 - ONE-TIME RELEASE  \
# 0                              0.00000                         nan
# 1                              0.00000                         nan
# 2                              0.00000                         nan
# 3                              0.00000                         nan
# 4                              0.00000                         nan
# ...                                ...                         ...
# 2739472                        0.00000                         nan
# 2739473                        9.40000                         nan
# 2739474                        0.00000                         nan
# 2739475                    53752.12000                         nan
# 2739476                        0.00000                         nan
#
#          114. PROD_RATIO_OR_ ACTIVITY 115. 8.9 - PRODUCTION RATIO Unnamed: 115
# 0                                 NaN                         nan          nan
# 1                                 NaN                         nan          nan
# 2                                 NaN                         nan          nan
# 3                                 NaN                         nan          nan
# 4                                 NaN                         nan          nan
# ...                               ...                         ...          ...
# 2739472                           NaN                         nan          nan
# 2739473                    PRODUCTION                     0.98000          nan
# 2739474                      ACTIVITY                     1.00000          nan
# 2739475                    PRODUCTION                     1.00000          nan
# 2739476                    PRODUCTION                     1.03000          nan
#
# [2739477 rows x 116 columns]

# %%
# create copy to revert back to
tri = combined.copy()

# %%
# remove leading numbers, periods, and space and from column names
tri.columns = tri.columns.str.lstrip('0123456789.- ')

# replace spaces in column names with underscores
tri.columns = tri.columns.str.replace(' ', '_')

# replace dashes in column names with underscores
tri.columns = tri.columns.str.replace('-', '_')

#convert column names to uppercase
tri.columns = map(str.upper, tri.columns)

tri.head()
# Out:
#    YEAR            TRIFD        FRS_ID  \
# 0  1987  94304QLTYT3400H  110000609887
# 1  1987  45377NLNDD480ND  110000394467
# 2  1987  27215PRKVN1821N  110043582101
# 3  1987  70058VNSCP1255P  110000448757
# 4  1987  55425VTCNC2401E  110002123158
#
#                                  FACILITY_NAME     STREET_ADDRESS  \
# 0                                 QUALITY TECH  3400 HILLVIEW AVE
# 1  DELPHI ENERGY & CHASSIS VANDALIA OPERATIONS     480 N DIXIE DR
# 2             GLEN RAVEN TECHNICAL FABRICS LLC    1821 N PARK AVE
# 3      GREIF USA (DBA GREIF HARVEY DCS HARVEY)     1255 PETERS RD
# 4                          VTC INC RIVER RIDGE     2401 E 28TH ST
#
#           CITY            COUNTY  ST    ZIP  BIA  ... ENERGY_RECOVER_OF  \
# 0    PALO ALTO       SANTA CLARA  CA  94304  nan  ...           0.00000
# 1     VANDALIA        MONTGOMERY  OH  45377  nan  ...           0.00000
# 2   BURLINGTON          ALAMANCE  NC  27217  nan  ...           0.00000
# 3       HARVEY  JEFFERSON PARISH  LA  70058  nan  ...           0.00000
# 4  BLOOMINGTON          HENNEPIN  MN  55425  nan  ...           0.00000
#
#    RECYCLING_ON_SITE  RECYCLING_OFF_SIT TREATMENT_ON_SITE TREATMENT_OFF_SITE  \
# 0            0.00000            0.00000           0.00000            0.00000
# 1            0.00000            0.00000           0.00000            0.00000
# 2            0.00000            0.00000           0.00000            0.00000
# 3            0.00000            0.00000           0.00000            0.00000
# 4            0.00000            0.00000           0.00000            0.00000
#
#   PRODUCTION_WSTE_(8.1_8.7) ONE_TIME_RELEASE  PROD_RATIO_OR__ACTIVITY  \
# 0                   0.00000              nan                      NaN
# 1                   0.00000              nan                      NaN
# 2                   0.00000              nan                      NaN
# 3                   0.00000              nan                      NaN
# 4                   0.00000              nan                      NaN
#
#   PRODUCTION_RATIO UNNAMED:_115
# 0              nan          nan
# 1              nan          nan
# 2              nan          nan
# 3              nan          nan
# 4              nan          nan
#
# [5 rows x 116 columns]

# %%
# replace spaces in column names with underscores
tri.columns = tri.columns.str.replace(' ', '_')

# replace dashes in column names with underscores
tri.columns = tri.columns.str.replace('-', '_')

#convert column names to uppercase
tri.columns = map(str.upper, tri.columns)

tri.head()
# Out:
#    YEAR            TRIFD        FRS_ID  \
# 0  1987  94304QLTYT3400H  110000609887
# 1  1987  45377NLNDD480ND  110000394467
# 2  1987  27215PRKVN1821N  110043582101
# 3  1987  70058VNSCP1255P  110000448757
# 4  1987  55425VTCNC2401E  110002123158
#
#                                  FACILITY_NAME     STREET_ADDRESS  \
# 0                                 QUALITY TECH  3400 HILLVIEW AVE
# 1  DELPHI ENERGY & CHASSIS VANDALIA OPERATIONS     480 N DIXIE DR
# 2             GLEN RAVEN TECHNICAL FABRICS LLC    1821 N PARK AVE
# 3      GREIF USA (DBA GREIF HARVEY DCS HARVEY)     1255 PETERS RD
# 4                          VTC INC RIVER RIDGE     2401 E 28TH ST
#
#           CITY            COUNTY  ST    ZIP  BIA  ... ENERGY_RECOVER_OF  \
# 0    PALO ALTO       SANTA CLARA  CA  94304  nan  ...           0.00000
# 1     VANDALIA        MONTGOMERY  OH  45377  nan  ...           0.00000
# 2   BURLINGTON          ALAMANCE  NC  27217  nan  ...           0.00000
# 3       HARVEY  JEFFERSON PARISH  LA  70058  nan  ...           0.00000
# 4  BLOOMINGTON          HENNEPIN  MN  55425  nan  ...           0.00000
#
#    RECYCLING_ON_SITE  RECYCLING_OFF_SIT TREATMENT_ON_SITE TREATMENT_OFF_SITE  \
# 0            0.00000            0.00000           0.00000            0.00000
# 1            0.00000            0.00000           0.00000            0.00000
# 2            0.00000            0.00000           0.00000            0.00000
# 3            0.00000            0.00000           0.00000            0.00000
# 4            0.00000            0.00000           0.00000            0.00000
#
#   PRODUCTION_WSTE_(8.1_8.7) ONE_TIME_RELEASE  PROD_RATIO_OR__ACTIVITY  \
# 0                   0.00000              nan                      NaN
# 1                   0.00000              nan                      NaN
# 2                   0.00000              nan                      NaN
# 3                   0.00000              nan                      NaN
# 4                   0.00000              nan                      NaN
#
#   PRODUCTION_RATIO UNNAMED:_115
# 0              nan          nan
# 1              nan          nan
# 2              nan          nan
# 3              nan          nan
# 4              nan          nan
#
# [5 rows x 116 columns]

# %%
list(tri.columns)
# Out:
# ['YEAR',
#  'TRIFD',
#  'FRS_ID',
#  'FACILITY_NAME',
#  'STREET_ADDRESS',
#  'CITY',
#  'COUNTY',
#  'ST',
#  'ZIP',
#  'BIA',
#  'TRIBE',
#  'LATITUDE',
#  'LONGITUDE',
#  'PARENT_CO_NAME',
#  'PARENT_CO_DB_NUM',
#  'STANDARD_PARENT_CO_NAME',
#  'FEDERAL_FACILITY',
#  'INDUSTRY_SECTOR_CODE',
#  'INDUSTRY_SECTOR',
#  'PRIMARY_SIC',
#  'SIC_2',
#  'SIC_3',
#  'SIC_4',
#  'SIC_5',
#  'SIC_6',
#  'PRIMARY_NAICS',
#  'NAICS_2',
#  'NAICS_3',
#  'NAICS_4',
#  'NAICS_5',
#  'NAICS_6',
#  'DOC_CTRL_NUM',
#  'CHEMICAL',
#  'ELEMENTAL_METAL_INCLUDED',
#  'CAS_#/COMPOUND_ID',
#  'SRS_ID',
#  'CLEAN_AIR_ACT_CHEMICAL',
#  'CLASSIFICATION',
#  'METAL',
#  'METAL_CATEGORY',
#  'CARCINOGEN',
#  'FORM_TYPE',
#  'UNIT_OF_MEASURE',
#  'FUGITIVE_AIR',
#  'STACK_AIR',
#  'WATER',
#  'UNDERGROUND',
#  'UNDERGROUND_CL_I',
#  'UNDERGROUND_C_II_V',
#  'LANDFILLS',
#  'A___RCRA_C_LANDFILL',
#  'B___OTHER_LANDFILLS',
#  'LAND_TREATMENT',
#  'SURFACE_IMPNDMNT',
#  'A___RCRA_SURFACE_IM',
#  'B___OTHER_SURFACE_I',
#  'OTHER_DISPOSAL',
#  'ON_SITE_RELEASE_TOTAL',
#  'POTW___TRNS_RLSE',
#  'POTW___TRNS_TRT',
#  'POTW___TOTAL_TRANSFERS',
#  'M10',
#  'M41',
#  'M62',
#  'M40_METAL',
#  'M61_METAL',
#  'M71',
#  'M81',
#  'M82',
#  'M72',
#  'M63',
#  'M66',
#  'M67',
#  'M64',
#  'M65',
#  'M73',
#  'M79',
#  'M90',
#  'M94',
#  'M99',
#  'OFF_SITE_RELEASE_TOTAL',
#  'M20',
#  'M24',
#  'M26',
#  'M28',
#  'M93',
#  'OFF_SITE_RECYCLED_TOTAL',
#  'M56',
#  'M92',
#  'OFF_SITE_ENERGY_RECOVERY_T',
#  'M40_NON_METAL',
#  'M50',
#  'M54',
#  'M61_NON_METAL',
#  'M69',
#  'M95',
#  'OFF_SITE_TREATED_TOTAL',
#  'UNCLASSIFIED',
#  'TOTAL_TRANSFER',
#  'TOTAL_RELEASES',
#  'RELEASES',
#  'A___ON_SITE_CONTAINED',
#  'B___ON_SITE_OTHER_',
#  'C___OFF_SITE_CONTAIN',
#  'D___OFF_SITE_OTHER_R',
#  'ENERGY_RECOVER_ON',
#  'ENERGY_RECOVER_OF',
#  'RECYCLING_ON_SITE',
#  'RECYCLING_OFF_SIT',
#  'TREATMENT_ON_SITE',
#  'TREATMENT_OFF_SITE',
#  'PRODUCTION_WSTE_(8.1_8.7)',
#  'ONE_TIME_RELEASE',
#  'PROD_RATIO_OR__ACTIVITY',
#  'PRODUCTION_RATIO',
#  'UNNAMED:_115']

# %% [markdown]
# [TRI basic data files documentation](https://www.epa.gov/sites/production/files/2019-08/documents/basic_data_files_documentation_aug_2019_v2.pdf)
#
# On-site release total = Total quantity of the toxic chemical released to air, water and
# land on-site at the facility.
#
# Off-site release total = Total quantity of the toxic chemical reported as transferred to
# off-site locations for release or disposal.
#
# There are several columns for various types of land release, and they vary by year as reporting changed in 1996 and 2003. Water and air release columns are consistent for each year, so for now I will just stick with on-site release totals and air and water releases. I will not look at off-site releases, because waste can be double counted if counted once by facility as off-site release, and then again by the receiving facility as on-site release.
#
# Ultimately I want one record per facility, with columns for on-site release totals, plus release totals for water and air release, for each year. There is only one column for water release, and air releases are reported by fugitive and stack. Most chemicals are reported in pounds, except for dioxides which are reported in grams. So before any aggregating I also need to convert records measured in grams into pounds.
#
# I will also sum RSEI score and RSEI modeled hazards to join to the TRI facilities.

# %%
# create new column summing fugitive air and stack air release
tri['AIR'] = tri['FUGITIVE_AIR'] + tri['STACK_AIR']

# %%
# filter columns to keep
tri_filter = tri.filter(['YEAR','TRIFD','FACILITY_NAME','STREET_ADDRESS','CITY','COUNTY','ST','ZIP','BIA','TRIBE','LATITUDE','LONGITUDE','INDUSTRY_SECTOR','PARENT_CO_NAME', 'CHEMICAL', 'WATER','ON_SITE_RELEASE_TOTAL','AIR','UNIT_OF_MEASURE'], axis=1)
tri_filter.head()
# Out:
#    YEAR            TRIFD                                FACILITY_NAME  \
# 0  1987  94304QLTYT3400H                                 QUALITY TECH
# 1  1987  45377NLNDD480ND  DELPHI ENERGY & CHASSIS VANDALIA OPERATIONS
# 2  1987  27215PRKVN1821N             GLEN RAVEN TECHNICAL FABRICS LLC
# 3  1987  70058VNSCP1255P      GREIF USA (DBA GREIF HARVEY DCS HARVEY)
# 4  1987  55425VTCNC2401E                          VTC INC RIVER RIDGE
#
#       STREET_ADDRESS         CITY            COUNTY  ST    ZIP  BIA TRIBE  \
# 0  3400 HILLVIEW AVE    PALO ALTO       SANTA CLARA  CA  94304  nan   NaN
# 1     480 N DIXIE DR     VANDALIA        MONTGOMERY  OH  45377  nan   NaN
# 2    1821 N PARK AVE   BURLINGTON          ALAMANCE  NC  27217  nan   NaN
# 3     1255 PETERS RD       HARVEY  JEFFERSON PARISH  LA  70058  nan   NaN
# 4     2401 E 28TH ST  BLOOMINGTON          HENNEPIN  MN  55425  nan   NaN
#
#    LATITUDE  LONGITUDE                    INDUSTRY_SECTOR  \
# 0  37.40348 -122.14600  Computers and Electronic Products
# 1  39.90040  -84.19882           Transportation Equipment
# 2  36.10932  -79.46178                           Textiles
# 3  29.88758  -90.07416                  Fabricated Metals
# 4  44.95979  -93.23143  Computers and Electronic Products
#
#                      PARENT_CO_NAME  \
# 0                      QUALITY TECH
# 1     DELPHI AUTOMOTIVE SYSTEMS LLC
# 2  GLEN RAVEN TECHNICAL FABRICS LLC
# 3                         GREIF USA
# 4                 CONTROL DATA CORP
#
#                                             CHEMICAL   WATER  \
# 0                                    PHOSPHORIC ACID 0.00000
# 1  SULFURIC ACID (1994 AND AFTER ACID AEROSOLS" O... 0.00000
# 2                        AMMONIUM SULFATE (SOLUTION) 0.00000
# 3                          N-NITROSODI-N-PROPYLAMINE 0.00000
# 4  SULFURIC ACID (1994 AND AFTER ACID AEROSOLS" O... 0.00000
#
#    ON_SITE_RELEASE_TOTAL        AIR UNIT_OF_MEASURE
# 0              250.00000  250.00000          Pounds
# 1                0.00000    0.00000          Pounds
# 2                0.00000    0.00000          Pounds
# 3             2700.00000 2700.00000          Pounds
# 4                0.00000    0.00000          Pounds

# %%
# inspect the different units of measure
tri_filter['UNIT_OF_MEASURE'].unique()
# Out:
# array(['Pounds', 'Grams'], dtype=object)

# %%
# # convert any gram measurements to pounds
# for index, row in tri_filter.iterrows(): # loop through each row
#     if row['UNIT_OF_MEASURE'] == 'Grams':
#         tri_filter.loc[index, 'ON_SITE_RELEASE_TOTAL'] = row['ON_SITE_RELEASE_TOTAL']/454
#         tri_filter.loc[index, 'WATER'] = row['WATER']/454
#         tri_filter.loc[index, 'AIR'] = row['AIR']/454

# %%
# filter all records measured in grams
grams = tri_filter.loc[tri_filter['UNIT_OF_MEASURE'] == 'Grams']

# convert gram measure to pounds
grams['ON_SITE_RELEASE_TOTAL'] = grams['ON_SITE_RELEASE_TOTAL']/454
grams['WATER'] = grams['WATER']/454
grams['AIR'] = grams['AIR']/454

# change unit of measure to pounds
grams['UNIT_OF_MEASURE'] = 'Pounds'

# check results
grams
# Out:
#          YEAR            TRIFD                             FACILITY_NAME  \
# 960756   1998  95017RMCPC700HW           RMC PACIFIC MATERIALS DBA CEMEX
# 1009938  1999  95017RMCPC700HW           RMC PACIFIC MATERIALS DBA CEMEX
# 1058622  1999  46302XDCRP2601W                        EXIDE TECHNOLOGIES
# 1086371  2000  71411WLLMTHIGHW      INTERNATIONAL PAPER / RED RIVER MILL
# 1086534  2000  16531GNRLL2901E                  GE TRANSPORTATION - ERIE
# ...       ...              ...                                       ...
# 2739119  2018  37716STVBL1265E              US TVA BULL RUN FOSSIL PLANT
# 2739221  2018  36548CHRLSCARSO              CHARLES R LOWMAN POWER PLANT
# 2739320  2018  84116CHVRN2351N  CHEVRON PRODUCTS CO - SALT LAKE REFINERY
# 2739400  2018  9852WSPBRD31HAG                 SPI ABERDEEN-GRAYS HARBOR
# 2739429  2018  49855PRSQS2701L                  PRESQUE ISLE POWER PLANT
#
#                      STREET_ADDRESS            CITY               COUNTY  ST  \
# 960756                700 HIGHWAY 1       DAVENPORT           SANTA CRUZ  CA
# 1009938               700 HIGHWAY 1       DAVENPORT           SANTA CRUZ  CA
# 1058622  2601 W MOUNT PLEASANT BLVD          MUNCIE             DELAWARE  IN
# 1086371                4537 HWY 480          CAMPTI  NATCHITOCHES PARISH  LA
# 1086534              2901 E LAKE RD            ERIE                 ERIE  PA
# ...                             ...             ...                  ...  ..
# 2739119            1265 EDGEMOOR RD         CLINTON             ANDERSON  TN
# 2739221              4392 CARSON RD           LEROY           WASHINGTON  AL
# 2739320        2351 NORTH 1100 WEST  SALT LAKE CITY            SALT LAKE  UT
# 2739400               301 HAGARA ST        ABERDEEN         GRAYS HARBOR  WA
# 2739429         2701 LAKESHORE BLVD       MARQUETTE            MARQUETTE  MI
#
#            ZIP  BIA TRIBE  LATITUDE  LONGITUDE              INDUSTRY_SECTOR  \
# 960756   95017  nan   NaN  37.01563 -122.19902  Nonmetallic Mineral Product
# 1009938  95017  nan   NaN  37.01563 -122.19902  Nonmetallic Mineral Product
# 1058622  47302  nan   NaN  40.15696  -85.41742               Primary Metals
# 1086371  71411  nan   NaN  31.90533  -93.17364                        Paper
# 1086534  16531  nan   NaN  42.14545  -80.02544     Transportation Equipment
# ...        ...  ...   ...       ...        ...                          ...
# 2739119  37716  nan   NaN  36.02280  -84.15180           Electric Utilities
# 2739221  36548  nan   NaN  31.48870  -87.91030           Electric Utilities
# 2739320  84116  nan   NaN  40.82490 -111.92380                    Petroleum
# 2739400  98520  nan   NaN  46.97306 -123.77805                Wood Products
# 2739429  49855  nan   NaN  46.57917  -87.39613           Electric Utilities
#
#                         PARENT_CO_NAME   WATER  ON_SITE_RELEASE_TOTAL     AIR  \
# 960756                           CEMEX 0.00000                0.00047 0.00047
# 1009938                          CEMEX 0.00000                0.00050 0.00050
# 1058622             EXIDE TECHNOLOGIES 0.00000                0.00220 0.00220
# 1086371         INTERNATIONAL PAPER CO 0.00000                0.00137 0.00126
# 1086534            WABTEC US RAIL INC. 0.00000                0.00070 0.00070
# ...                                ...     ...                    ...     ...
# 2739119  US TENNESSEE VALLEY AUTHORITY 0.00000                0.00062 0.00062
# 2739221  POWERSOUTH ENERGY COOPERATIVE 0.00000                0.00053 0.00053
# 2739320                   CHEVRON CORP 0.00002                0.00002 0.00000
# 2739400      SIERRA PACIFIC INDUSTRIES 0.00000                0.00163 0.00163
# 2739429               WEC ENERGY GROUP 0.00000                0.00088 0.00088
#
#         UNIT_OF_MEASURE
# 960756           Pounds
# 1009938          Pounds
# 1058622          Pounds
# 1086371          Pounds
# 1086534          Pounds
# ...                 ...
# 2739119          Pounds
# 2739221          Pounds
# 2739320          Pounds
# 2739400          Pounds
# 2739429          Pounds
#
# [21529 rows x 18 columns]

# %%
# append converted records back to tri dataframe
tri_filter.append(grams)

# redefine tri_filter dataframe as records measured in pounds
tri_filter = tri_filter[tri_filter['UNIT_OF_MEASURE'] == 'Pounds']

tri_filter
# Out:
#          YEAR            TRIFD                                FACILITY_NAME  \
# 0        1987  94304QLTYT3400H                                 QUALITY TECH
# 1        1987  45377NLNDD480ND  DELPHI ENERGY & CHASSIS VANDALIA OPERATIONS
# 2        1987  27215PRKVN1821N             GLEN RAVEN TECHNICAL FABRICS LLC
# 3        1987  70058VNSCP1255P      GREIF USA (DBA GREIF HARVEY DCS HARVEY)
# 4        1987  55425VTCNC2401E                          VTC INC RIVER RIDGE
# ...       ...              ...                                          ...
# 2739472  2018  42366PRMML5680O                          HINES PRECISION INC
# 2739473  2018  37066STVGL1499S                 US TVA GALLATIN FOSSIL PLANT
# 2739474  2018  6416WPNNYS861NE                              PENNYS CONCRETE
# 2739475  2018  46368BTSTL6500S                                 NLMK INDIANA
# 2739476  2018  63115KLLRK3940M                                      KILLARK
#
#                      STREET_ADDRESS         CITY            COUNTY  ST    ZIP  \
# 0                 3400 HILLVIEW AVE    PALO ALTO       SANTA CLARA  CA  94304
# 1                    480 N DIXIE DR     VANDALIA        MONTGOMERY  OH  45377
# 2                   1821 N PARK AVE   BURLINGTON          ALAMANCE  NC  27217
# 3                    1255 PETERS RD       HARVEY  JEFFERSON PARISH  LA  70058
# 4                    2401 E 28TH ST  BLOOMINGTON          HENNEPIN  MN  55425
# ...                             ...          ...               ...  ..    ...
# 2739472              5680 OLD KY 54      PHILPOT           DAVIESS  KY  42366
# 2739473         1499 STEAM PLANT RD     GALLATIN            SUMNER  TN  37066
# 2739474         8601 NE 38TH STREET  KANSAS CITY              CLAY  MO  64161
# 2739475          6500 S BOUNDARY RD      PORTAGE            PORTER  IN  46368
# 2739476  3940 MARTIN LUTHER KING DR  SAINT LOUIS   ST LOUIS (CITY)  MO  63113
#
#          BIA TRIBE  LATITUDE  LONGITUDE                    INDUSTRY_SECTOR  \
# 0        nan   NaN  37.40348 -122.14600  Computers and Electronic Products
# 1        nan   NaN  39.90040  -84.19882           Transportation Equipment
# 2        nan   NaN  36.10932  -79.46178                           Textiles
# 3        nan   NaN  29.88758  -90.07416                  Fabricated Metals
# 4        nan   NaN  44.95979  -93.23143  Computers and Electronic Products
# ...      ...   ...       ...        ...                                ...
# 2739472  nan   NaN  37.73491  -87.00282                  Fabricated Metals
# 2739473  nan   NaN  36.32460  -86.40260                 Electric Utilities
# 2739474  nan   NaN  39.16218  -94.48128        Nonmetallic Mineral Product
# 2739475  nan   NaN  41.62152  -87.16148                     Primary Metals
# 2739476  nan   NaN  38.65141  -90.23342               Electrical Equipment
#
#                            PARENT_CO_NAME   WATER  ON_SITE_RELEASE_TOTAL  \
# 0                            QUALITY TECH 0.00000              250.00000
# 1           DELPHI AUTOMOTIVE SYSTEMS LLC 0.00000                0.00000
# 2        GLEN RAVEN TECHNICAL FABRICS LLC 0.00000                0.00000
# 3                               GREIF USA 0.00000             2700.00000
# 4                       CONTROL DATA CORP 0.00000                0.00000
# ...                                   ...     ...                    ...
# 2739472                               NaN 0.00000                0.00000
# 2739473     US TENNESSEE VALLEY AUTHORITY 0.00000                9.40000
# 2739474                   PENNYS CONCRETE 0.00000                0.00000
# 2739475                               NaN 5.92000                6.02000
# 2739476                       HUBBELL INC 0.00000                0.00000
#
#                AIR UNIT_OF_MEASURE
# 0        250.00000          Pounds
# 1          0.00000          Pounds
# 2          0.00000          Pounds
# 3       2700.00000          Pounds
# 4          0.00000          Pounds
# ...            ...             ...
# 2739472    0.00000          Pounds
# 2739473    3.70000          Pounds
# 2739474    0.00000          Pounds
# 2739475    0.10000          Pounds
# 2739476    0.00000          Pounds
#
# [2717948 rows x 18 columns]

# %%
# now reduce filtered dataframe to find one record per facility
# use group by TRIFID field, and only keep the identifying fields about each facility
# will use this to join to after performing pivot table operations
all_tri = tri_filter.fillna('').groupby('TRIFD').agg({'FACILITY_NAME':'first',
                             'STREET_ADDRESS':'first',
                             'CITY':'first',
                             'COUNTY':'first',
                             'ST':'first',
                             'ZIP':'first',
                             'BIA':'first',
                             'TRIBE':'first',
                             'LATITUDE':'first',
                             'LONGITUDE':'first',
                             'INDUSTRY_SECTOR':'first',
                             'PARENT_CO_NAME': 'first'
                                               }).reset_index()

all_tri

# %%
# # filter columns to keep
# tri_filter = tri.filter(['YEAR','TRIFD','FACILITY_NAME','STREET_ADDRESS','CITY','COUNTY','ST','ZIP','BIA','TRIBE','LATITUDE','LONGITUDE','INDUSTRY_SECTOR','PARENT_CO_NAME','WATER','ON_SITE_RELEASE_TOTAL','AIR_TOTAL'], axis=1)
# tri_filter.head()

# %%
# create pivot table summing totals to create records per facility per year, with total releases
pivot = pd.pivot_table(tri_filter,index=['YEAR', 'TRIFD'], values=['ON_SITE_RELEASE_TOTAL'],aggfunc=np.sum)
pivot
# Out:
#                       ON_SITE_RELEASE_TOTAL
# YEAR TRIFD
# 1987 00602BXTRHRD115                0.00000
#      00602DSCFPPOBOX            21862.00000
#      00602GRNGRAGUAD            14723.00000
#      00605BRNQNPR467                0.00000
#      00605VNMRBMONTA            19147.00000
# ...                                     ...
# 2018 99801CRLSK331CL          2212952.20000
#      99801KNNCT13401         55589597.00000
#      9980WCRWLY176JA             2185.28000
#      99901SCSTG1300S                0.80000
#      9990WCRWLY9STED             1397.34000
#
# [747975 rows x 1 columns]

# %%
# rename columns to simplify names
pivot = pivot.rename(columns={'ON_SITE_RELEASE_TOTAL':'TOTAL'})
pivot
# Out:
#                               TOTAL
# YEAR TRIFD
# 1987 00602BXTRHRD115        0.00000
#      00602DSCFPPOBOX    21862.00000
#      00602GRNGRAGUAD    14723.00000
#      00605BRNQNPR467        0.00000
#      00605VNMRBMONTA    19147.00000
# ...                             ...
# 2018 99801CRLSK331CL  2212952.20000
#      99801KNNCT13401 55589597.00000
#      9980WCRWLY176JA     2185.28000
#      99901SCSTG1300S        0.80000
#      9990WCRWLY9STED     1397.34000
#
# [747975 rows x 1 columns]

# %%
# unstack pivot table to create columns for release type for each year
amountsUnstacked = pivot.unstack(level=0)
amountsUnstacked
# Out:
#                       TOTAL                                                 \
# YEAR                   1987        1988        1989        1990       1991
# TRIFD
# 00602BXTRF111CO         nan 11700.00000 12000.00000         nan        nan
# 00602BXTRHRD115     0.00000   250.00000     0.00000     0.00000    0.00000
# 00602DSCFPPOBOA         nan         nan 17447.00000  4086.00000        nan
# 00602DSCFPPOBOX 21862.00000         nan 17717.00000 14730.00000        nan
# 00602GRNGRAGUAD 14723.00000         nan 22349.00000 25133.00000 4900.00000
# ...                     ...         ...         ...         ...        ...
# 99901LSKSH381TN         nan         nan         nan         nan        nan
# 99901SCSTG1300S         nan         nan         nan         nan        nan
# 99901TSRLS1010S         nan         nan         nan         nan        nan
# 9990WCRWLY9STED         nan         nan         nan         nan        nan
# 99929TRDNT641SH         nan         nan         nan         nan        nan
#
#                                                          ...                  \
# YEAR               1992    1993    1994    1995    1996  ...    2009    2010
# TRIFD                                                    ...
# 00602BXTRF111CO     nan     nan     nan     nan     nan  ...     nan     nan
# 00602BXTRHRD115 0.00000 0.00000 0.00000 0.00000 0.00000  ...     nan     nan
# 00602DSCFPPOBOA     nan     nan     nan     nan     nan  ...     nan     nan
# 00602DSCFPPOBOX     nan     nan     nan     nan     nan  ...     nan     nan
# 00602GRNGRAGUAD     nan     nan     nan     nan     nan  ...     nan     nan
# ...                 ...     ...     ...     ...     ...  ...     ...     ...
# 99901LSKSH381TN     nan     nan     nan     nan     nan  ...     nan     nan
# 99901SCSTG1300S     nan     nan     nan     nan     nan  ... 0.00000 0.00000
# 99901TSRLS1010S     nan     nan     nan     nan     nan  ...     nan     nan
# 9990WCRWLY9STED     nan     nan     nan     nan     nan  ...     nan     nan
# 99929TRDNT641SH     nan     nan     nan     nan     nan  ... 0.00000     nan
#
#                                                                      \
# YEAR                  2011       2012    2013       2014       2015
# TRIFD
# 00602BXTRF111CO        nan        nan     nan        nan        nan
# 00602BXTRHRD115        nan        nan     nan        nan        nan
# 00602DSCFPPOBOA        nan        nan     nan        nan        nan
# 00602DSCFPPOBOX        nan        nan     nan        nan        nan
# 00602GRNGRAGUAD        nan        nan     nan        nan        nan
# ...                    ...        ...     ...        ...        ...
# 99901LSKSH381TN 9362.00000 1534.00000     nan 8043.31460        nan
# 99901SCSTG1300S    0.00000    0.00000 0.49320    0.29320    0.10520
# 99901TSRLS1010S        nan        nan     nan        nan        nan
# 9990WCRWLY9STED        nan        nan     nan 1769.95000 1825.74000
# 99929TRDNT641SH        nan        nan     nan        nan        nan
#
#
# YEAR                  2016       2017       2018
# TRIFD
# 00602BXTRF111CO        nan        nan        nan
# 00602BXTRHRD115        nan        nan        nan
# 00602DSCFPPOBOA        nan        nan        nan
# 00602DSCFPPOBOX        nan        nan        nan
# 00602GRNGRAGUAD        nan        nan        nan
# ...                    ...        ...        ...
# 99901LSKSH381TN        nan        nan        nan
# 99901SCSTG1300S    0.14120    0.11410    0.80000
# 99901TSRLS1010S        nan        nan        nan
# 9990WCRWLY9STED 1474.49000 1412.03000 1397.34000
# 99929TRDNT641SH        nan        nan        nan
#
# [60528 rows x 32 columns]

# %%
# rename columns to reflect year and release type
amountsUnstacked.columns = [''.join(str(s).strip() for s in col if s) for col in amountsUnstacked.columns]
amountsUnstacked
# Out:
#                   TOTAL1987   TOTAL1988   TOTAL1989   TOTAL1990  TOTAL1991  \
# TRIFD
# 00602BXTRF111CO         nan 11700.00000 12000.00000         nan        nan
# 00602BXTRHRD115     0.00000   250.00000     0.00000     0.00000    0.00000
# 00602DSCFPPOBOA         nan         nan 17447.00000  4086.00000        nan
# 00602DSCFPPOBOX 21862.00000         nan 17717.00000 14730.00000        nan
# 00602GRNGRAGUAD 14723.00000         nan 22349.00000 25133.00000 4900.00000
# ...                     ...         ...         ...         ...        ...
# 99901LSKSH381TN         nan         nan         nan         nan        nan
# 99901SCSTG1300S         nan         nan         nan         nan        nan
# 99901TSRLS1010S         nan         nan         nan         nan        nan
# 9990WCRWLY9STED         nan         nan         nan         nan        nan
# 99929TRDNT641SH         nan         nan         nan         nan        nan
#
#                  TOTAL1992  TOTAL1993  TOTAL1994  TOTAL1995  TOTAL1996  ...  \
# TRIFD                                                                   ...
# 00602BXTRF111CO        nan        nan        nan        nan        nan  ...
# 00602BXTRHRD115    0.00000    0.00000    0.00000    0.00000    0.00000  ...
# 00602DSCFPPOBOA        nan        nan        nan        nan        nan  ...
# 00602DSCFPPOBOX        nan        nan        nan        nan        nan  ...
# 00602GRNGRAGUAD        nan        nan        nan        nan        nan  ...
# ...                    ...        ...        ...        ...        ...  ...
# 99901LSKSH381TN        nan        nan        nan        nan        nan  ...
# 99901SCSTG1300S        nan        nan        nan        nan        nan  ...
# 99901TSRLS1010S        nan        nan        nan        nan        nan  ...
# 9990WCRWLY9STED        nan        nan        nan        nan        nan  ...
# 99929TRDNT641SH        nan        nan        nan        nan        nan  ...
#
#                  TOTAL2009  TOTAL2010  TOTAL2011  TOTAL2012  TOTAL2013  \
# TRIFD
# 00602BXTRF111CO        nan        nan        nan        nan        nan
# 00602BXTRHRD115        nan        nan        nan        nan        nan
# 00602DSCFPPOBOA        nan        nan        nan        nan        nan
# 00602DSCFPPOBOX        nan        nan        nan        nan        nan
# 00602GRNGRAGUAD        nan        nan        nan        nan        nan
# ...                    ...        ...        ...        ...        ...
# 99901LSKSH381TN        nan        nan 9362.00000 1534.00000        nan
# 99901SCSTG1300S    0.00000    0.00000    0.00000    0.00000    0.49320
# 99901TSRLS1010S        nan        nan        nan        nan        nan
# 9990WCRWLY9STED        nan        nan        nan        nan        nan
# 99929TRDNT641SH    0.00000        nan        nan        nan        nan
#
#                  TOTAL2014  TOTAL2015  TOTAL2016  TOTAL2017  TOTAL2018
# TRIFD
# 00602BXTRF111CO        nan        nan        nan        nan        nan
# 00602BXTRHRD115        nan        nan        nan        nan        nan
# 00602DSCFPPOBOA        nan        nan        nan        nan        nan
# 00602DSCFPPOBOX        nan        nan        nan        nan        nan
# 00602GRNGRAGUAD        nan        nan        nan        nan        nan
# ...                    ...        ...        ...        ...        ...
# 99901LSKSH381TN 8043.31460        nan        nan        nan        nan
# 99901SCSTG1300S    0.29320    0.10520    0.14120    0.11410    0.80000
# 99901TSRLS1010S        nan        nan        nan        nan        nan
# 9990WCRWLY9STED 1769.95000 1825.74000 1474.49000 1412.03000 1397.34000
# 99929TRDNT641SH        nan        nan        nan        nan        nan
#
# [60528 rows x 32 columns]

# %%
amountsUnstacked.fillna(0)
amountsUnstacked.loc['TOTAL_RELEASE']= amountsUnstacked.sum()
amountsUnstacked
# Out:
#                         TOTAL1987        TOTAL1988        TOTAL1989  \
# TRIFD
# 00602BXTRF111CO               nan      11700.00000      12000.00000
# 00602BXTRHRD115           0.00000        250.00000          0.00000
# 00602DSCFPPOBOA               nan              nan      17447.00000
# 00602DSCFPPOBOX       21862.00000              nan      17717.00000
# 00602GRNGRAGUAD       14723.00000              nan      22349.00000
# ...                           ...              ...              ...
# 99901SCSTG1300S               nan              nan              nan
# 99901TSRLS1010S               nan              nan              nan
# 9990WCRWLY9STED               nan              nan              nan
# 99929TRDNT641SH               nan              nan              nan
# TOTAL_RELEASE   17495362548.00000 5680148075.00000 4452091324.00000
#
#                        TOTAL1990        TOTAL1991        TOTAL1992  \
# TRIFD
# 00602BXTRF111CO              nan              nan              nan
# 00602BXTRHRD115          0.00000          0.00000          0.00000
# 00602DSCFPPOBOA       4086.00000              nan              nan
# 00602DSCFPPOBOX      14730.00000              nan              nan
# 00602GRNGRAGUAD      25133.00000       4900.00000              nan
# ...                          ...              ...              ...
# 99901SCSTG1300S              nan              nan              nan
# 99901TSRLS1010S              nan              nan              nan
# 9990WCRWLY9STED              nan              nan              nan
# 99929TRDNT641SH              nan              nan              nan
# TOTAL_RELEASE   3753465237.00000 3496917822.96000 3318950504.64000
#
#                        TOTAL1993        TOTAL1994        TOTAL1995  \
# TRIFD
# 00602BXTRF111CO              nan              nan              nan
# 00602BXTRHRD115          0.00000          0.00000          0.00000
# 00602DSCFPPOBOA              nan              nan              nan
# 00602DSCFPPOBOX              nan              nan              nan
# 00602GRNGRAGUAD              nan              nan              nan
# ...                          ...              ...              ...
# 99901SCSTG1300S              nan              nan              nan
# 99901TSRLS1010S              nan              nan              nan
# 9990WCRWLY9STED              nan              nan              nan
# 99929TRDNT641SH              nan              nan              nan
# TOTAL_RELEASE   2909276729.72000 2365597221.36000 2387160808.09000
#
#                        TOTAL1996  ...        TOTAL2009        TOTAL2010  \
# TRIFD                             ...
# 00602BXTRF111CO              nan  ...              nan              nan
# 00602BXTRHRD115          0.00000  ...              nan              nan
# 00602DSCFPPOBOA              nan  ...              nan              nan
# 00602DSCFPPOBOX              nan  ...              nan              nan
# 00602GRNGRAGUAD              nan  ...              nan              nan
# ...                          ...  ...              ...              ...
# 99901SCSTG1300S              nan  ...          0.00000          0.00000
# 99901TSRLS1010S              nan  ...              nan              nan
# 9990WCRWLY9STED              nan  ...              nan              nan
# 99929TRDNT641SH              nan  ...          0.00000              nan
# TOTAL_RELEASE   2318409398.65000  ... 3038737468.64420 3401823195.53792
#
#                        TOTAL2011        TOTAL2012        TOTAL2013  \
# TRIFD
# 00602BXTRF111CO              nan              nan              nan
# 00602BXTRHRD115              nan              nan              nan
# 00602DSCFPPOBOA              nan              nan              nan
# 00602DSCFPPOBOX              nan              nan              nan
# 00602GRNGRAGUAD              nan              nan              nan
# ...                          ...              ...              ...
# 99901SCSTG1300S          0.00000          0.00000          0.49320
# 99901TSRLS1010S              nan              nan              nan
# 9990WCRWLY9STED              nan              nan              nan
# 99929TRDNT641SH              nan              nan              nan
# TOTAL_RELEASE   3701652530.05003 3232491920.86028 3727353563.30422
#
#                        TOTAL2014        TOTAL2015        TOTAL2016  \
# TRIFD
# 00602BXTRF111CO              nan              nan              nan
# 00602BXTRHRD115              nan              nan              nan
# 00602DSCFPPOBOA              nan              nan              nan
# 00602DSCFPPOBOX              nan              nan              nan
# 00602GRNGRAGUAD              nan              nan              nan
# ...                          ...              ...              ...
# 99901SCSTG1300S          0.29320          0.10520          0.14120
# 99901TSRLS1010S              nan              nan              nan
# 9990WCRWLY9STED       1769.95000       1825.74000       1474.49000
# 99929TRDNT641SH              nan              nan              nan
# TOTAL_RELEASE   3544714287.81079 2972866487.44393 3134064227.29282
#
#                        TOTAL2017        TOTAL2018
# TRIFD
# 00602BXTRF111CO              nan              nan
# 00602BXTRHRD115              nan              nan
# 00602DSCFPPOBOA              nan              nan
# 00602DSCFPPOBOX              nan              nan
# 00602GRNGRAGUAD              nan              nan
# ...                          ...              ...
# 99901SCSTG1300S          0.11410          0.80000
# 99901TSRLS1010S              nan              nan
# 9990WCRWLY9STED       1412.03000       1397.34000
# 99929TRDNT641SH              nan              nan
# TOTAL_RELEASE   3541607790.97415 3367991070.30157
#
# [60529 rows x 32 columns]

# %%
amountsUnstacked.to_json("../data/total-releases.json")

# %%
# now find top values for each column
# declare empty dataframe to hold top ordered rows
topRows = pd.DataFrame()

# create list of column names
columns = list(amountsUnstacked.columns)

# loop through each column
# finding the 100 largest values in each
# and appending to empty topRows dataframe
for column in columns:
    topValues = amountsUnstacked.nlargest(100, column)
    topRows = topRows.append(topValues)

topRows
# Out:
#                         TOTAL1987        TOTAL1988        TOTAL1989  \
# TRIFD
# TOTAL_RELEASE   17495362548.00000 5680148075.00000 4452091324.00000
# 93562KRRMC13200  5229012615.00000    1300574.00000    1078748.00000
# 77978LMNMCSTATE   468874750.00000   10700650.00000      30250.00000
# 76567LMNMCSANDO   329112650.00000    4683150.00000    1448233.00000
# 70094MRCNC10800   217298702.00000  176386400.00000  192340500.00000
# ...                           ...              ...              ...
# 46392NRTHR2723E               nan              nan              nan
# 37050STVCM815CU               nan              nan              nan
# 70669KRNSL3300B               nan              nan              nan
# 48161DTRTD3500E               nan              nan              nan
# 7785WKGRVS13MIL               nan              nan              nan
#
#                        TOTAL1990        TOTAL1991        TOTAL1992  \
# TRIFD
# TOTAL_RELEASE   3753465237.00000 3496917822.96000 3318950504.64000
# 93562KRRMC13200    1275504.00000    1039515.00000     634025.00000
# 77978LMNMCSTATE      19605.00000      10855.00000       8513.00000
# 76567LMNMCSANDO    1440839.00000    1214510.00000     978813.00000
# 70094MRCNC10800  162030982.00000  142009076.00000  147088590.00000
# ...                          ...              ...              ...
# 46392NRTHR2723E              nan              nan              nan
# 37050STVCM815CU              nan              nan              nan
# 70669KRNSL3300B              nan              nan      13583.00000
# 48161DTRTD3500E              nan              nan              nan
# 7785WKGRVS13MIL              nan              nan              nan
#
#                        TOTAL1993        TOTAL1994        TOTAL1995  \
# TRIFD
# TOTAL_RELEASE   2909276729.72000 2365597221.36000 2387160808.09000
# 93562KRRMC13200     556795.00000     415897.00000     320000.00000
# 77978LMNMCSTATE       2086.00000        458.00000       1046.00000
# 76567LMNMCSANDO     780927.00000    1177274.00000     914029.00000
# 70094MRCNC10800  120149724.00000   20514100.00000   29534568.00000
# ...                          ...              ...              ...
# 46392NRTHR2723E              nan              nan              nan
# 37050STVCM815CU              nan              nan              nan
# 70669KRNSL3300B    1198990.00000    1705506.00000    2523776.00000
# 48161DTRTD3500E              nan              nan              nan
# 7785WKGRVS13MIL              nan              nan              nan
#
#                        TOTAL1996  ...        TOTAL2009        TOTAL2010  \
# TRIFD                             ...
# TOTAL_RELEASE   2318409398.65000  ... 3038737468.64420 3401823195.53792
# 93562KRRMC13200     517953.00000  ...              nan              nan
# 77978LMNMCSTATE        961.00000  ...     104538.00000     178771.10000
# 76567LMNMCSANDO    1908875.00000  ...     180854.27000     264000.00000
# 70094MRCNC10800   28561121.00000  ...   14033632.00000   15611971.00000
# ...                          ...  ...              ...              ...
# 46392NRTHR2723E              nan  ...    4287714.00000    4556925.00000
# 37050STVCM815CU              nan  ...    5382106.50000    4715736.90000
# 70669KRNSL3300B    2821002.00000  ...    3066783.00000    3298216.00000
# 48161DTRTD3500E              nan  ...   14618971.97000    9587098.76000
# 7785WKGRVS13MIL              nan  ...     332865.38000    4213235.83000
#
#                        TOTAL2011        TOTAL2012        TOTAL2013  \
# TRIFD
# TOTAL_RELEASE   3701652530.05003 3232491920.86028 3727353563.30422
# 93562KRRMC13200              nan              nan              nan
# 77978LMNMCSTATE     199796.00000     188280.10000     215479.80000
# 76567LMNMCSANDO     353000.00000     159422.00000     133398.00000
# 70094MRCNC10800   12514975.00000   13033799.00000    9981778.00000
# ...                          ...              ...              ...
# 46392NRTHR2723E    3397391.00000    2345310.00000    3741248.00000
# 37050STVCM815CU    4363220.40000    5097929.20000    4722749.70000
# 70669KRNSL3300B    3321821.00000    3592649.00000    3183305.00000
# 48161DTRTD3500E   10049596.03000    9017157.56000    7705028.59000
# 7785WKGRVS13MIL    6239267.46000    6632922.40000    6398461.50000
#
#                        TOTAL2014        TOTAL2015        TOTAL2016  \
# TRIFD
# TOTAL_RELEASE   3544714287.81079 2972866487.44393 3134064227.29282
# 93562KRRMC13200              nan              nan              nan
# 77978LMNMCSTATE     229453.30000     235630.60000      31152.40000
# 76567LMNMCSANDO      62416.00000              nan              nan
# 70094MRCNC10800   11626902.87000   12079217.00000   12144943.00000
# ...                          ...              ...              ...
# 46392NRTHR2723E    4281160.00000    2885054.00000    2886632.00000
# 37050STVCM815CU    4433526.80000    4774354.40000    4607203.50000
# 70669KRNSL3300B    3284455.00000    3382155.00000    3492605.00000
# 48161DTRTD3500E    3535352.53000    3450607.93000    3577156.57000
# 7785WKGRVS13MIL    5917928.80000    4725968.87000    4432179.56000
#
#                        TOTAL2017        TOTAL2018
# TRIFD
# TOTAL_RELEASE   3541607790.97415 3367991070.30157
# 93562KRRMC13200              nan              nan
# 77978LMNMCSTATE              nan              nan
# 76567LMNMCSANDO              nan              nan
# 70094MRCNC10800   11604350.00000   14758762.00000
# ...                          ...              ...
# 46392NRTHR2723E    3142912.00000    3749726.00000
# 37050STVCM815CU    3406534.70000    3725472.70000
# 70669KRNSL3300B    3389960.00000    3725055.00000
# 48161DTRTD3500E    3608092.43000    3721469.62000
# 7785WKGRVS13MIL    4341808.35000    3709684.90000
#
# [3200 rows x 32 columns]

# %%
topRows = topRows.drop_duplicates()
topRows
# Out:
#                         TOTAL1987        TOTAL1988        TOTAL1989  \
# TRIFD
# TOTAL_RELEASE   17495362548.00000 5680148075.00000 4452091324.00000
# 93562KRRMC13200  5229012615.00000    1300574.00000    1078748.00000
# 77978LMNMCSTATE   468874750.00000   10700650.00000      30250.00000
# 76567LMNMCSANDO   329112650.00000    4683150.00000    1448233.00000
# 70094MRCNC10800   217298702.00000  176386400.00000  192340500.00000
# ...                           ...              ...              ...
# 89015TTNMMPOBOX         250.00000        500.00000       1540.00000
# 19706TXCDL2000W     7362990.00000     911024.00000     507911.00000
# 38563SVGZN120ZI               nan              nan              nan
# 0073WLLDWSBARAM               nan              nan              nan
# 15025SSCLR400ST     9682058.00000    5463388.00000    2988002.00000
#
#                        TOTAL1990        TOTAL1991        TOTAL1992  \
# TRIFD
# TOTAL_RELEASE   3753465237.00000 3496917822.96000 3318950504.64000
# 93562KRRMC13200    1275504.00000    1039515.00000     634025.00000
# 77978LMNMCSTATE      19605.00000      10855.00000       8513.00000
# 76567LMNMCSANDO    1440839.00000    1214510.00000     978813.00000
# 70094MRCNC10800  162030982.00000  142009076.00000  147088590.00000
# ...                          ...              ...              ...
# 89015TTNMMPOBOX     173117.00000     158451.00000     125775.00000
# 19706TXCDL2000W     567124.00000     465922.00000     408037.00000
# 38563SVGZN120ZI              nan              nan              nan
# 0073WLLDWSBARAM              nan              nan              nan
# 15025SSCLR400ST    2569496.00000    1078917.00000     184031.00000
#
#                        TOTAL1993        TOTAL1994        TOTAL1995  \
# TRIFD
# TOTAL_RELEASE   2909276729.72000 2365597221.36000 2387160808.09000
# 93562KRRMC13200     556795.00000     415897.00000     320000.00000
# 77978LMNMCSTATE       2086.00000        458.00000       1046.00000
# 76567LMNMCSANDO     780927.00000    1177274.00000     914029.00000
# 70094MRCNC10800  120149724.00000   20514100.00000   29534568.00000
# ...                          ...              ...              ...
# 89015TTNMMPOBOX     122155.00000      49500.00000      65100.00000
# 19706TXCDL2000W     344549.00000     292758.00000     195207.00000
# 38563SVGZN120ZI              nan              nan              nan
# 0073WLLDWSBARAM              nan              nan              nan
# 15025SSCLR400ST     133580.00000     142710.00000     569205.00000
#
#                        TOTAL1996  ...        TOTAL2009        TOTAL2010  \
# TRIFD                             ...
# TOTAL_RELEASE   2318409398.65000  ... 3038737468.64420 3401823195.53792
# 93562KRRMC13200     517953.00000  ...              nan              nan
# 77978LMNMCSTATE        961.00000  ...     104538.00000     178771.10000
# 76567LMNMCSANDO    1908875.00000  ...     180854.27000     264000.00000
# 70094MRCNC10800   28561121.00000  ...   14033632.00000   15611971.00000
# ...                          ...  ...              ...              ...
# 89015TTNMMPOBOX      53100.00000  ...       6315.00000       3657.00000
# 19706TXCDL2000W     162642.00000  ...    1596283.00000     432302.50000
# 38563SVGZN120ZI              nan  ...      68628.71000     130402.60000
# 0073WLLDWSBARAM              nan  ...              nan              nan
# 15025SSCLR400ST     450658.00000  ...    1567537.66000    3523913.85000
#
#                        TOTAL2011        TOTAL2012        TOTAL2013  \
# TRIFD
# TOTAL_RELEASE   3701652530.05003 3232491920.86028 3727353563.30422
# 93562KRRMC13200              nan              nan              nan
# 77978LMNMCSTATE     199796.00000     188280.10000     215479.80000
# 76567LMNMCSANDO     353000.00000     159422.00000     133398.00000
# 70094MRCNC10800   12514975.00000   13033799.00000    9981778.00000
# ...                          ...              ...              ...
# 89015TTNMMPOBOX       2572.00000       8126.00000       7797.00000
# 19706TXCDL2000W    1145901.70000    3689999.50000    3043548.10000
# 38563SVGZN120ZI     209584.00000    1628325.70000    1716833.55000
# 0073WLLDWSBARAM              nan              nan              nan
# 15025SSCLR400ST    3410850.09000    3222026.52000    1801747.30000
#
#                        TOTAL2014        TOTAL2015        TOTAL2016  \
# TRIFD
# TOTAL_RELEASE   3544714287.81079 2972866487.44393 3134064227.29282
# 93562KRRMC13200              nan              nan              nan
# 77978LMNMCSTATE     229453.30000     235630.60000      31152.40000
# 76567LMNMCSANDO      62416.00000              nan              nan
# 70094MRCNC10800   11626902.87000   12079217.00000   12144943.00000
# ...                          ...              ...              ...
# 89015TTNMMPOBOX      12651.00000       9600.00000    3216860.00000
# 19706TXCDL2000W    3157776.60000    3728165.76000    2698200.38000
# 38563SVGZN120ZI    2327303.72700    2804096.16000      86003.21000
# 0073WLLDWSBARAM     520700.00000     954568.00000     216040.00000
# 15025SSCLR400ST    3889668.64000    3179381.05000    2399799.22000
#
#                        TOTAL2017        TOTAL2018
# TRIFD
# TOTAL_RELEASE   3541607790.97415 3367991070.30157
# 93562KRRMC13200              nan              nan
# 77978LMNMCSTATE              nan              nan
# 76567LMNMCSANDO              nan              nan
# 70094MRCNC10800   11604350.00000   14758762.00000
# ...                          ...              ...
# 89015TTNMMPOBOX    4801870.00000    1891730.00000
# 19706TXCDL2000W    3995973.11600    5665306.55000
# 38563SVGZN120ZI    2849557.00000    4357062.23812
# 0073WLLDWSBARAM    3020524.00000    3990680.00000
# 15025SSCLR400ST    2983885.81000    3866865.38000
#
# [462 rows x 32 columns]

# %%
# merge topRows dataframe to reduced dataframe with one record per facility, with lat/long values
merged = all_tri.merge(topRows, on='TRIFD')
merged
# Out:
#                TRIFD                       FACILITY_NAME  \
# 0    0073WLLDWSBARAM               ALLIED WASTE OF PONCE
# 1    03570JMSRV650MA  FRASER N.H. LLC - BERLIN PULP MILL
# 2    04239NTRNTRILEY         PIXELLE SPECIALTY SOLUTIONS
# 3    04276BSCSCROUTE          ND PAPER INC - RUMFORD DIV
# 4    04694GRGPCMILLA                   WOODLAND PULP LLC
# ..               ...                                 ...
# 456  99707FRTKN1FORA                      FORT KNOX MINE
# 457  99737PGMNX38MIL                           POGO MINE
# 458  99752RDDGP90MIL                  RED DOG OPERATIONS
# 459  99801KNNCT13401        HECLA GREENS CREEK MINING CO
# 460  99901KTCHKMILE7                   KETCHIKAN PULP CO
#
#                               STREET_ADDRESS            CITY  \
# 0    BARAMAYA AVENUE - PR 500 - COTORRA WARD           PONCE
# 1                                650 MAIN ST          BERLIN
# 2           300 RILEY RD - ANDROSCOGGIN MILL             JAY
# 3                             35 HARTFORD ST         RUMFORD
# 4                                144 MAIN ST     BAILEYVILLE
# ..                                       ...             ...
# 456                           1 FORT KNOX RD       FAIRBANKS
# 457            38 MILES NE OF DELTA JUNCTION  DELTA JUNCTION
# 458                   90 MILES N OF KOTZEBUE        KOTZEBUE
# 459                        13401 GLACIER HWY          JUNEAU
# 460                       7559 N TONGASS HWY       KETCHIKAN
#
#                            COUNTY  ST    ZIP BIA TRIBE  LATITUDE  ...  \
# 0                 PONCE MUNICIPIO  PR    732            18.00226  ...
# 1                            COOS  NH   3570            44.47194  ...
# 2                        FRANKLIN  ME   4239            44.50633  ...
# 3                          OXFORD  ME   4276            44.55080  ...
# 4                      WASHINGTON  ME   4694            45.15689  ...
# ..                            ...  ..    ...  ..   ...       ...  ...
# 456  FAIRBANKS NORTH STAR BOROUGH  AK  99712            64.99953  ...
# 457  FAIRBANKS NORTH STAR BOROUGH  AK  99737            64.44972  ...
# 458      NORTHWEST ARCTIC BOROUGH  AK  99752            68.06151  ...
# 459                JUNEAU BOROUGH  AK  99801            58.08180  ...
# 460     KETCHIKAN GATEWAY BOROUGH  AK  99901            55.40838  ...
#
#           TOTAL2009       TOTAL2010       TOTAL2011       TOTAL2012  \
# 0               nan             nan             nan             nan
# 1               nan             nan             nan             nan
# 2     1798082.10000   1898321.30000   2114151.09000   1616165.37000
# 3      450201.80000    578810.30000    418143.86000    422078.45000
# 4      701134.71520    796244.08590    780170.44930   1138512.10840
# ..              ...             ...             ...             ...
# 456   3995500.50651   2443891.65163   2611142.20000   2278446.20000
# 457   9546678.00000   7770795.60000   8402917.40000   9442627.70000
# 458 637521196.30000 777395652.60300 989392511.30300 814003310.83000
# 459  47242868.62000  47185465.74000  47043841.64000  48754931.74000
# 460             nan             nan             nan             nan
#
#           TOTAL2013        TOTAL2014       TOTAL2015       TOTAL2016  \
# 0               nan     520700.00000    954568.00000    216040.00000
# 1               nan              nan             nan             nan
# 2     1887060.64000    1396386.86000   1083316.18000    768153.61000
# 3      433966.31400     423637.04500    402934.33900    406028.30000
# 4     1177567.17000    1116741.02000   1195719.24000   1178097.64500
# ..              ...              ...             ...             ...
# 456   2724241.00000    2468292.90000  19600834.70000  23292802.60000
# 457   7719192.80000   12062935.10000   8638067.40000   9281139.20000
# 458 906385793.10200 1124384868.58200 561222144.59200 776973928.58100
# 459  50615872.74000   41557030.50000  29951062.50000  41780361.00000
# 460             nan              nan             nan             nan
#
#            TOTAL2017       TOTAL2018
# 0      3020524.00000   3990680.00000
# 1                nan             nan
# 2      3061296.84000   3007123.32000
# 3       518495.59200    489577.92900
# 4      1270418.46500   1086406.59300
# ..               ...             ...
# 456   20823727.50000  19530448.10000
# 457    9205581.50000   7922913.80000
# 458 1082414482.97500 885682874.24200
# 459   58696349.90000  55589597.00000
# 460              nan             nan
#
# [461 rows x 45 columns]

# %%
# cast lat/long columns to float
merged['LATITUDE'] = merged['LATITUDE'].astype(float)
merged['LONGITUDE'] = merged['LONGITUDE'].astype(float)

# create geodataframe using Latitude and Longitude columns
gdf = gpd.GeoDataFrame(merged, geometry=gpd.points_from_xy(merged.LONGITUDE, merged.LATITUDE))

# define crs for geodataframe
gdf.crs = {'init' :'epsg:4326'}

gdf.head()
# Out:
#              TRIFD                       FACILITY_NAME  \
# 0  0073WLLDWSBARAM               ALLIED WASTE OF PONCE
# 1  03570JMSRV650MA  FRASER N.H. LLC - BERLIN PULP MILL
# 2  04239NTRNTRILEY         PIXELLE SPECIALTY SOLUTIONS
# 3  04276BSCSCROUTE          ND PAPER INC - RUMFORD DIV
# 4  04694GRGPCMILLA                   WOODLAND PULP LLC
#
#                             STREET_ADDRESS         CITY           COUNTY  ST  \
# 0  BARAMAYA AVENUE - PR 500 - COTORRA WARD        PONCE  PONCE MUNICIPIO  PR
# 1                              650 MAIN ST       BERLIN             COOS  NH
# 2         300 RILEY RD - ANDROSCOGGIN MILL          JAY         FRANKLIN  ME
# 3                           35 HARTFORD ST      RUMFORD           OXFORD  ME
# 4                              144 MAIN ST  BAILEYVILLE       WASHINGTON  ME
#
#     ZIP BIA TRIBE  LATITUDE  ...     TOTAL2010     TOTAL2011     TOTAL2012  \
# 0   732            18.00226  ...           nan           nan           nan
# 1  3570            44.47194  ...           nan           nan           nan
# 2  4239            44.50633  ... 1898321.30000 2114151.09000 1616165.37000
# 3  4276            44.55080  ...  578810.30000  418143.86000  422078.45000
# 4  4694            45.15689  ...  796244.08590  780170.44930 1138512.10840
#
#       TOTAL2013     TOTAL2014     TOTAL2015     TOTAL2016     TOTAL2017  \
# 0           nan  520700.00000  954568.00000  216040.00000 3020524.00000
# 1           nan           nan           nan           nan           nan
# 2 1887060.64000 1396386.86000 1083316.18000  768153.61000 3061296.84000
# 3  433966.31400  423637.04500  402934.33900  406028.30000  518495.59200
# 4 1177567.17000 1116741.02000 1195719.24000 1178097.64500 1270418.46500
#
#       TOTAL2018                    geometry
# 0 3990680.00000  POINT (-66.64132 18.00226)
# 1           nan  POINT (-71.16944 44.47194)
# 2 3007123.32000  POINT (-70.23861 44.50633)
# 3  489577.92900  POINT (-70.54110 44.55080)
# 4 1086406.59300  POINT (-67.40201 45.15689)
#
# [5 rows x 46 columns]

# %%
# export geodataframe to geojson
gdf.to_file("../data/top-tri-releases.geojson", driver='GeoJSON', encoding='utf-8')

# %%
# load RSEI scores
scores = pd.read_excel('../data/all-rsei.xlsx')
scores
# Out:
#         SubmissionYear       FacilityID  RSEI Modeled Pounds  \
# 0                 2007  0071WPNCCN619AV              0.00000
# 1                 2007  0106WCNNLL25TEX              0.00000
# 2                 2007  0150WCNSLD17SAI              0.00000
# 3                 2007  0150WKRLST91CAR             29.79996
# 4                 2007  0152WCMRNX1537G              0.00000
# ...                ...              ...                  ...
# 266097            2018  99801KNNCT13401          18646.00000
# 266098            2018  99901SCSTG1300S              0.80000
# 266099            2018  155524GYSN23IND            750.00000
# 266100            2018  275593MCPT4191H            148.70000
# 266101            2018  688181FBRG1318W          17128.10000
#
#         RSEI Modeled Hazard  RSEI Score
# 0                   0.00000     0.00000
# 1                   0.00000     0.00000
# 2                   0.00000     0.00000
# 3              536400.20000    62.10780
# 4                   0.00000     0.00000
# ...                     ...         ...
# 266097     3599499777.10000   779.09962
# 266098          18400.00000     0.51736
# 266099    10965000000.00000 46982.70000
# 266100         208700.00000     3.75601
# 266101          59948.50000     0.22939
#
# [266102 rows x 5 columns]

# %%
scores = scores.rename(columns={'SubmissionYear':'YEAR','FacilityID': 'TRIFD','RSEI Modeled Pounds':'MODEL_LBS','RSEI Modeled Hazard':'MODEL_HAZARD','RSEI Score':'SCORE'})
scores
# Out:
#         YEAR            TRIFD   MODEL_LBS      MODEL_HAZARD       SCORE
# 0       2007  0071WPNCCN619AV     0.00000           0.00000     0.00000
# 1       2007  0106WCNNLL25TEX     0.00000           0.00000     0.00000
# 2       2007  0150WCNSLD17SAI     0.00000           0.00000     0.00000
# 3       2007  0150WKRLST91CAR    29.79996      536400.20000    62.10780
# 4       2007  0152WCMRNX1537G     0.00000           0.00000     0.00000
# ...      ...              ...         ...               ...         ...
# 266097  2018  99801KNNCT13401 18646.00000  3599499777.10000   779.09962
# 266098  2018  99901SCSTG1300S     0.80000       18400.00000     0.51736
# 266099  2018  155524GYSN23IND   750.00000 10965000000.00000 46982.70000
# 266100  2018  275593MCPT4191H   148.70000      208700.00000     3.75601
# 266101  2018  688181FBRG1318W 17128.10000       59948.50000     0.22939
#
# [266102 rows x 5 columns]

# %%
# create pivot table summing totals to create records per facility per year, with total releases
scoresPivot = pd.pivot_table(scores,index=['YEAR', 'TRIFD'], values=['MODEL_LBS','MODEL_HAZARD','SCORE'],aggfunc=np.sum)
scoresPivot
# Out:
#                           MODEL_HAZARD    MODEL_LBS         SCORE
# YEAR TRIFD
# 2007 00602SMRTMRD115      115000.00000      5.00000       4.07923
#      00603HWLTTSTATE           0.00000     78.00000       0.00000
#      00603SYMMTLAMNT           0.00000      0.00000       0.00000
#      00608DCRBNRD3KM        2625.00000    750.00000       0.17256
#      00610BXTRHROAD4 11000000000.00000   1000.00000 2018063.00000
# ...                                ...          ...           ...
# 2018 9974WSBLLC1RIVE       94356.60000     11.58000       0.00506
#      99752RDDGP90MIL  3518393675.55500 219298.24383    2172.04828
#      99801CRLSK331CL     4220502.81000 292294.00000       0.05632
#      99801KNNCT13401  3599499777.10000  18646.00000     779.09962
#      99901SCSTG1300S       18400.00000      0.80000       0.51736
#
# [266102 rows x 3 columns]

# %%
# unstack pivot table to create columns for release type for each year
scoresUnstacked = scoresPivot.unstack(level=0)
scoresUnstacked
# Out:
#                     MODEL_HAZARD                                    \
# YEAR                        2007             2008             2009
# TRIFD
# 00602SMRTMRD115     115000.00000      46000.00000     161000.00000
# 00603HWLTTSTATE          0.00000          0.00000    3511990.00000
# 00603SYMMTLAMNT          0.00000          0.00000              nan
# 00608DCRBNRD3KM       2625.00000      55411.10000      43987.50000
# 0060WHPNTRCARR1              nan              nan              nan
# ...                          ...              ...              ...
# 99801KNNCT13401 7223744936.00000 7223598369.00000 7221730839.00000
# 9982WGLCRBPBX14              nan              nan              nan
# 99901LSKSH381TN              nan              nan              nan
# 99901SCSTG1300S          0.00000          0.00000          0.00000
# 99929TRDNT641SH              nan              nan          0.00000
#
#                                                                     \
# YEAR                        2010             2011             2012
# TRIFD
# 00602SMRTMRD115     161000.00000              nan              nan
# 00603HWLTTSTATE     927190.00000    1194610.00000     879255.00000
# 00603SYMMTLAMNT          0.00000              nan              nan
# 00608DCRBNRD3KM      44078.50000      46360.50000      49958.50000
# 0060WHPNTRCARR1              nan              nan              nan
# ...                          ...              ...              ...
# 99801KNNCT13401 7521905809.00000 7522176340.00000 7523344007.00000
# 9982WGLCRBPBX14              nan              nan          0.00000
# 99901LSKSH381TN              nan     327670.00000      53690.00000
# 99901SCSTG1300S          0.00000          0.00000          0.00000
# 99929TRDNT641SH              nan              nan              nan
#
#                                                                     \
# YEAR                        2013             2014             2015
# TRIFD
# 00602SMRTMRD115              nan              nan              nan
# 00603HWLTTSTATE    1244880.00000     192880.00000       2300.00000
# 00603SYMMTLAMNT              nan              nan              nan
# 00608DCRBNRD3KM      56703.00000      53546.00000      54428.00000
# 0060WHPNTRCARR1              nan              nan      98280.00000
# ...                          ...              ...              ...
# 99801KNNCT13401 7674883606.00000 3660391250.50000 3665556534.60000
# 9982WGLCRBPBX14          0.00000          0.00000          0.00000
# 99901LSKSH381TN              nan     281516.00000              nan
# 99901SCSTG1300S      11343.60000       6743.60000       2419.60000
# 99929TRDNT641SH              nan              nan              nan
#
#                                   ...      SCORE                        \
# YEAR                        2016  ...       2009       2010       2011
# TRIFD                             ...
# 00602SMRTMRD115              nan  ...   24.12741   23.61643        nan
# 00603HWLTTSTATE       4600.00000  ...  113.23530   36.96524   33.77863
# 00603SYMMTLAMNT              nan  ...        nan    0.00000        nan
# 00608DCRBNRD3KM      51726.00000  ...    1.79884    1.81474    1.92370
# 0060WHPNTRCARR1      63540.00000  ...        nan        nan        nan
# ...                          ...  ...        ...        ...        ...
# 99801KNNCT13401 2437083706.10000  ... 1576.32292 1636.10736 1632.72914
# 9982WGLCRBPBX14              nan  ...        nan        nan        nan
# 99901LSKSH381TN              nan  ...        nan        nan   10.36650
# 99901SCSTG1300S       3247.60000  ...    0.00000    0.00000    0.00000
# 99929TRDNT641SH              nan  ...    0.00000        nan        nan
#
#                                                                                \
# YEAR                  2012       2013      2014      2015      2016      2017
# TRIFD
# 00602SMRTMRD115        nan        nan       nan       nan       nan       nan
# 00603HWLTTSTATE   26.35994   33.97479   8.37460   0.06183   0.12144       nan
# 00603SYMMTLAMNT        nan        nan       nan       nan       nan       nan
# 00608DCRBNRD3KM    2.09458    2.39524   2.27793   2.33606   2.24153   2.10507
# 0060WHPNTRCARR1        nan        nan       nan   5.58495   3.05970   1.81010
# ...                    ...        ...       ...       ...       ...       ...
# 99801KNNCT13401 1630.07289 1660.46230 788.74866 790.08475 526.19206 698.74436
# 9982WGLCRBPBX14    0.00000    0.00000   0.00000   0.00000       nan       nan
# 99901LSKSH381TN    1.69391        nan   0.39908       nan       nan       nan
# 99901SCSTG1300S    0.00000    0.32276   0.19133   0.06846   0.09167   0.07391
# 99929TRDNT641SH        nan        nan       nan       nan       nan       nan
#
#
# YEAR                 2018
# TRIFD
# 00602SMRTMRD115       nan
# 00603HWLTTSTATE       nan
# 00603SYMMTLAMNT       nan
# 00608DCRBNRD3KM   2.03719
# 0060WHPNTRCARR1   1.76193
# ...                   ...
# 99801KNNCT13401 779.09962
# 9982WGLCRBPBX14       nan
# 99901LSKSH381TN       nan
# 99901SCSTG1300S   0.51736
# 99929TRDNT641SH       nan
#
# [32908 rows x 36 columns]

# %%
# rename columns to reflect year and release type
scoresUnstacked.columns = [''.join(str(s).strip() for s in col if s) for col in scoresUnstacked.columns]
scoresUnstacked
# Out:
#                  MODEL_HAZARD2007  MODEL_HAZARD2008  MODEL_HAZARD2009  \
# TRIFD
# 00602SMRTMRD115      115000.00000       46000.00000      161000.00000
# 00603HWLTTSTATE           0.00000           0.00000     3511990.00000
# 00603SYMMTLAMNT           0.00000           0.00000               nan
# 00608DCRBNRD3KM        2625.00000       55411.10000       43987.50000
# 0060WHPNTRCARR1               nan               nan               nan
# ...                           ...               ...               ...
# 99801KNNCT13401  7223744936.00000  7223598369.00000  7221730839.00000
# 9982WGLCRBPBX14               nan               nan               nan
# 99901LSKSH381TN               nan               nan               nan
# 99901SCSTG1300S           0.00000           0.00000           0.00000
# 99929TRDNT641SH               nan               nan           0.00000
#
#                  MODEL_HAZARD2010  MODEL_HAZARD2011  MODEL_HAZARD2012  \
# TRIFD
# 00602SMRTMRD115      161000.00000               nan               nan
# 00603HWLTTSTATE      927190.00000     1194610.00000      879255.00000
# 00603SYMMTLAMNT           0.00000               nan               nan
# 00608DCRBNRD3KM       44078.50000       46360.50000       49958.50000
# 0060WHPNTRCARR1               nan               nan               nan
# ...                           ...               ...               ...
# 99801KNNCT13401  7521905809.00000  7522176340.00000  7523344007.00000
# 9982WGLCRBPBX14               nan               nan           0.00000
# 99901LSKSH381TN               nan      327670.00000       53690.00000
# 99901SCSTG1300S           0.00000           0.00000           0.00000
# 99929TRDNT641SH               nan               nan               nan
#
#                  MODEL_HAZARD2013  MODEL_HAZARD2014  MODEL_HAZARD2015  \
# TRIFD
# 00602SMRTMRD115               nan               nan               nan
# 00603HWLTTSTATE     1244880.00000      192880.00000        2300.00000
# 00603SYMMTLAMNT               nan               nan               nan
# 00608DCRBNRD3KM       56703.00000       53546.00000       54428.00000
# 0060WHPNTRCARR1               nan               nan       98280.00000
# ...                           ...               ...               ...
# 99801KNNCT13401  7674883606.00000  3660391250.50000  3665556534.60000
# 9982WGLCRBPBX14           0.00000           0.00000           0.00000
# 99901LSKSH381TN               nan      281516.00000               nan
# 99901SCSTG1300S       11343.60000        6743.60000        2419.60000
# 99929TRDNT641SH               nan               nan               nan
#
#                  MODEL_HAZARD2016  ...  SCORE2009  SCORE2010  SCORE2011  \
# TRIFD                              ...
# 00602SMRTMRD115               nan  ...   24.12741   23.61643        nan
# 00603HWLTTSTATE        4600.00000  ...  113.23530   36.96524   33.77863
# 00603SYMMTLAMNT               nan  ...        nan    0.00000        nan
# 00608DCRBNRD3KM       51726.00000  ...    1.79884    1.81474    1.92370
# 0060WHPNTRCARR1       63540.00000  ...        nan        nan        nan
# ...                           ...  ...        ...        ...        ...
# 99801KNNCT13401  2437083706.10000  ... 1576.32292 1636.10736 1632.72914
# 9982WGLCRBPBX14               nan  ...        nan        nan        nan
# 99901LSKSH381TN               nan  ...        nan        nan   10.36650
# 99901SCSTG1300S        3247.60000  ...    0.00000    0.00000    0.00000
# 99929TRDNT641SH               nan  ...    0.00000        nan        nan
#
#                  SCORE2012  SCORE2013  SCORE2014  SCORE2015  SCORE2016  \
# TRIFD
# 00602SMRTMRD115        nan        nan        nan        nan        nan
# 00603HWLTTSTATE   26.35994   33.97479    8.37460    0.06183    0.12144
# 00603SYMMTLAMNT        nan        nan        nan        nan        nan
# 00608DCRBNRD3KM    2.09458    2.39524    2.27793    2.33606    2.24153
# 0060WHPNTRCARR1        nan        nan        nan    5.58495    3.05970
# ...                    ...        ...        ...        ...        ...
# 99801KNNCT13401 1630.07289 1660.46230  788.74866  790.08475  526.19206
# 9982WGLCRBPBX14    0.00000    0.00000    0.00000    0.00000        nan
# 99901LSKSH381TN    1.69391        nan    0.39908        nan        nan
# 99901SCSTG1300S    0.00000    0.32276    0.19133    0.06846    0.09167
# 99929TRDNT641SH        nan        nan        nan        nan        nan
#
#                  SCORE2017  SCORE2018
# TRIFD
# 00602SMRTMRD115        nan        nan
# 00603HWLTTSTATE        nan        nan
# 00603SYMMTLAMNT        nan        nan
# 00608DCRBNRD3KM    2.10507    2.03719
# 0060WHPNTRCARR1    1.81010    1.76193
# ...                    ...        ...
# 99801KNNCT13401  698.74436  779.09962
# 9982WGLCRBPBX14        nan        nan
# 99901LSKSH381TN        nan        nan
# 99901SCSTG1300S    0.07391    0.51736
# 99929TRDNT641SH        nan        nan
#
# [32908 rows x 36 columns]

# %%
# # merge amounts and scores, by TRIFD
# amountsUnstacked = amountsUnstacked.merge(scoresUnstacked, on='TRIFD',)
# amountsUnstacked

# %%
# now find top values for each column
# declare empty dataframe to hold top ordered rows
topRows = pd.DataFrame()

# create list of column names
columns = list(scoresUnstacked.columns)

# loop through each column
# finding the 100 largest values in each
# and appending to empty topRows dataframe
for column in columns:
    topValues = scoresUnstacked.nlargest(25, column)
    topRows = topRows.append(topValues)

    
topRows
# Out:
#                    MODEL_HAZARD2007    MODEL_HAZARD2008    MODEL_HAZARD2009  \
# TRIFD
# 65704MNSSTHWYAX 4865485302531.59961 2411174770000.00000      24775800.00000
# 65746STLPRSTEEL 4645690980000.00000     122114100.00000      58944000.00000
# 27263RYLDV325KE 3040057865020.00000 3383242775240.00000             0.00000
# 77507HCHST9502B 2255236358380.63916 1954471840428.12305 2105096365491.16406
# 40216DDLSV4242C  567235632382.14600   82757546903.50389                 nan
# ...                             ...                 ...                 ...
# 90248NCMTL417WE                 nan                 nan                 nan
# 23231STRLZ5674E                 nan                 nan                 nan
# 77545CHMPN3130H    2814887878.96000   47808820049.74000    8385175926.31240
# 72032KRKWD670EQ        648000.00000                 nan       2693980.00000
# 18018BRRNM824TW   19624001056.49951   20603000000.00000   98560000000.00000
#
#                    MODEL_HAZARD2010    MODEL_HAZARD2011  MODEL_HAZARD2012  \
# TRIFD
# 65704MNSSTHWYAX      86119420.20000      16885200.00000 72662243080.00000
# 65746STLPRSTEEL      92928000.00000     214680000.00000     1752000.00000
# 27263RYLDV325KE             0.00000                 nan               nan
# 77507HCHST9502B 2418763223862.15381 1706315519667.36011 92564760369.27101
# 40216DDLSV4242C                 nan                 nan               nan
# ...                             ...                 ...               ...
# 90248NCMTL417WE                 nan                 nan               nan
# 23231STRLZ5674E                 nan                 nan               nan
# 77545CHMPN3130H    5566576127.45200    2407937770.46000  1306428309.91353
# 72032KRKWD670EQ                 nan             0.00000           0.00000
# 18018BRRNM824TW   22286000000.00000   54120000000.00000 54780000000.00000
#
#                  MODEL_HAZARD2013    MODEL_HAZARD2014  MODEL_HAZARD2015  \
# TRIFD
# 65704MNSSTHWYAX    21471240.00000       7506060.00000    11765980.00000
# 65746STLPRSTEEL     1536000.00000       1856400.00000     7119360.00000
# 27263RYLDV325KE               nan                 nan               nan
# 77507HCHST9502B 79490864711.93098 1407874857634.17407 86950515300.13263
# 40216DDLSV4242C               nan                 nan               nan
# ...                           ...                 ...               ...
# 90248NCMTL417WE               nan                 nan               nan
# 23231STRLZ5674E               nan   90728000000.00000 79134000000.00000
# 77545CHMPN3130H  1587930924.75200     397842095.92633    17543033.56060
# 72032KRKWD670EQ           0.00000             0.00000     3867800.00000
# 18018BRRNM824TW 53680000000.00000   75680000000.00000 83600000000.00000
#
#                   MODEL_HAZARD2016  ...      SCORE2009      SCORE2010  \
# TRIFD                               ...
# 65704MNSSTHWYAX   3548697943.00000  ...      144.14422      350.98860
# 65746STLPRSTEEL      7830313.00000  ...      221.88482      352.98599
# 27263RYLDV325KE                nan  ...        0.00000        0.00000
# 77507HCHST9502B 386477071288.75891  ... 13695517.96758 15389441.02056
# 40216DDLSV4242C                nan  ...            nan            nan
# ...                            ...  ...            ...            ...
# 90248NCMTL417WE                nan  ...            nan            nan
# 23231STRLZ5674E  85547000000.00000  ...            nan            nan
# 77545CHMPN3130H   3445002861.96000  ...  1765116.62601  1432918.54424
# 72032KRKWD670EQ      6339900.00000  ...      174.02488            nan
# 18018BRRNM824TW  70028200000.00000  ...  5131210.00000  1169140.00000
#
#                      SCORE2011      SCORE2012     SCORE2013      SCORE2014  \
# TRIFD
# 65704MNSSTHWYAX       65.46088   279476.34137     115.12757       69.17252
# 65746STLPRSTEEL      819.68715        6.89668       6.05382        7.60944
# 27263RYLDV325KE            nan            nan           nan            nan
# 77507HCHST9502B 12483090.21320 10328717.56011 9500398.18205 20728213.71492
# 40216DDLSV4242C            nan            nan           nan            nan
# ...                        ...            ...           ...            ...
# 90248NCMTL417WE            nan            nan           nan            nan
# 23231STRLZ5674E            nan            nan           nan  7385530.00000
# 77545CHMPN3130H   662839.72721   365662.35459  399680.07633   113200.49034
# 72032KRKWD670EQ        0.00000        0.00000       0.00000        0.00000
# 18018BRRNM824TW  2861080.00000  2918560.00000 2882630.00000  4097010.00000
#
#                      SCORE2015      SCORE2016      SCORE2017     SCORE2018
# TRIFD
# 65704MNSSTHWYAX      217.60205    14247.79543       49.29491      63.02393
# 65746STLPRSTEEL       29.43378       32.08000        5.28936       4.25826
# 27263RYLDV325KE            nan            nan            nan           nan
# 77507HCHST9502B 10794495.68243 13930121.30488 10585289.44109 6086036.46651
# 40216DDLSV4242C            nan            nan            nan           nan
# ...                        ...            ...            ...           ...
# 90248NCMTL417WE            nan            nan  3456180.00000 3454770.00000
# 23231STRLZ5674E  6513360.00000  7119780.00000  7173770.00000 3273930.00000
# 77545CHMPN3130H     4972.86686  1046188.16252   150432.49884 3260765.87813
# 72032KRKWD670EQ      179.82202      301.36254        4.24130 2983905.68540
# 18018BRRNM824TW  4563180.00000  3854750.00000  3603360.00000 2873530.00000
#
# [900 rows x 36 columns]

# %%
topRows = topRows.drop_duplicates()
topRows
# Out:
#                    MODEL_HAZARD2007    MODEL_HAZARD2008    MODEL_HAZARD2009  \
# TRIFD
# 65704MNSSTHWYAX 4865485302531.59961 2411174770000.00000      24775800.00000
# 65746STLPRSTEEL 4645690980000.00000     122114100.00000      58944000.00000
# 27263RYLDV325KE 3040057865020.00000 3383242775240.00000             0.00000
# 77507HCHST9502B 2255236358380.63916 1954471840428.12305 2105096365491.16406
# 40216DDLSV4242C  567235632382.14600   82757546903.50389                 nan
# ...                             ...                 ...                 ...
# 25112NNCRBRTE25   45100825710.28000   39810333313.40000   66451416751.52000
# 77205SMTHN16740     202800000.00000     202800000.00000     202800000.00000
# 44035NGLHR120PI   14402638865.40196   14401732210.40982   14402677984.39582
# 4503WFCNLL346GR                 nan                 nan                 nan
# 72032KRKWD670EQ        648000.00000                 nan       2693980.00000
#
#                    MODEL_HAZARD2010    MODEL_HAZARD2011  MODEL_HAZARD2012  \
# TRIFD
# 65704MNSSTHWYAX      86119420.20000      16885200.00000 72662243080.00000
# 65746STLPRSTEEL      92928000.00000     214680000.00000     1752000.00000
# 27263RYLDV325KE             0.00000                 nan               nan
# 77507HCHST9502B 2418763223862.15381 1706315519667.36011 92564760369.27101
# 40216DDLSV4242C                 nan                 nan               nan
# ...                             ...                 ...               ...
# 25112NNCRBRTE25   61908417855.58001   44946550154.61466 36444234497.10001
# 77205SMTHN16740    3738249000.00000    6053391000.00000  5750514000.00000
# 44035NGLHR120PI   14403150201.16442    5899662729.06162  6057749069.05000
# 4503WFCNLL346GR                 nan                 nan               nan
# 72032KRKWD670EQ                 nan             0.00000           0.00000
#
#                  MODEL_HAZARD2013    MODEL_HAZARD2014  MODEL_HAZARD2015  \
# TRIFD
# 65704MNSSTHWYAX    21471240.00000       7506060.00000    11765980.00000
# 65746STLPRSTEEL     1536000.00000       1856400.00000     7119360.00000
# 27263RYLDV325KE               nan                 nan               nan
# 77507HCHST9502B 79490864711.93098 1407874857634.17407 86950515300.13263
# 40216DDLSV4242C               nan                 nan               nan
# ...                           ...                 ...               ...
# 25112NNCRBRTE25 72183269734.86000   63966134578.16000 67728109614.04000
# 77205SMTHN16740  4269228000.00000    4325374000.00000  4335240000.00000
# 44035NGLHR120PI 11722372092.94220    2939631058.77136  4897596379.09032
# 4503WFCNLL346GR               nan                 nan               nan
# 72032KRKWD670EQ           0.00000             0.00000     3867800.00000
#
#                   MODEL_HAZARD2016  ...      SCORE2009      SCORE2010  \
# TRIFD                               ...
# 65704MNSSTHWYAX   3548697943.00000  ...      144.14422      350.98860
# 65746STLPRSTEEL      7830313.00000  ...      221.88482      352.98599
# 27263RYLDV325KE                nan  ...        0.00000        0.00000
# 77507HCHST9502B 386477071288.75891  ... 13695517.96758 15389441.02056
# 40216DDLSV4242C                nan  ...            nan            nan
# ...                            ...  ...            ...            ...
# 25112NNCRBRTE25  52199127617.34000  ...  2805162.83276  2251220.53756
# 77205SMTHN16740                nan  ...    45657.67000   882419.40000
# 44035NGLHR120PI   2166170571.60522  ...  1342339.50786  1337221.51577
# 4503WFCNLL346GR                nan  ...            nan            nan
# 72032KRKWD670EQ      6339900.00000  ...      174.02488            nan
#
#                      SCORE2011      SCORE2012     SCORE2013      SCORE2014  \
# TRIFD
# 65704MNSSTHWYAX       65.46088   279476.34137     115.12757       69.17252
# 65746STLPRSTEEL      819.68715        6.89668       6.05382        7.60944
# 27263RYLDV325KE            nan            nan           nan            nan
# 77507HCHST9502B 12483090.21320 10328717.56011 9500398.18205 20728213.71492
# 40216DDLSV4242C            nan            nan           nan            nan
# ...                        ...            ...           ...            ...
# 25112NNCRBRTE25  1183632.18060   761567.45406 3000570.78465  2548972.65795
# 77205SMTHN16740  1467106.00000  1430150.70000 1088890.30000  1130844.90000
# 44035NGLHR120PI   543747.00890   556210.50839 1010977.04315   240696.68519
# 4503WFCNLL346GR            nan            nan           nan            nan
# 72032KRKWD670EQ        0.00000        0.00000       0.00000        0.00000
#
#                      SCORE2015      SCORE2016      SCORE2017     SCORE2018
# TRIFD
# 65704MNSSTHWYAX      217.60205    14247.79543       49.29491      63.02393
# 65746STLPRSTEEL       29.43378       32.08000        5.28936       4.25826
# 27263RYLDV325KE            nan            nan            nan           nan
# 77507HCHST9502B 10794495.68243 13930121.30488 10585289.44109 6086036.46651
# 40216DDLSV4242C            nan            nan            nan           nan
# ...                        ...            ...            ...           ...
# 25112NNCRBRTE25  2877263.46568  2404096.23304  2544750.42711 2282336.73052
# 77205SMTHN16740  1161263.00000            nan            nan 7468108.00000
# 44035NGLHR120PI   417024.92123   177055.43162   288096.72446 5198391.92029
# 4503WFCNLL346GR            nan            nan            nan 4296230.51981
# 72032KRKWD670EQ      179.82202      301.36254        4.24130 2983905.68540
#
# [197 rows x 36 columns]

# %%
# # now reduce filtered dataframe to find one record per facility
# # use group by TRIFID field, and only keep the identifying fields about each facility
# all_tri = tri_filter.fillna('').groupby('TRIFD').agg({'FACILITY_NAME':'first',
#                              'STREET_ADDRESS':'first',
#                              'CITY':'first',
#                              'COUNTY':'first',
#                              'ST':'first',
#                              'ZIP':'first',
#                              'BIA':'first',
#                              'TRIBE':'first',
#                              'LATITUDE':'first',
#                              'LONGITUDE':'first',
#                              'INDUSTRY_SECTOR':'first',
#                              'PARENT_CO_NAME': 'first'
#                                                }).reset_index()

# all_tri

# %%
# merge topRows dataframe to reduced dataframe with one record per facility, with lat/long values
merged = all_tri.merge(topRows, on='TRIFD')
merged
# Out:
#                TRIFD                                      FACILITY_NAME  \
# 0    00610BXTRHROAD4               EDWARDS LIFESCIENCES TECHNOLOGY SARL
# 1    01151MNSNT730WO                                        SOLUTIA INC
# 2    06383FDRLPINLAN                FUSION PAPERBOARD - CONNECTICUT LLC
# 3    07080MTZMT3900S                       AMES ADVANCED MATERIALS CORP
# 4    07524CRDNL50561                                 CARDINAL COLOR INC
# ..               ...                                                ...
# 192  9453WSLYND477KA                              SOLARCITY- SILEVO CTC
# 193  97015SMLLS13340  PCC STRUCTURALS INC SMALL STRUCTURALS BUSINESS...
# 194  97206LRGST4600S             PCC STRUCTURALS INC LARGE PARTS CAMPUS
# 195  97220BNGFP19000                              BOEING CO OF PORTLAND
# 196  98134BLLNC5801E                                   ARDAGH GLASS INC
#
#                                         STREET_ADDRESS              CITY  \
# 0    STATE RD 402 KM 1.4 N LAS MARIAS IND US TRIAL ...            ANASCO
# 1                                     730 WORCESTER ST       SPRINGFIELD
# 2                                        130 INLAND RD        VERSAILLES
# 3                                   3900 S CLINTON AVE  SOUTH PLAINFIELD
# 4                                        50-56 1ST AVE          PATERSON
# ..                                                 ...               ...
# 192                                    47700 KATO ROAD           FREMONT
# 193                                  13340 SE 84TH AVE         CLACKAMAS
# 194                                  4600 SE HARNEY DR          PORTLAND
# 195                                19000 NE SANDY BLVD          PORTLAND
# 196                              5801 E MARGINAL WAY S           SEATTLE
#
#                COUNTY  ST        ZIP BIA TRIBE  LATITUDE  ...     SCORE2009  \
# 0    ANASCO MUNICIPIO  PR        610            18.29390  ... 1994720.00000
# 1             HAMPDEN  MA       1151            42.15498  ...    2066.02561
# 2          NEW LONDON  CT       6383            41.62371  ...       0.00000
# 3           MIDDLESEX  NJ       7080            40.56461  ...  590942.90672
# 4             PASSAIC  NJ       7524            40.94033  ...       0.00000
# ..                ...  ..        ...  ..   ...       ...  ...           ...
# 192           ALAMEDA  CA  945387307            37.46927  ...           nan
# 193         CLACKAMAS  OR      97015            45.42578  ... 5858851.15149
# 194         MULTNOMAH  OR      97206            45.46130  ... 9982351.61660
# 195         MULTNOMAH  OR      97230            45.54385  ...   35444.16726
# 196              KING  WA      98134            47.55177  ... 1386217.70000
#
#         SCORE2010     SCORE2011     SCORE2012     SCORE2013     SCORE2014  \
# 0   1983053.00000 1971439.00000 2318757.30000 2579384.00000 2825327.00000
# 1      4600.43524    5275.97550    5178.29442    7404.05958   20519.58557
# 2         0.00000       0.00000       0.00000 1042687.22673 1049377.71344
# 3   2444261.67552  713384.65160  200326.28348   79885.60989  148097.92734
# 4         0.00000       0.00000       0.00000           nan           nan
# ..            ...           ...           ...           ...           ...
# 192  851098.00000           nan           nan           nan           nan
# 193   98635.29384  100076.77533   95401.18236  162857.18657  117824.88851
# 194  226043.61263  265963.35368  276260.26285  303082.36639  184658.30360
# 195   47877.80802  101709.22820  157336.56945   90141.55673  101948.89736
# 196 1397690.60000 3660563.22000 1421858.15000 1434105.31000 1755528.90362
#
#         SCORE2015     SCORE2016      SCORE2017      SCORE2018
# 0   2999252.00000 6185696.00000   938779.00000   901403.70000
# 1     22642.33037   21925.85518    21709.77031    22334.36070
# 2             nan           nan            nan            nan
# 3     31458.78769   51581.74653    51872.61882   133989.86931
# 4             nan           nan            nan            nan
# ..            ...           ...            ...            ...
# 192       0.58710           nan            nan            nan
# 193  120010.30345  107022.43776    90751.06355    79885.79854
# 194  180601.85074   93670.65909    64886.79497    36916.78475
# 195  574793.29243 6982511.19271 19846568.83484 20009309.06369
# 196 1735132.06787 1784291.98432   931251.99980   886219.64534
#
# [197 rows x 49 columns]

# %%
# cast lat/long columns to float
merged['LATITUDE'] = merged['LATITUDE'].astype(float)
merged['LONGITUDE'] = merged['LONGITUDE'].astype(float)

# create geodataframe using Latitude and Longitude columns
gdf = gpd.GeoDataFrame(merged, geometry=gpd.points_from_xy(merged.LONGITUDE, merged.LATITUDE))

# define crs for geodataframe
gdf.crs = {'init' :'epsg:4326'}

gdf.head()
# Out:
#              TRIFD                         FACILITY_NAME  \
# 0  00610BXTRHROAD4  EDWARDS LIFESCIENCES TECHNOLOGY SARL
# 1  01151MNSNT730WO                           SOLUTIA INC
# 2  06383FDRLPINLAN   FUSION PAPERBOARD - CONNECTICUT LLC
# 3  07080MTZMT3900S          AMES ADVANCED MATERIALS CORP
# 4  07524CRDNL50561                    CARDINAL COLOR INC
#
#                                       STREET_ADDRESS              CITY  \
# 0  STATE RD 402 KM 1.4 N LAS MARIAS IND US TRIAL ...            ANASCO
# 1                                   730 WORCESTER ST       SPRINGFIELD
# 2                                      130 INLAND RD        VERSAILLES
# 3                                 3900 S CLINTON AVE  SOUTH PLAINFIELD
# 4                                      50-56 1ST AVE          PATERSON
#
#              COUNTY  ST   ZIP BIA TRIBE  LATITUDE  ...     SCORE2010  \
# 0  ANASCO MUNICIPIO  PR   610            18.29390  ... 1983053.00000
# 1           HAMPDEN  MA  1151            42.15498  ...    4600.43524
# 2        NEW LONDON  CT  6383            41.62371  ...       0.00000
# 3         MIDDLESEX  NJ  7080            40.56461  ... 2444261.67552
# 4           PASSAIC  NJ  7524            40.94033  ...       0.00000
#
#       SCORE2011     SCORE2012     SCORE2013     SCORE2014     SCORE2015  \
# 0 1971439.00000 2318757.30000 2579384.00000 2825327.00000 2999252.00000
# 1    5275.97550    5178.29442    7404.05958   20519.58557   22642.33037
# 2       0.00000       0.00000 1042687.22673 1049377.71344           nan
# 3  713384.65160  200326.28348   79885.60989  148097.92734   31458.78769
# 4       0.00000       0.00000           nan           nan           nan
#
#       SCORE2016    SCORE2017    SCORE2018                    geometry
# 0 6185696.00000 938779.00000 901403.70000  POINT (-67.13660 18.29390)
# 1   21925.85518  21709.77031  22334.36070  POINT (-72.52642 42.15498)
# 2           nan          nan          nan  POINT (-72.04313 41.62371)
# 3   51581.74653  51872.61882 133989.86931  POINT (-74.42964 40.56461)
# 4           nan          nan          nan  POINT (-74.14554 40.94033)
#
# [5 rows x 50 columns]

# %%
# export geodataframe to geojson
gdf.to_file("../data/top-tri-scores.geojson", driver='GeoJSON', encoding='utf-8')

# %%
tri_filter['CHEMICAL'].unique()
# Out:
# array(['PHOSPHORIC ACID',
#        'SULFURIC ACID (1994 AND AFTER ACID AEROSOLS" ONLY)"',
#        'AMMONIUM SULFATE (SOLUTION)', 'N-NITROSODI-N-PROPYLAMINE',
#        'METHYL ETHYL KETONE', 'AMMONIA', 'CHLOROMETHANE',
#        '2-METHOXYETHANOL', 'TOLUENE', 'ZINC COMPOUNDS', 'METHANOL',
#        'SODIUM HYDROXIDE (SOLUTION)', 'TETRACHLOROETHYLENE',
#        'POLYCHLORINATED BIPHENYLS', '1,1,1-TRICHLOROETHANE', 'PROPYLENE',
#        'ETHYLENE GLYCOL', 'CARBON DISULFIDE', 'COPPER', 'STYRENE',
#        'HYDROGEN CYANIDE', 'ALUMINUM OXIDE (FIBROUS FORMS)', 'MIXTURE',
#        'HYDROCHLORIC ACID (1995 AND AFTER ACID AEROSOLS" ONLY)"',
#        'SODIUM SULFATE (SOLUTION)', 'ACETONE', 'ZINC (FUME OR DUST)',
#        'VINYL CHLORIDE', 'XYLENE (MIXED ISOMERS)', 'COPPER COMPOUNDS',
#        'O-XYLENE',
#        'CHROMIUM COMPOUNDS(EXCEPT CHROMITE ORE MINED IN THE TRANSVAAL REGION)',
#        'DIBUTYL PHTHALATE', 'FREON 113', 'DICHLOROMETHANE',
#        'HEXACHLORO-1,3-BUTADIENE', 'METHYLENEBIS(PHENYLISOCYANATE)',
#        'N-DIOCTYL PHTHALATE', 'M-XYLENE', 'METHYL ISOBUTYL KETONE',
#        'CARBON TETRACHLORIDE', 'CUMENE', 'MANGANESE COMPOUNDS',
#        'CERTAIN GLYCOL ETHERS', 'LEAD', 'NICKEL', 'NITRIC ACID',
#        'ASBESTOS (FRIABLE)', 'CADMIUM', 'CHLORINE',
#        'ALUMINUM (FUME OR DUST)', 'CYANIDE COMPOUNDS',
#        'TITANIUM TETRACHLORIDE', 'CHROMIUM', 'LEAD COMPOUNDS',
#        'NAPHTHALENE', 'PHENOL', 'MANGANESE', 'BARIUM', 'ETHYLENE OXIDE',
#        'ETHYLBENZENE', 'BENZENE', 'STYRENE OXIDE', 'METHYL ACRYLATE',
#        'FORMALDEHYDE', 'METHYLENE BROMIDE', 'TRICHLOROETHYLENE',
#        'AMMONIUM NITRATE (SOLUTION)', 'CRESOL (MIXED ISOMERS)',
#        'BIPHENYL', 'ANTIMONY COMPOUNDS',
#        'VANADIUM (EXCEPT WHEN CONTAINED IN AN ALLOY)', 'THIOUREA',
#        '1,2-DICHLOROETHANE', 'MERCURY COMPOUNDS', 'P-XYLENE',
#        'N-BUTYL ALCOHOL', 'BARIUM COMPOUNDS', 'VINYL ACETATE',
#        'HYDROQUINONE', 'PROPYLENE OXIDE', 'DIETHYL PHTHALATE', '2,4-D',
#        'ACRYLIC ACID', "4,4'-ISOPROPYLIDENEDIPHENOL", 'TEREPHTHALIC ACID',
#        'NICKEL COMPOUNDS', 'HYDROGEN FLUORIDE', 'EPICHLOROHYDRIN',
#        'ACRYLAMIDE', 'ANTHRACENE', 'PHOSPHORUS (YELLOW OR WHITE)',
#        'TOLUENE-2,6-DIISOCYANATE', 'BIS(2-CHLOROETHYL) ETHER',
#        'DIETHANOLAMINE', 'DIBENZOFURAN', 'CYCLOHEXANE', 'MELAMINE',
#        'P-PHENYLENEDIAMINE', 'BENZOYL PEROXIDE', '2-ETHOXYETHANOL',
#        'DI(2-ETHYLHEXYL) PHTHALATE', 'COBALT', 'ETHYL ACRYLATE',
#        'P-CRESIDINE', '1,3-BUTADIENE', 'CHLOROETHANE',
#        'METHYL METHACRYLATE', 'MALEIC ANHYDRIDE', 'CHLOROFORM',
#        'SELENIUM', 'CHLOROPRENE', 'SEC-BUTYL ALCOHOL',
#        "4,4'-DIAMINODIPHENYL ETHER", 'PHTHALIC ANHYDRIDE',
#        '1,1,2-TRICHLOROETHANE', 'DIMETHYL PHTHALATE', 'ACETALDEHYDE',
#        'ACRYLONITRILE', 'URETHANE', 'PENTACHLOROPHENOL', 'ARSENIC',
#        'BIS(2-ETHYLHEXYL) ADIPATE', 'N,N-DIMETHYLANILINE',
#        'ARSENIC COMPOUNDS', 'SILVER', 'DECABROMODIPHENYL OXIDE',
#        'ETHYLENE', 'CHLOROACETIC ACID', 'PROPIONALDEHYDE',
#        'TOLUENE-2,4-DIISOCYANATE', '1,2,4-TRIMETHYLBENZENE',
#        'CADMIUM COMPOUNDS', 'NITROGLYCERIN', '1,2,4-TRICHLOROBENZENE',
#        'BROMOMETHANE', 'TRIFLURALIN', 'ANILINE', 'BUTYL ACRYLATE',
#        'ISOPROPYL ALCOHOL (MANUFACTURING,STRONG-ACID PROCESS ONLY,NO SUPPLIER)',
#        'TETRACHLORVINPHOS', 'TRICHLORFON', '2-NITROPHENOL',
#        'COBALT COMPOUNDS', 'BENZOIC TRICHLORIDE', 'MANEB', 'PHOSGENE',
#        'QUINOLINE', '1,4-DIOXANE', 'BENZYL CHLORIDE', 'DIMETHYL SULFATE',
#        'MERCURY', 'ANTIMONY', 'DICHLOROBENZENE (MIXED ISOMERS)',
#        '2,4-DIAMINOTOLUENE', '1,1,2,2-TETRACHLOROETHANE',
#        'MOLYBDENUM TRIOXIDE', '2,4-DINITROPHENOL', 'BERYLLIUM COMPOUNDS',
#        'ACETONITRILE', 'M-CRESOL', 'P-ANISIDINE', 'NITRILOTRIACETIC ACID',
#        'METHYL TERT-BUTYL ETHER', '2-NITROPROPANE',
#        'BUTYL BENZYL PHTHALATE', 'SILVER COMPOUNDS', 'P-CRESOL',
#        'CHLORINE DIOXIDE', 'HEXACHLOROETHANE', 'ACROLEIN',
#        '2-PHENYLPHENOL', 'DIETHYL SULFATE', 'TERT-BUTYL ALCOHOL',
#        'PERACETIC ACID', 'CHLOROBENZENE', '2,4-DINITROTOLUENE',
#        'CARBONYL SULFIDE', 'PARATHION', 'CHLOROTHALONIL', 'BERYLLIUM',
#        'CATECHOL', "4,4'-METHYLENEDIANILINE", 'THORIUM DIOXIDE',
#        'CUMENE HYDROPEROXIDE', 'DIAMINOTOLUENE (MIXED ISOMERS)',
#        '1,2-DICHLOROETHYLENE', '1,2-DIBROMOETHANE', 'METHYL IODIDE',
#        'CARBARYL', 'HEXACHLOROBENZENE', '1,4-DICHLOROBENZENE',
#        'DICHLORVOS', 'VINYL BROMIDE', '1,2-DICHLOROBENZENE',
#        '1,2-BUTYLENE OXIDE', "3,3'-DICHLOROBENZIDINE", 'PROPOXUR',
#        'ALLYL CHLORIDE', 'HYDRAZINE', '2,4-DIMETHYLPHENOL',
#        'BUTYRALDEHYDE', "4,4'-METHYLENEBIS(2-CHLOROANILINE)",
#        'THALLIUM COMPOUNDS', 'CAPTAN', 'BENZOYL CHLORIDE',
#        '1,2-DICHLOROPROPANE', 'METHOXYCHLOR', 'LINDANE', 'NITROBENZENE',
#        'SACCHARIN (MANUFACTURING, NO SUPPLIER NOTIFICATION)',
#        'CHLOROMETHYL METHYL ETHER', 'ETHYLENE THIOUREA', 'O-CRESOL',
#        'C.I. BASIC GREEN 4', 'METHYL ISOCYANATE', '2,4-DICHLOROPHENOL',
#        'ISOBUTYRALDEHYDE', 'C.I. ACID BLUE 9, DISODIUM SALT',
#        'O-TOLUIDINE', 'BIS(2-CHLORO-1-METHYLETHYL) ETHER',
#        '4-NITROPHENOL', 'PYRIDINE', 'CHLOROPHENOLS', 'SELENIUM COMPOUNDS',
#        '2,6-DINITROTOLUENE', '1,3-DICHLOROBENZENE',
#        'C.I. DISPERSE YELLOW 3', 'PICRIC ACID', 'HYDRAZINE SULFATE',
#        'O-ANISIDINE', 'CALCIUM CYANAMIDE', 'HEXACHLOROCYCLOPENTADIENE',
#        'VINYLIDENE CHLORIDE', '2,6-XYLIDINE', 'TRADE SECRET CHEMICAL',
#        'BIS(CHLOROMETHYL) ETHER', "MICHLER'S KETONE", 'CHLORAMBEN',
#        'ALPHA-NAPHTHYLAMINE', 'ETHYL CHLOROFORMATE',
#        '1,3-DICHLOROPROPYLENE', 'QUINONE', 'DICOFOL', 'NITROGEN MUSTARD',
#        'C.I. SOLVENT YELLOW 14',
#        "4,4'-METHYLENEBIS(N,N-DIMETHYL)BENZENAMINE",
#        '4,6-DINITRO-O-CRESOL', 'N-NITROSODIPHENYLAMINE', 'SAFROLE',
#        '5-NITRO-O-ANISIDINE', 'BENZAL CHLORIDE', 'PROPYLENEIMINE',
#        '2,4,6-TRICHLOROPHENOL', 'CUPFERRON', 'P-NITROSODIPHENYLAMINE',
#        'THALLIUM', 'C.I. ACID BLUE 9, DIAMMONIUM SALT',
#        '2,4-DIAMINOANISOLE SULFATE', 'ZINEB', 'METHYL HYDRAZINE',
#        'ACETAMIDE', 'DICHLOROBROMOMETHANE', 'CHLOROBENZILATE',
#        '1,1-DIMETHYL HYDRAZINE', 'ETHYLENEIMINE', '2,4-DIAMINOANISOLE',
#        '2-CHLOROACETOPHENONE', 'CHLORDANE', '4-AMINOAZOBENZENE',
#        'QUINTOZENE', 'FLUOMETURON', 'HEPTACHLOR', '4-AMINOBIPHENYL',
#        'PROPANE SULTONE', 'BROMOFORM', 'C.I. FOOD RED 15', 'BENZAMIDE',
#        'C.I. SOLVENT YELLOW 3', 'N-HEXANE', 'N-NITROSODIMETHYLAMINE',
#        'THIOACETAMIDE', 'POLYBROMINATED BIPHENYLS',
#        '2,4,5-TRICHLOROPHENOL', 'C.I. DIRECT BLACK 38',
#        'C.I. BASIC RED 1', 'DIISOCYANATES', "3,3'-DIMETHOXYBENZIDINE",
#        "3,3'-DIMETHYLBENZIDINE", 'C.I. SOLVENT ORANGE 7',
#        'NITRATE COMPOUNDS', 'TOLUENE DIISOCYANATE (MIXED ISOMERS)',
#        'ALLYL ALCOHOL', 'CREOSOTE', 'O-DINITROBENZENE',
#        '2,3-DICHLOROPROPENE', 'DINITROTOLUENE (MIXED ISOMERS)',
#        'ISOSAFROLE', 'M-DINITROBENZENE', 'TOXAPHENE', 'P-DINITROBENZENE',
#        'DICHLORODIFLUOROMETHANE', 'BROMOTRIFLUOROMETHANE',
#        'DICHLOROTETRAFLUOROETHANE (CFC-114)', 'TRICHLOROFLUOROMETHANE',
#        'BROMOCHLORODIFLUOROMETHANE', 'MONOCHLOROPENTAFLUOROETHANE',
#        'DIBROMOTETRAFLUOROETHANE', 'DIEPOXYBUTANE', 'FORMIC ACID',
#        '1,2-DIBROMO-3-CHLOROPROPANE', 'N,N-DIMETHYLFORMAMIDE',
#        '1,1-DICHLORO-1-FLUOROETHANE', 'BENZIDINE',
#        'ETHYLENEBISDITHIOCARBAMIC ACID, SALTS AND ESTERS',
#        'CHLORODIFLUOROMETHANE', 'ACETOPHENONE', 'THIRAM',
#        'LITHIUM CARBONATE', 'PENTACHLOROETHANE',
#        '1,1,1,2-TETRACHLOROETHANE', '1-CHLORO-1,1-DIFLUOROETHANE',
#        '1-CHLORO-1,1,2,2-TETRAFLUOROETHANE', '2-METHYLPYRIDINE',
#        '2,2-DICHLORO-1,1,1-TRIFLUOROETHANE', 'DICHLOROTRIFLUOROETHANE',
#        '2-CHLORO-1,1,1,2-TETRAFLUOROETHANE', 'METHYL CHLOROCARBONATE',
#        'METHACRYLONITRILE', 'DIHYDROSAFROLE', '1,4-DICHLORO-2-BUTENE',
#        'ETHYLIDENE DICHLORIDE', 'N-METHYL-2-PYRROLIDONE', 'MALONONITRILE',
#        'HEXACHLOROPHENE', 'PARALDEHYDE', 'BIS(2-CHLOROETHOXY)METHANE',
#        'SODIUM NITRITE', '5-NITRO-O-TOLUIDINE', 'PRONAMIDE',
#        'DICYCLOPENTADIENE', 'SODIUM DIMETHYLDITHIOCARBAMATE',
#        'HYDRAMETHYLNON', 'BROMOXYNIL OCTANOATE', 'DIPHENYLAMINE',
#        'PENDIMETHALIN', '3-CHLORO-2-METHYL-1-PROPENE', 'CHLORSULFURON',
#        'BORON TRIFLUORIDE', 'POLYCYCLIC AROMATIC COMPOUNDS',
#        'METHYL ISOTHIOCYANATE', 'DIAZINON', 'SODIUM AZIDE',
#        'DIMETHYLAMINE', 'POLYCHLORINATED ALKANES', 'TRIETHYLAMINE',
#        'MYCLOBUTANIL', 'NICOTINE AND SALTS', '1,3-PHENYLENEDIAMINE',
#        'TRICLOPYR TRIETHYLAMMONIUM SALT', 'ALACHLOR', 'MECOPROP',
#        'BIFENTHRIN', 'PHENANTHRENE', 'DISODIUM CYANODITHIOIMIDOCARBONATE',
#        'MALATHION', "3,3'-DICHLOROBENZIDINE DIHYDROCHLORIDE", 'OZONE',
#        'CYANAZINE', 'BENFLURALIN', 'CYCLOHEXANOL', '2-METHYLLACTONITRILE',
#        '2-MERCAPTOBENZOTHIAZOLE', 'C.I. DIRECT BLUE 218', 'ACEPHATE',
#        'POTASSIUM DIMETHYLDITHIOCARBAMATE', 'BROMINE', 'METHAM SODIUM',
#        '2,4-D 2-ETHYLHEXYL ESTER', 'DIPOTASSIUM ENDOTHALL', 'HEXAZINONE',
#        'CHLORIMURON ETHYL', 'AMETRYN', '2,4-D BUTOXYETHYL ESTER',
#        'FLUORINE', 'PERMETHRIN', 'ETHOPROP', 'SIMAZINE', 'CHLOROPICRIN',
#        'TEMEPHOS', 'DIURON', 'PROMETRYN', 'LINURON', 'FOMESAFEN',
#        'TRIADIMEFON', 'NITRAPYRIN', 'DICHLORAN',
#        '3-IODO-2-PROPYNYL BUTYLCARBAMATE', 'BROMOXYNIL',
#        '1-(3-CHLOROALLYL)-3,5,7-TRIAZA-1-AZONIAADAMANTANE CHLORIDE',
#        'THIOSEMICARBAZIDE', 'N-NITROSOMORPHOLINE', 'N-METHYLOLACRYLAMIDE',
#        'METHYL PARATHION', 'TRICHLOROACETYL CHLORIDE',
#        'PIPERONYL BUTOXIDE', 'DICAMBA', 'TRIBUTYLTIN FLUORIDE',
#        'ATRAZINE', 'METRIBUZIN', 'CYCLOATE', 'ISOFENPHOS',
#        'CROTONALDEHYDE', 'TETRACYCLINE HYDROCHLORIDE',
#        'TRANS-1,3-DICHLOROPROPENE', 'FAMPHUR', 'TERBACIL', 'NALED',
#        'TRANS-1,4-DICHLORO-2-BUTENE', 'ORYZALIN', 'DAZOMET', 'OXYDIAZON',
#        'ACIFLUORFEN, SODIUM SALT', 'DODINE', 'IRON PENTACARBONYL',
#        'PARAQUAT DICHLORIDE', 'METHOXONE', 'PROPANIL',
#        'TRIBENURON METHYL', 'P-CHLOROANILINE', 'THIABENDAZOLE',
#        'PROPACHLOR', 'NABAM', '2,6-DIMETHYLPHENOL', 'DINITROBUTYL PHENOL',
#        'ETHYL DIPROPYLTHIOCARBAMATE', '2-BROMO-2-NITROPROPANE-1,3-DIOL',
#        '1,2-DICHLORO-1,1-DIFLUOROETHANE', 'BENDIOCARB',
#        'SULFURYL FLUORIDE', '1,2-PHENYLENEDIAMINE', 'TRIFORINE',
#        'DAZOMET, SODIUM SALT', 'DINOCAP',
#        'POTASSIUM N-METHYLDITHIOCARBAMATE', 'THIOPHANATE-METHYL',
#        '2,4-DB', 'THIOBENCARB', 'BROMACIL', 'BORON TRICHLORIDE',
#        'NORFLURAZON', 'FOLPET', 'DESMEDIPHAM', 'PROPARGYL ALCOHOL',
#        'DIMETHOATE', 'DIMETHYLAMINE DICAMBA', 'DICHLOROFLUOROMETHANE',
#        'DIMETHYL CHLOROTHIOPHOSPHATE', 'PROPICONAZOLE', 'PROPARGITE',
#        'CHLORPYRIFOS METHYL', 'BRUCINE', 'CYFLUTHRIN', 'P-NITROANILINE',
#        'MOLINATE', 'PHOSPHINE', 'S,S,S-TRIBUTYLTRITHIOPHOSPHATE',
#        'OXYDEMETON METHYL', 'RESMETHRIN', 'TRIALLATE',
#        'SODIUM O-PHENYLPHENOXIDE', 'POTASSIUM BROMATE', 'FENTHION',
#        'TEBUTHIURON', '3,3-DICHLORO-1,1,1,2,2-PENTAFLUOROPROPANE',
#        'ALDICARB', '1,2,3-TRICHLOROPROPANE', 'LACTOFEN',
#        'ALUMINUM PHOSPHIDE', 'TRIPHENYLTIN HYDROXIDE', 'CARBOXIN',
#        'D-TRANS-ALLETHRIN', 'FENVALERATE', '2,4-D BUTYL ESTER',
#        'THIODICARB', 'TRIBUTYLTIN METHACRYLATE', 'PEBULATE',
#        'PROPETAMPHOS', 'CHLOROTRIFLUOROMETHANE', 'CARBOFURAN',
#        'CHLORENDIC ACID', '1,3-DICHLORO-1,1,2,2,3-PENTAFLUOROPROPANE',
#        'SULPROFOS', 'TRIPHENYLTIN CHLORIDE', 'FENARIMOL',
#        "3,3'-DIMETHOXYBENZIDINE DIHYDROCHLORIDE", 'PHENOTHRIN',
#        'FLUVALINATE', "3,3'-DICHLOROBENZIDINE SULFATE",
#        '1,1,2,2-TETRACHLORO-1-FLUOROETHANE', 'ABAMECTIN',
#        'FENBUTATIN OXIDE', 'C.I. DIRECT BROWN 95', 'BENOMYL',
#        'QUIZALOFOP-ETHYL', 'PICLORAM', 'BIS(TRIBUTYLTIN) OXIDE', '2,4-DP',
#        'PERCHLOROMETHYL MERCAPTAN', 'VINCLOZOLIN', 'FENOXYCARB',
#        'SODIUM DICAMBA', 'TETRAMETHRIN', '2-CHLORO-1,1,1-TRIFLUOROETHANE',
#        'OXYFLUORFEN', 'DIMETHIPIN', 'MEVINPHOS', 'MERPHOS', 'PROFENOFOS',
#        'DIFLUBENZURON', 'C.I. ACID RED 114', 'FENPROPATHRIN',
#        '2,4-D SODIUM SALT', 'PHENYTOIN',
#        '1-BROMO-1-(BROMOMETHYL)-1,3-PROPANEDICARBONITRILE',
#        'THIOPHANATE ETHYL', 'AMITRAZ', 'DIGLYCIDYL RESORCINOL ETHER',
#        'FLUAZIFOP BUTYL', 'DIPROPYL ISOCINCHOMERONATE',
#        '1,2-DICHLORO-1,1,2-TRIFLUOROETHANE', 'ALLYLAMINE', 'FLUOROURACIL',
#        "3,3'-DIMETHYLBENZIDINE DIHYDROCHLORIDE", 'SETHOXYDIM',
#        '1,1,1,2-TETRACHLORO-2-FLUOROETHANE', 'PENTOBARBITAL SODIUM',
#        'DIMETHYLCARBAMYL CHLORIDE', 'METHIOCARB', 'N-NITROSODIETHYLAMINE',
#        'CHLOROTETRAFLUOROETHANE', 'ALDRIN', 'AMITROLE',
#        '1,2-DIPHENYLHYDRAZINE', 'N-NITROSOPIPERIDINE',
#        'BETA-NAPHTHYLAMINE', 'C.I. SOLVENT YELLOW 34',
#        'DICHLOROPENTAFLUOROPROPANE', 'O-TOLUIDINE HYDROCHLORIDE',
#        'N-NITROSO-N-ETHYLUREA', 'TRYPAN BLUE', 'IMAZALIL', 'DIALLATE',
#        'DIOXIN AND DIOXIN-LIKE COMPOUNDS', 'N-NITROSO-N-METHYLUREA',
#        '2-ACETYLAMINOFLUORENE', 'STRYCHNINE AND SALTS',
#        'N-NITROSODI-N-BUTYLAMINE', 'TRIS(2,3-DIBROMOPROPYL) PHOSPHATE',
#        'WARFARIN AND SALTS', 'OSMIUM TETROXIDE',
#        'N-NITROSOMETHYLVINYLAMINE', 'SODIUM FLUOROACETATE',
#        'PIRIMIPHOS METHYL', '3-CHLOROPROPIONITRILE', 'CYHALOTHRIN',
#        'VANADIUM COMPOUNDS', '2,4-DITHIOBIURET', 'BENZO(G,H,I)PERYLENE',
#        'DIAZOMETHANE', 'TETRABROMOBISPHENOL A', 'PENTACHLOROBENZENE',
#        'NITROFEN', '4-DIMETHYLAMINOAZOBENZENE', 'OCTACHLOROSTYRENE',
#        'ISODRIN', 'HEXAMETHYLPHOSPHORAMIDE', 'FERBAM',
#        'METHOXONE SODIUM SALT', '2,4-D ISOPROPYL ESTER',
#        '1,1-DICHLORO-1,2,2-TRIFLUOROETHANE',
#        '2,4-D 2-ETHYL-4-METHYLPENTYL ESTER',
#        '1,1-DICHLORO-1,2,2,3,3-PENTAFLUOROPROPANE', 'ANILAZINE',
#        '1,2-DICHLORO-1,1,3,3,3-PENTAFLUOROPROPANE', 'METIRAM',
#        'METHAZOLE', 'P-CHLOROPHENYL ISOCYANATE',
#        'ALPHA-HEXACHLOROCYCLOHEXANE', 'OCTACHLORONAPHTHALENE',
#        'BETA-PROPIOLACTONE', '2,3-DICHLORO-1,1,1,2,3-PENTAFLUOROPROPANE',
#        '3-CHLORO-1,1,1-TRIFLUOROPROPANE',
#        '2,4-D PROPYLENE GLYCOL BUTYL ETHER ESTER', 'MUSTARD GAS',
#        'TETRAFLUOROETHYLENE', 'ISOPRENE', 'NITROMETHANE', 'GLYCIDOL',
#        'VINYL FLUORIDE', 'PHENOLPHTHALEIN', 'FURAN',
#        '2,4-D CHLOROCROTYL ESTER', '2,2-BIS(BROMOMETHYL)-1,3-PROPANEDIOL',
#        '2-AMINOANTHRAQUINONE', 'METHYLEUGENOL', 'HYDROGEN SULFIDE',
#        'DICHLOROPHENE', 'MONURON', 'MANGANESE  and MANGANESE COMPOUNDS',
#        'C.I. VAT YELLOW 4', 'NONYLPHENOL', nan, '1-BROMOPROPANE',
#        'FENOXAPROP ETHYL', 'COPPER  and COPPER COMPOUNDS',
#        'HEXABROMOCYCLODODECANE', 'LEAD  and LEAD COMPOUNDS',
#        'NICKEL  and NICKEL COMPOUNDS', 'COBALT  and COBALT COMPOUNDS',
#        'MERCURY  and MERCURY COMPOUNDS',
#        'ANTIMONY  and ANTIMONY COMPOUNDS', 'BARIUM  and BARIUM COMPOUNDS',
#        'SELENIUM  and SELENIUM COMPOUNDS',
#        'ARSENIC  and ARSENIC COMPOUNDS', 'CADMIUM  and CADMIUM COMPOUNDS',
#        'SILVER and SILVER COMPOUNDS',
#        'BERYLLIUM  and BERYLLIUM COMPOUNDS',
#        'THALLIUM  and THALLIUM COMPOUNDS'], dtype=object)

# %%
chromium = tri_filter[(tri_filter['YEAR'] == 2018) & (tri_filter['CHEMICAL'].str.contains('CHROMIUM'))]
chromium
# Out:
#          YEAR            TRIFD                               FACILITY_NAME  \
# 2659866  2018  2974WCMSTL6371C                                CM STEEL INC
# 2659879  2018  27893NCRMC2401S                    LINAMAR FORGING CAROLINA
# 2659913  2018  74651SNRGNHWY15   OGE ENERGY CORP SOONER GENERATING STATION
# 2659922  2018  55719MNNST611WE               MN TWIST DRILL AQUISITION LLC
# 2659929  2018  54971LLNCL69STA  ALLIANCE LAUNDRY SYSTEMS LLC STANTON PLANT
# ...       ...              ...                                         ...
# 2739398  2018  66106FRBNK3601F            PENTAIR  - KANSAS CITY OPERATION
# 2739419  2018  75501LMXML300AL                           TCI TEXARKANA INC
# 2739425  2018  46580THYNC486W3          SYMMETRY MEDICAL WARSAW BULDING #1
# 2739447  2018  7737WNVRMS196FM                            NOV RMES TOMBALL
# 2739472  2018  42366PRMML5680O                         HINES PRECISION INC
#
#                STREET_ADDRESS         CITY       COUNTY  ST    ZIP  BIA TRIBE  \
# 2659866    6371 CAMPBELL ROAD         YORK         YORK  SC  29745  nan   NaN
# 2659879  2401 STANTONSBURG RD       WILSON       WILSON  NC  27893  nan   NaN
# 2659913              HWY 15 N     RED ROCK        NOBLE  OK  74651  nan   NaN
# 2659922           1 SW 7TH ST     CHISHOLM     ST LOUIS  MN  55719  nan   NaN
# 2659929        690 STANTON ST        RIPON  FOND DU LAC  WI  54971  nan   NaN
# ...                       ...          ...          ...  ..    ...  ...   ...
# 2739398    3601 FAIRBANKS AVE  KANSAS CITY    WYANDOTTE  KS  66106  nan   NaN
# 2739419         300 ALUMAX DR    TEXARKANA        BOWIE  TX  75501  nan   NaN
# 2739425           486 W 350 N       WARSAW    KOSCIUSKO  IN  46582  nan   NaN
# 2739447         10906 FM 2920      TOMBALL       HARRIS  TX  77375  nan   NaN
# 2739472        5680 OLD KY 54      PHILPOT      DAVIESS  KY  42366  nan   NaN
#
#          LATITUDE  LONGITUDE              INDUSTRY_SECTOR  \
# 2659866  35.03478  -81.12497            Fabricated Metals
# 2659879  35.69570  -77.89097            Fabricated Metals
# 2659913  36.45350  -97.05267           Electric Utilities
# 2659922  47.48216  -92.87961                    Machinery
# 2659929  43.85293  -88.82580                    Machinery
# ...           ...        ...                          ...
# 2739398  39.08783  -94.67105         Electrical Equipment
# 2739419  33.45071  -94.13436               Primary Metals
# 2739425  41.28500  -85.85270  Miscellaneous Manufacturing
# 2739447  30.09958  -95.58480                    Machinery
# 2739472  37.73491  -87.00282            Fabricated Metals
#
#                        PARENT_CO_NAME  \
# 2659866                           NaN
# 2659879                  LINAMAR CORP
# 2659913               OGE ENERGY CORP
# 2659922                           NaN
# 2659929  ALLIANCE LAUNDRY SYSTEMS LLC
# ...                               ...
# 2739398                   PENTAIR INC
# 2739419     TA CHEN INTERNATIONAL INC
# 2739425                   TECOMET INC
# 2739447     NATIONAL OILWELL VARCO LP
# 2739472                           NaN
#
#                                                   CHEMICAL   WATER  \
# 2659866                                           CHROMIUM 0.00000
# 2659879                                           CHROMIUM 0.00000
# 2659913  CHROMIUM COMPOUNDS(EXCEPT CHROMITE ORE MINED I... 0.00000
# 2659922                                           CHROMIUM 0.00000
# 2659929                                           CHROMIUM 0.00000
# ...                                                    ...     ...
# 2739398                                           CHROMIUM 5.00000
# 2739419                                           CHROMIUM 1.30000
# 2739425                                           CHROMIUM 0.00000
# 2739447                                           CHROMIUM 0.00000
# 2739472                                           CHROMIUM 0.00000
#
#          ON_SITE_RELEASE_TOTAL       AIR UNIT_OF_MEASURE
# 2659866               15.07200  15.07200          Pounds
# 2659879                0.00000   0.00000          Pounds
# 2659913              199.00000 199.00000          Pounds
# 2659922                0.00000   0.00000          Pounds
# 2659929                5.00000   5.00000          Pounds
# ...                        ...       ...             ...
# 2739398              212.64000 207.64000          Pounds
# 2739419                1.40400   0.10400          Pounds
# 2739425                0.00000   0.00000          Pounds
# 2739447                0.00000   0.00000          Pounds
# 2739472                0.00000   0.00000          Pounds
#
# [3258 rows x 19 columns]

# %%
# now reduce filtered dataframe to find one record per facility and sum chromium and chromium compound releases
# use group by TRIFID field
chromium = chromium.fillna('').groupby('TRIFD').agg({'FACILITY_NAME':'first',
                             'STREET_ADDRESS':'first',
                             'CITY':'first',
                             'COUNTY':'first',
                             'ST':'first',
                             'ZIP':'first',
                             'BIA':'first',
                             'TRIBE':'first',
                             'LATITUDE':'first',
                             'LONGITUDE':'first',
                             'INDUSTRY_SECTOR':'first',
                             'PARENT_CO_NAME': 'first',
                             'ON_SITE_RELEASE_TOTAL':'sum',
                             'AIR':'sum',
                             'YEAR': 'first'
                                               }).reset_index()

chromium
# Out:
#                 TRIFD                              FACILITY_NAME  \
# 0     00612THRMKZENOG    THERMO KING PUERTO RICO MANUFACTURA INC
# 1     00617PRCSNTMASD  ADM ALLIANCE NUTRITION OF PUERTO RICO LLC
# 2     00630WDTRT65INF                  PUERTO RICO WOOD TREATING
# 3     00659CNTRLRD2KM           ADM ALLIANCE NUTRITION OF PR LLC
# 4     00694HRVYHRD686                         HUBBELL CARIBE LTD
# ...               ...                                        ...
# 3221  99707FRTKN1FORA                             FORT KNOX MINE
# 3222  99737PGMNX38MIL                                  POGO MINE
# 3223  99752RDDGP90MIL                         RED DOG OPERATIONS
# 3224  99801CRLSK331CL   COEUR ALASKA INC KENSINGTON GOLD PROJECT
# 3225  99801KNNCT13401               HECLA GREENS CREEK MINING CO
#
#                                          STREET_ADDRESS            CITY  \
# 0                                 517 ZONA IND US TRIAL         ARECIBO
# 1     TOMAS DAVILA ST EDIF 10  PALMAS ALTAS INDUSTRI...     BARCELONETA
# 2                           AVE 65 DE INFANTERIA KM 7.0        CAROLINA
# 3                STATE RD NO. 2 KM 83.0 CARRIZALES WARD         HATILLO
# 4                                        RD 686 KM 17.3       VEGA BAJA
# ...                                                 ...             ...
# 3221                                     1 FORT KNOX RD       FAIRBANKS
# 3222                      38 MILES NE OF DELTA JUNCTION  DELTA JUNCTION
# 3223                             90 MILES N OF KOTZEBUE        KOTZEBUE
# 3224                                    3031 CLINTON DR          JUNEAU
# 3225                                  13401 GLACIER HWY          JUNEAU
#
#                             COUNTY  ST    ZIP BIA TRIBE  LATITUDE  LONGITUDE  \
# 0                ARECIBO MUNICIPIO  PR    612            18.45815  -66.74646
# 1            BARCELONETA MUNICIPIO  PR    617            18.45276  -66.54038
# 2               SAN JUAN MUNICIPIO  PR    985            18.38135  -66.03416
# 3                HATILLO MUNICIPIO  PR    659            18.48514  -66.77732
# 4              VEGA BAJA MUNICIPIO  PR    693            18.48647  -66.40520
# ...                            ...  ..    ...  ..   ...       ...        ...
# 3221  FAIRBANKS NORTH STAR BOROUGH  AK  99712            64.99953 -147.35811
# 3222  FAIRBANKS NORTH STAR BOROUGH  AK  99737            64.44972 -144.93962
# 3223      NORTHWEST ARCTIC BOROUGH  AK  99752            68.06151 -162.85549
# 3224                JUNEAU BOROUGH  AK  99801            58.86749 -135.10476
# 3225                JUNEAU BOROUGH  AK  99801            58.08180 -134.64121
#
#            INDUSTRY_SECTOR                     PARENT_CO_NAME  \
# 0                Machinery                  INGERSOLL-RAND CO
# 1                     Food          ARCHER DANIELS MIDLAND CO
# 2            Wood Products
# 3                     Food          ARCHER DANIELS MIDLAND CO
# 4     Electrical Equipment                        HUBBELL INC
# ...                    ...                                ...
# 3221          Metal Mining                  KINROSS GOLD CORP
# 3222          Metal Mining  SUMITOMO METAL MINING AMERICA INC
# 3223          Metal Mining                  TECK AMERICAN INC
# 3224          Metal Mining                  COEUR MINING INC.
# 3225          Metal Mining                    HECLA MINING CO
#
#       ON_SITE_RELEASE_TOTAL      AIR  YEAR
# 0                   0.04900  0.04900  2018
# 1                   0.00000  0.00000  2018
# 2                   0.00000  0.00000  2018
# 3                   0.00000  0.00000  2018
# 4                   0.00000  0.00000  2018
# ...                     ...      ...   ...
# 3221          1600039.00000 39.00000  2018
# 3222            39161.00000  1.00000  2018
# 3223          3458943.92000 34.59000  2018
# 3224             3502.00000  2.00000  2018
# 3225            38927.00000  0.00000  2018
#
# [3226 rows x 16 columns]

# %%
# cast lat/long columns to float
chromium['LATITUDE'] = chromium['LATITUDE'].astype(float)
chromium['LONGITUDE'] = chromium['LONGITUDE'].astype(float)

# create geodataframe using Latitude and Longitude columns
gdf = gpd.GeoDataFrame(chromium, geometry=gpd.points_from_xy(chromium.LONGITUDE, chromium.LATITUDE))

# define crs for geodataframe
gdf.crs = {'init' :'epsg:4326'}

gdf.head()
# Out:
#              TRIFD                              FACILITY_NAME  \
# 0  00612THRMKZENOG    THERMO KING PUERTO RICO MANUFACTURA INC
# 1  00617PRCSNTMASD  ADM ALLIANCE NUTRITION OF PUERTO RICO LLC
# 2  00630WDTRT65INF                  PUERTO RICO WOOD TREATING
# 3  00659CNTRLRD2KM           ADM ALLIANCE NUTRITION OF PR LLC
# 4  00694HRVYHRD686                         HUBBELL CARIBE LTD
#
#                                       STREET_ADDRESS         CITY  \
# 0                              517 ZONA IND US TRIAL      ARECIBO
# 1  TOMAS DAVILA ST EDIF 10  PALMAS ALTAS INDUSTRI...  BARCELONETA
# 2                        AVE 65 DE INFANTERIA KM 7.0     CAROLINA
# 3             STATE RD NO. 2 KM 83.0 CARRIZALES WARD      HATILLO
# 4                                     RD 686 KM 17.3    VEGA BAJA
#
#                   COUNTY  ST  ZIP BIA TRIBE  LATITUDE  LONGITUDE  \
# 0      ARECIBO MUNICIPIO  PR  612            18.45815  -66.74646
# 1  BARCELONETA MUNICIPIO  PR  617            18.45276  -66.54038
# 2     SAN JUAN MUNICIPIO  PR  985            18.38135  -66.03416
# 3      HATILLO MUNICIPIO  PR  659            18.48514  -66.77732
# 4    VEGA BAJA MUNICIPIO  PR  693            18.48647  -66.40520
#
#         INDUSTRY_SECTOR             PARENT_CO_NAME  ON_SITE_RELEASE_TOTAL  \
# 0             Machinery          INGERSOLL-RAND CO                0.04900
# 1                  Food  ARCHER DANIELS MIDLAND CO                0.00000
# 2         Wood Products                                           0.00000
# 3                  Food  ARCHER DANIELS MIDLAND CO                0.00000
# 4  Electrical Equipment                HUBBELL INC                0.00000
#
#       AIR  YEAR                    geometry
# 0 0.04900  2018  POINT (-66.74646 18.45815)
# 1 0.00000  2018  POINT (-66.54038 18.45276)
# 2 0.00000  2018  POINT (-66.03416 18.38135)
# 3 0.00000  2018  POINT (-66.77732 18.48514)
# 4 0.00000  2018  POINT (-66.40520 18.48647)

# %%
# export geodataframe to geojson
gdf.to_file("../data/chromium-facilities.geojson", driver='GeoJSON', encoding='utf-8')

# %%
ethylene = tri_filter[(tri_filter['YEAR'] == 2018) & (tri_filter['CHEMICAL'].str.contains('ETHYLENE OXIDE'))]
ethylene
# Out:
#          YEAR            TRIFD  \
# 2661062  2018  70669VSTCHOLDSP
# 2661163  2018  30209CRBRD8195N
# 2661788  2018  16510MDCLM2205E
# 2662031  2018  74063CHMLN9100W
# 2662084  2018  49504STRLS520WA
# ...       ...              ...
# 2738248  2018  30906KNDLL1816M
# 2738259  2018  29605THXCHPERIM
# 2738280  2018  62525STLYM2200E
# 2738555  2018  43920VNRLL1250S
# 2738915  2018  76905THCNN3348P
#
#                                              FACILITY_NAME  \
# 2661062  SASOL CHEMICALS (USA) LLC-LAKE CHARLES CHEMICA...
# 2661163         BECTON DICKINSON & CO COVINGTON OPERATIONS
# 2661788                             COSMED OF PENNSYLVANIA
# 2662031                                BAKER PETROLITE LLC
# 2662084     VIANT MEDICAL INC VIANT STERILIZATION SERVICES
# ...                                                    ...
# 2738248                       KENDALL PATIENT RECOVERY LLC
# 2738259                                ETHOX CHEMICALS LLC
# 2738280                                TATE & LYLE DECATUR
# 2738555                          HERITAGE THERMAL SERVICES
# 2738915                                        ETHICON INC
#
#                  STREET_ADDRESS            CITY            COUNTY  ST    ZIP  \
# 2661062  2201 OLD SPANISH TRAIL        WESTLAKE  CALCASIEU PARISH  LA  70669
# 2661163    8195 INDUSTRIAL BLVD       COVINGTON            NEWTON  GA  30014
# 2661788          2205 E 33RD ST            ERIE              ERIE  PA  16510
# 2662031          9100 W 21ST ST    SAND SPRINGS             TULSA  OK  74063
# 2662084        520 WATSON ST SW    GRAND RAPIDS              KENT  MI  49504
# ...                         ...             ...               ...  ..    ...
# 2738248  1430 MARVIN GRIFFIN RD         AUGUSTA          RICHMOND  GA  30906
# 2738259       1801 PERIMETER RD      GREENVILLE        GREENVILLE  SC  29605
# 2738280      2200 E ELDORADO ST         DECATUR             MACON  IL  62521
# 2738555       1250 ST GEORGE ST  EAST LIVERPOOL        COLUMBIANA  OH  43920
# 2738915         3348 PULLIAM ST      SAN ANGELO         TOM GREEN  TX  76905
#
#          BIA TRIBE  LATITUDE  LONGITUDE              INDUSTRY_SECTOR  \
# 2661062  nan   NaN  30.25880  -93.29370                    Chemicals
# 2661163  nan   NaN  33.60820  -83.83960  Miscellaneous Manufacturing
# 2661788  nan   NaN  42.12398  -80.02186  Miscellaneous Manufacturing
# 2662031  nan   NaN  36.12999  -96.09903                    Chemicals
# 2662084  nan   NaN  42.96175  -85.68245  Miscellaneous Manufacturing
# ...      ...   ...       ...        ...                          ...
# 2738248  nan   NaN  33.39440  -81.98460  Miscellaneous Manufacturing
# 2738259  nan   NaN  34.73447  -82.37562                    Chemicals
# 2738280  nan   NaN  39.84995  -88.92346                         Food
# 2738555  nan   NaN  40.63162  -80.54632              Hazardous Waste
# 2738915  nan   NaN  31.47232 -100.38830  Miscellaneous Manufacturing
#
#                                PARENT_CO_NAME        CHEMICAL   WATER  \
# 2661062                      SASOL (USA) CORP  ETHYLENE OXIDE 0.00000
# 2661163                 BECTON DICKINSON & CO  ETHYLENE OXIDE 0.00000
# 2661788                      COSMED GROUP INC  ETHYLENE OXIDE 0.00000
# 2662031              BAKER HUGHES A GE CO LLC  ETHYLENE OXIDE 0.00000
# 2662084                     VIANT MEDICAL LLC  ETHYLENE OXIDE 0.00000
# ...                                       ...             ...     ...
# 2738248                   CARDINAL HEALTH INC  ETHYLENE OXIDE 0.00000
# 2738259      PIEDMONT CHEMICAL INDUSTRIES INC  ETHYLENE OXIDE 0.00000
# 2738280  TATE & LYLE INGREDIENTS AMERICAS LLC  ETHYLENE OXIDE 0.00000
# 2738555                      HERITAGE-WTI LLC  ETHYLENE OXIDE 0.00000
# 2738915                     JOHNSON & JOHNSON  ETHYLENE OXIDE 0.00000
#
#          ON_SITE_RELEASE_TOTAL        AIR UNIT_OF_MEASURE
# 2661062             2237.00000 2237.00000          Pounds
# 2661163              656.30000  656.30000          Pounds
# 2661788              293.00000  293.00000          Pounds
# 2662031                9.00000    9.00000          Pounds
# 2662084              378.39000  378.39000          Pounds
# ...                        ...        ...             ...
# 2738248              259.00000  259.00000          Pounds
# 2738259               11.30000   11.30000          Pounds
# 2738280              239.00000  239.00000          Pounds
# 2738555                0.00302    0.00302          Pounds
# 2738915             1010.00000 1010.00000          Pounds
#
# [109 rows x 19 columns]

# %%
# cast lat/long columns to float
ethylene['LATITUDE'] = ethylene['LATITUDE'].astype(float)
ethylene['LONGITUDE'] = ethylene['LONGITUDE'].astype(float)

# create geodataframe using Latitude and Longitude columns
gdf = gpd.GeoDataFrame(ethylene, geometry=gpd.points_from_xy(ethylene.LONGITUDE, ethylene.LATITUDE))

# define crs for geodataframe
gdf.crs = {'init' :'epsg:4326'}

gdf.head()
# Out:
#          YEAR            TRIFD  \
# 2661062  2018  70669VSTCHOLDSP
# 2661163  2018  30209CRBRD8195N
# 2661788  2018  16510MDCLM2205E
# 2662031  2018  74063CHMLN9100W
# 2662084  2018  49504STRLS520WA
#
#                                              FACILITY_NAME  \
# 2661062  SASOL CHEMICALS (USA) LLC-LAKE CHARLES CHEMICA...
# 2661163         BECTON DICKINSON & CO COVINGTON OPERATIONS
# 2661788                             COSMED OF PENNSYLVANIA
# 2662031                                BAKER PETROLITE LLC
# 2662084     VIANT MEDICAL INC VIANT STERILIZATION SERVICES
#
#                  STREET_ADDRESS          CITY            COUNTY  ST    ZIP  \
# 2661062  2201 OLD SPANISH TRAIL      WESTLAKE  CALCASIEU PARISH  LA  70669
# 2661163    8195 INDUSTRIAL BLVD     COVINGTON            NEWTON  GA  30014
# 2661788          2205 E 33RD ST          ERIE              ERIE  PA  16510
# 2662031          9100 W 21ST ST  SAND SPRINGS             TULSA  OK  74063
# 2662084        520 WATSON ST SW  GRAND RAPIDS              KENT  MI  49504
#
#          BIA TRIBE  LATITUDE  LONGITUDE              INDUSTRY_SECTOR  \
# 2661062  nan   NaN  30.25880  -93.29370                    Chemicals
# 2661163  nan   NaN  33.60820  -83.83960  Miscellaneous Manufacturing
# 2661788  nan   NaN  42.12398  -80.02186  Miscellaneous Manufacturing
# 2662031  nan   NaN  36.12999  -96.09903                    Chemicals
# 2662084  nan   NaN  42.96175  -85.68245  Miscellaneous Manufacturing
#
#                    PARENT_CO_NAME        CHEMICAL   WATER  \
# 2661062          SASOL (USA) CORP  ETHYLENE OXIDE 0.00000
# 2661163     BECTON DICKINSON & CO  ETHYLENE OXIDE 0.00000
# 2661788          COSMED GROUP INC  ETHYLENE OXIDE 0.00000
# 2662031  BAKER HUGHES A GE CO LLC  ETHYLENE OXIDE 0.00000
# 2662084         VIANT MEDICAL LLC  ETHYLENE OXIDE 0.00000
#
#          ON_SITE_RELEASE_TOTAL        AIR UNIT_OF_MEASURE  \
# 2661062             2237.00000 2237.00000          Pounds
# 2661163              656.30000  656.30000          Pounds
# 2661788              293.00000  293.00000          Pounds
# 2662031                9.00000    9.00000          Pounds
# 2662084              378.39000  378.39000          Pounds
#
#                            geometry
# 2661062  POINT (-93.29370 30.25880)
# 2661163  POINT (-83.83960 33.60820)
# 2661788  POINT (-80.02186 42.12398)
# 2662031  POINT (-96.09903 36.12999)
# 2662084  POINT (-85.68245 42.96175)

# %%
# export geodataframe to geojson
gdf.to_file("../data/ethylene-facilities.geojson", driver='GeoJSON', encoding='utf-8')
