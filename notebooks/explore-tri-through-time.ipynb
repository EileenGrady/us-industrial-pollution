# %% [markdown]
# # Explore TRI facility releases over time
#
# I want to explore trends over time. I downloaded each [TRI basic data file](https://www.epa.gov/toxics-release-inventory-tri-program/tri-basic-data-files-calendar-years-1987-2018) for the US for all years available, 1987-2018 to retrieve facility location information and release amounts.

# %%
# import packages
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from shapely.geometry import Polygon
from shapely.geometry import mapping
from functools import reduce
import os
import re
import numpy as np
import jenkspy

import warnings
warnings.simplefilter(action='ignore')

# supress scientific notation
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %% [markdown]
# ## Wrangle TRI facility location information
#
# First I want to combine all the TRI data files for each year into one dataframe.

# %%
# define folder containing all tri files
folder = "../data/tri-data"

# create empty list to hold dataframes
fileList = list()

# add each file to the dataframe list
for file in os.listdir(folder):
    df = pd.read_csv(os.path.join(folder, file))
    fileList.append(df)
    
# concatenate all list of dataframes
combined = pd.concat(fileList, axis=0, ignore_index=True)
combined
# Out:
#          1. YEAR         2. TRIFD     3. FRS ID  \
# 0           1987  94304QLTYT3400H  110000609887
# 1           1987  45377NLNDD480ND  110000394467
# 2           1987  27215PRKVN1821N  110043582101
# 3           1987  70058VNSCP1255P  110000448757
# 4           1987  55425VTCNC2401E  110002123158
# ...          ...              ...           ...
# 2739472     2018  42366PRMML5680O  110000380971
# 2739473     2018  37066STVGL1499S  110000493136
# 2739474     2018  6416WPNNYS861NE  110020834276
# 2739475     2018  46368BTSTL6500S  110000398212
# 2739476     2018  63115KLLRK3940M  110001452357
#
#                                     4. FACILITY NAME  \
# 0                                       QUALITY TECH
# 1        DELPHI ENERGY & CHASSIS VANDALIA OPERATIONS
# 2                   GLEN RAVEN TECHNICAL FABRICS LLC
# 3            GREIF USA (DBA GREIF HARVEY DCS HARVEY)
# 4                                VTC INC RIVER RIDGE
# ...                                              ...
# 2739472                          HINES PRECISION INC
# 2739473                 US TVA GALLATIN FOSSIL PLANT
# 2739474                              PENNYS CONCRETE
# 2739475                                 NLMK INDIANA
# 2739476                                      KILLARK
#
#                   5. STREET ADDRESS      6. CITY         7. COUNTY 8. ST  \
# 0                 3400 HILLVIEW AVE    PALO ALTO       SANTA CLARA    CA
# 1                    480 N DIXIE DR     VANDALIA        MONTGOMERY    OH
# 2                   1821 N PARK AVE   BURLINGTON          ALAMANCE    NC
# 3                    1255 PETERS RD       HARVEY  JEFFERSON PARISH    LA
# 4                    2401 E 28TH ST  BLOOMINGTON          HENNEPIN    MN
# ...                             ...          ...               ...   ...
# 2739472              5680 OLD KY 54      PHILPOT           DAVIESS    KY
# 2739473         1499 STEAM PLANT RD     GALLATIN            SUMNER    TN
# 2739474         8601 NE 38TH STREET  KANSAS CITY              CLAY    MO
# 2739475          6500 S BOUNDARY RD      PORTAGE            PORTER    IN
# 2739476  3940 MARTIN LUTHER KING DR  SAINT LOUIS   ST LOUIS (CITY)    MO
#
#         9. ZIP  10. BIA  ... 107. 8.3 - ENERGY RECOVER OF  \
# 0        94304      nan  ...                      0.00000
# 1        45377      nan  ...                      0.00000
# 2        27217      nan  ...                      0.00000
# 3        70058      nan  ...                      0.00000
# 4        55425      nan  ...                      0.00000
# ...        ...      ...  ...                          ...
# 2739472  42366      nan  ...                      0.00000
# 2739473  37066      nan  ...                      0.00000
# 2739474  64161      nan  ...                      0.00000
# 2739475  46368      nan  ...                      0.00000
# 2739476  63113      nan  ...                      0.00000
#
#          108. 8.4 - RECYCLING ON SITE  109. 8.5 - RECYCLING OFF SIT  \
# 0                             0.00000                       0.00000
# 1                             0.00000                       0.00000
# 2                             0.00000                       0.00000
# 3                             0.00000                       0.00000
# 4                             0.00000                       0.00000
# ...                               ...                           ...
# 2739472                       0.00000                       0.00000
# 2739473                       0.00000                       0.00000
# 2739474                       0.00000                       0.00000
# 2739475                       0.00000                   53429.00000
# 2739476                       0.00000                       0.00000
#
#         110. 8.6 - TREATMENT ON SITE 111. 8.7 - TREATMENT OFF SITE  \
# 0                            0.00000                       0.00000
# 1                            0.00000                       0.00000
# 2                            0.00000                       0.00000
# 3                            0.00000                       0.00000
# 4                            0.00000                       0.00000
# ...                              ...                           ...
# 2739472                      0.00000                       0.00000
# 2739473                      0.00000                       0.00000
# 2739474                      0.00000                       0.00000
# 2739475                      0.00000                       0.00000
# 2739476                      0.00000                       0.00000
#
#         112. PRODUCTION WSTE (8.1-8.7) 113. 8.8 - ONE-TIME RELEASE  \
# 0                              0.00000                         nan
# 1                              0.00000                         nan
# 2                              0.00000                         nan
# 3                              0.00000                         nan
# 4                              0.00000                         nan
# ...                                ...                         ...
# 2739472                        0.00000                         nan
# 2739473                        9.40000                         nan
# 2739474                        0.00000                         nan
# 2739475                    53752.12000                         nan
# 2739476                        0.00000                         nan
#
#          114. PROD_RATIO_OR_ ACTIVITY 115. 8.9 - PRODUCTION RATIO Unnamed: 115
# 0                                 NaN                         nan          nan
# 1                                 NaN                         nan          nan
# 2                                 NaN                         nan          nan
# 3                                 NaN                         nan          nan
# 4                                 NaN                         nan          nan
# ...                               ...                         ...          ...
# 2739472                           NaN                         nan          nan
# 2739473                    PRODUCTION                     0.98000          nan
# 2739474                      ACTIVITY                     1.00000          nan
# 2739475                    PRODUCTION                     1.00000          nan
# 2739476                    PRODUCTION                     1.03000          nan
#
# [2739477 rows x 116 columns]

# %%
# create copy to revert back to
tri = combined.copy()

# %%
# clean up column names
# remove leading numbers, periods, and space and from column names
tri.columns = tri.columns.str.lstrip('0123456789.- ')

# replace spaces in column names with underscores
tri.columns = tri.columns.str.replace(' ', '_')

# replace dashes in column names with underscores
tri.columns = tri.columns.str.replace('-', '_')

#convert column names to uppercase
tri.columns = map(str.upper, tri.columns)

tri.head()
# Out:
#    YEAR            TRIFD        FRS_ID  \
# 0  1987  94304QLTYT3400H  110000609887
# 1  1987  45377NLNDD480ND  110000394467
# 2  1987  27215PRKVN1821N  110043582101
# 3  1987  70058VNSCP1255P  110000448757
# 4  1987  55425VTCNC2401E  110002123158
#
#                                  FACILITY_NAME     STREET_ADDRESS  \
# 0                                 QUALITY TECH  3400 HILLVIEW AVE
# 1  DELPHI ENERGY & CHASSIS VANDALIA OPERATIONS     480 N DIXIE DR
# 2             GLEN RAVEN TECHNICAL FABRICS LLC    1821 N PARK AVE
# 3      GREIF USA (DBA GREIF HARVEY DCS HARVEY)     1255 PETERS RD
# 4                          VTC INC RIVER RIDGE     2401 E 28TH ST
#
#           CITY            COUNTY  ST    ZIP  BIA  ... ENERGY_RECOVER_OF  \
# 0    PALO ALTO       SANTA CLARA  CA  94304  nan  ...           0.00000
# 1     VANDALIA        MONTGOMERY  OH  45377  nan  ...           0.00000
# 2   BURLINGTON          ALAMANCE  NC  27217  nan  ...           0.00000
# 3       HARVEY  JEFFERSON PARISH  LA  70058  nan  ...           0.00000
# 4  BLOOMINGTON          HENNEPIN  MN  55425  nan  ...           0.00000
#
#    RECYCLING_ON_SITE  RECYCLING_OFF_SIT TREATMENT_ON_SITE TREATMENT_OFF_SITE  \
# 0            0.00000            0.00000           0.00000            0.00000
# 1            0.00000            0.00000           0.00000            0.00000
# 2            0.00000            0.00000           0.00000            0.00000
# 3            0.00000            0.00000           0.00000            0.00000
# 4            0.00000            0.00000           0.00000            0.00000
#
#   PRODUCTION_WSTE_(8.1_8.7) ONE_TIME_RELEASE  PROD_RATIO_OR__ACTIVITY  \
# 0                   0.00000              nan                      NaN
# 1                   0.00000              nan                      NaN
# 2                   0.00000              nan                      NaN
# 3                   0.00000              nan                      NaN
# 4                   0.00000              nan                      NaN
#
#   PRODUCTION_RATIO UNNAMED:_115
# 0              nan          nan
# 1              nan          nan
# 2              nan          nan
# 3              nan          nan
# 4              nan          nan
#
# [5 rows x 116 columns]

# %%
# view list of all columns
list(tri.columns)
# Out:
# ['YEAR',
#  'TRIFD',
#  'FRS_ID',
#  'FACILITY_NAME',
#  'STREET_ADDRESS',
#  'CITY',
#  'COUNTY',
#  'ST',
#  'ZIP',
#  'BIA',
#  'TRIBE',
#  'LATITUDE',
#  'LONGITUDE',
#  'PARENT_CO_NAME',
#  'PARENT_CO_DB_NUM',
#  'STANDARD_PARENT_CO_NAME',
#  'FEDERAL_FACILITY',
#  'INDUSTRY_SECTOR_CODE',
#  'INDUSTRY_SECTOR',
#  'PRIMARY_SIC',
#  'SIC_2',
#  'SIC_3',
#  'SIC_4',
#  'SIC_5',
#  'SIC_6',
#  'PRIMARY_NAICS',
#  'NAICS_2',
#  'NAICS_3',
#  'NAICS_4',
#  'NAICS_5',
#  'NAICS_6',
#  'DOC_CTRL_NUM',
#  'CHEMICAL',
#  'ELEMENTAL_METAL_INCLUDED',
#  'CAS_#/COMPOUND_ID',
#  'SRS_ID',
#  'CLEAN_AIR_ACT_CHEMICAL',
#  'CLASSIFICATION',
#  'METAL',
#  'METAL_CATEGORY',
#  'CARCINOGEN',
#  'FORM_TYPE',
#  'UNIT_OF_MEASURE',
#  'FUGITIVE_AIR',
#  'STACK_AIR',
#  'WATER',
#  'UNDERGROUND',
#  'UNDERGROUND_CL_I',
#  'UNDERGROUND_C_II_V',
#  'LANDFILLS',
#  'A___RCRA_C_LANDFILL',
#  'B___OTHER_LANDFILLS',
#  'LAND_TREATMENT',
#  'SURFACE_IMPNDMNT',
#  'A___RCRA_SURFACE_IM',
#  'B___OTHER_SURFACE_I',
#  'OTHER_DISPOSAL',
#  'ON_SITE_RELEASE_TOTAL',
#  'POTW___TRNS_RLSE',
#  'POTW___TRNS_TRT',
#  'POTW___TOTAL_TRANSFERS',
#  'M10',
#  'M41',
#  'M62',
#  'M40_METAL',
#  'M61_METAL',
#  'M71',
#  'M81',
#  'M82',
#  'M72',
#  'M63',
#  'M66',
#  'M67',
#  'M64',
#  'M65',
#  'M73',
#  'M79',
#  'M90',
#  'M94',
#  'M99',
#  'OFF_SITE_RELEASE_TOTAL',
#  'M20',
#  'M24',
#  'M26',
#  'M28',
#  'M93',
#  'OFF_SITE_RECYCLED_TOTAL',
#  'M56',
#  'M92',
#  'OFF_SITE_ENERGY_RECOVERY_T',
#  'M40_NON_METAL',
#  'M50',
#  'M54',
#  'M61_NON_METAL',
#  'M69',
#  'M95',
#  'OFF_SITE_TREATED_TOTAL',
#  'UNCLASSIFIED',
#  'TOTAL_TRANSFER',
#  'TOTAL_RELEASES',
#  'RELEASES',
#  'A___ON_SITE_CONTAINED',
#  'B___ON_SITE_OTHER_',
#  'C___OFF_SITE_CONTAIN',
#  'D___OFF_SITE_OTHER_R',
#  'ENERGY_RECOVER_ON',
#  'ENERGY_RECOVER_OF',
#  'RECYCLING_ON_SITE',
#  'RECYCLING_OFF_SIT',
#  'TREATMENT_ON_SITE',
#  'TREATMENT_OFF_SITE',
#  'PRODUCTION_WSTE_(8.1_8.7)',
#  'ONE_TIME_RELEASE',
#  'PROD_RATIO_OR__ACTIVITY',
#  'PRODUCTION_RATIO',
#  'UNNAMED:_115']

# %% [markdown]
# I consulted [TRI basic data files documentation](https://www.epa.gov/sites/production/files/2019-08/documents/basic_data_files_documentation_aug_2019_v2.pdf) to understand what each column actually represents.
#
# On-site release total = Total quantity of the toxic chemical released to air, water and
# land on-site at the facility.
#
# Off-site release total = Total quantity of the toxic chemical reported as transferred to
# off-site locations for release or disposal.
#
# There are several columns for various types of land release, and they vary by year as reporting changed in 1996 and 2003. Water and air release columns are consistent for each year, so for now I will just stick with on-site release totals and air and water releases. I will not look at off-site releases, because waste can be double counted if counted once by facility as off-site release, and then again by the receiving facility as on-site release.
#
# Ultimately I want one record per facility, with columns for on-site release totals, plus release totals for water and air release, for each year. There is only one column for water release, and air releases are reported by fugitive and stack. Most chemicals are reported in pounds, except for dioxides which are reported in grams. So before any aggregating I also need to convert records measured in grams into pounds.

# %% [markdown]
# ## Create air release column, convert releases measured in grams into pounds

# %%
# create new column summing fugitive air and stack air release
tri['AIR'] = tri['FUGITIVE_AIR'] + tri['STACK_AIR']

# %%
# filter columns to keep
tri_filter = tri.filter(['YEAR','TRIFD','FACILITY_NAME','STREET_ADDRESS','CITY','COUNTY','ST','ZIP','BIA','TRIBE','LATITUDE','LONGITUDE','INDUSTRY_SECTOR','PARENT_CO_NAME', 'CHEMICAL', 'WATER','ON_SITE_RELEASE_TOTAL','AIR','UNIT_OF_MEASURE'], axis=1)
tri_filter.head()
# Out:
#    YEAR            TRIFD                                FACILITY_NAME  \
# 0  1987  94304QLTYT3400H                                 QUALITY TECH
# 1  1987  45377NLNDD480ND  DELPHI ENERGY & CHASSIS VANDALIA OPERATIONS
# 2  1987  27215PRKVN1821N             GLEN RAVEN TECHNICAL FABRICS LLC
# 3  1987  70058VNSCP1255P      GREIF USA (DBA GREIF HARVEY DCS HARVEY)
# 4  1987  55425VTCNC2401E                          VTC INC RIVER RIDGE
#
#       STREET_ADDRESS         CITY            COUNTY  ST    ZIP  BIA TRIBE  \
# 0  3400 HILLVIEW AVE    PALO ALTO       SANTA CLARA  CA  94304  nan   NaN
# 1     480 N DIXIE DR     VANDALIA        MONTGOMERY  OH  45377  nan   NaN
# 2    1821 N PARK AVE   BURLINGTON          ALAMANCE  NC  27217  nan   NaN
# 3     1255 PETERS RD       HARVEY  JEFFERSON PARISH  LA  70058  nan   NaN
# 4     2401 E 28TH ST  BLOOMINGTON          HENNEPIN  MN  55425  nan   NaN
#
#    LATITUDE  LONGITUDE                    INDUSTRY_SECTOR  \
# 0  37.40348 -122.14600  Computers and Electronic Products
# 1  39.90040  -84.19882           Transportation Equipment
# 2  36.10932  -79.46178                           Textiles
# 3  29.88758  -90.07416                  Fabricated Metals
# 4  44.95979  -93.23143  Computers and Electronic Products
#
#                      PARENT_CO_NAME  \
# 0                      QUALITY TECH
# 1     DELPHI AUTOMOTIVE SYSTEMS LLC
# 2  GLEN RAVEN TECHNICAL FABRICS LLC
# 3                         GREIF USA
# 4                 CONTROL DATA CORP
#
#                                             CHEMICAL   WATER  \
# 0                                    PHOSPHORIC ACID 0.00000
# 1  SULFURIC ACID (1994 AND AFTER ACID AEROSOLS" O... 0.00000
# 2                        AMMONIUM SULFATE (SOLUTION) 0.00000
# 3                          N-NITROSODI-N-PROPYLAMINE 0.00000
# 4  SULFURIC ACID (1994 AND AFTER ACID AEROSOLS" O... 0.00000
#
#    ON_SITE_RELEASE_TOTAL        AIR UNIT_OF_MEASURE
# 0              250.00000  250.00000          Pounds
# 1                0.00000    0.00000          Pounds
# 2                0.00000    0.00000          Pounds
# 3             2700.00000 2700.00000          Pounds
# 4                0.00000    0.00000          Pounds

# %%
# inspect the different units of measure
tri_filter['UNIT_OF_MEASURE'].unique()
# Out:
# array(['Pounds', 'Grams'], dtype=object)

# %% [markdown]
# My method for converting grams to pounds is to first create a subset of records measured in grams. Then for this subset I will convert grams to pounds, and calculate the unit of measure to pounds. Then after appending this converted subset back to the original dataframe, I will drop any records measured in grams.

# %%
# filter all records measured in grams
grams = tri_filter.loc[tri_filter['UNIT_OF_MEASURE'] == 'Grams']

# convert gram measure to pounds
grams['ON_SITE_RELEASE_TOTAL'] = grams['ON_SITE_RELEASE_TOTAL']/454
grams['WATER'] = grams['WATER']/454
grams['AIR'] = grams['AIR']/454

# change unit of measure to pounds
grams['UNIT_OF_MEASURE'] = 'Pounds'

# check results
grams
# Out:
#          YEAR            TRIFD                             FACILITY_NAME  \
# 960756   1998  95017RMCPC700HW           RMC PACIFIC MATERIALS DBA CEMEX
# 1009938  1999  95017RMCPC700HW           RMC PACIFIC MATERIALS DBA CEMEX
# 1058622  1999  46302XDCRP2601W                        EXIDE TECHNOLOGIES
# 1086371  2000  71411WLLMTHIGHW      INTERNATIONAL PAPER / RED RIVER MILL
# 1086534  2000  16531GNRLL2901E                  GE TRANSPORTATION - ERIE
# ...       ...              ...                                       ...
# 2739119  2018  37716STVBL1265E              US TVA BULL RUN FOSSIL PLANT
# 2739221  2018  36548CHRLSCARSO              CHARLES R LOWMAN POWER PLANT
# 2739320  2018  84116CHVRN2351N  CHEVRON PRODUCTS CO - SALT LAKE REFINERY
# 2739400  2018  9852WSPBRD31HAG                 SPI ABERDEEN-GRAYS HARBOR
# 2739429  2018  49855PRSQS2701L                  PRESQUE ISLE POWER PLANT
#
#                      STREET_ADDRESS            CITY               COUNTY  ST  \
# 960756                700 HIGHWAY 1       DAVENPORT           SANTA CRUZ  CA
# 1009938               700 HIGHWAY 1       DAVENPORT           SANTA CRUZ  CA
# 1058622  2601 W MOUNT PLEASANT BLVD          MUNCIE             DELAWARE  IN
# 1086371                4537 HWY 480          CAMPTI  NATCHITOCHES PARISH  LA
# 1086534              2901 E LAKE RD            ERIE                 ERIE  PA
# ...                             ...             ...                  ...  ..
# 2739119            1265 EDGEMOOR RD         CLINTON             ANDERSON  TN
# 2739221              4392 CARSON RD           LEROY           WASHINGTON  AL
# 2739320        2351 NORTH 1100 WEST  SALT LAKE CITY            SALT LAKE  UT
# 2739400               301 HAGARA ST        ABERDEEN         GRAYS HARBOR  WA
# 2739429         2701 LAKESHORE BLVD       MARQUETTE            MARQUETTE  MI
#
#            ZIP  BIA TRIBE  LATITUDE  LONGITUDE              INDUSTRY_SECTOR  \
# 960756   95017  nan   NaN  37.01563 -122.19902  Nonmetallic Mineral Product
# 1009938  95017  nan   NaN  37.01563 -122.19902  Nonmetallic Mineral Product
# 1058622  47302  nan   NaN  40.15696  -85.41742               Primary Metals
# 1086371  71411  nan   NaN  31.90533  -93.17364                        Paper
# 1086534  16531  nan   NaN  42.14545  -80.02544     Transportation Equipment
# ...        ...  ...   ...       ...        ...                          ...
# 2739119  37716  nan   NaN  36.02280  -84.15180           Electric Utilities
# 2739221  36548  nan   NaN  31.48870  -87.91030           Electric Utilities
# 2739320  84116  nan   NaN  40.82490 -111.92380                    Petroleum
# 2739400  98520  nan   NaN  46.97306 -123.77805                Wood Products
# 2739429  49855  nan   NaN  46.57917  -87.39613           Electric Utilities
#
#                         PARENT_CO_NAME                          CHEMICAL  \
# 960756                           CEMEX  DIOXIN AND DIOXIN-LIKE COMPOUNDS
# 1009938                          CEMEX  DIOXIN AND DIOXIN-LIKE COMPOUNDS
# 1058622             EXIDE TECHNOLOGIES  DIOXIN AND DIOXIN-LIKE COMPOUNDS
# 1086371         INTERNATIONAL PAPER CO  DIOXIN AND DIOXIN-LIKE COMPOUNDS
# 1086534            WABTEC US RAIL INC.  DIOXIN AND DIOXIN-LIKE COMPOUNDS
# ...                                ...                               ...
# 2739119  US TENNESSEE VALLEY AUTHORITY  DIOXIN AND DIOXIN-LIKE COMPOUNDS
# 2739221  POWERSOUTH ENERGY COOPERATIVE  DIOXIN AND DIOXIN-LIKE COMPOUNDS
# 2739320                   CHEVRON CORP  DIOXIN AND DIOXIN-LIKE COMPOUNDS
# 2739400      SIERRA PACIFIC INDUSTRIES  DIOXIN AND DIOXIN-LIKE COMPOUNDS
# 2739429               WEC ENERGY GROUP  DIOXIN AND DIOXIN-LIKE COMPOUNDS
#
#           WATER  ON_SITE_RELEASE_TOTAL     AIR UNIT_OF_MEASURE
# 960756  0.00000                0.00047 0.00047          Pounds
# 1009938 0.00000                0.00050 0.00050          Pounds
# 1058622 0.00000                0.00220 0.00220          Pounds
# 1086371 0.00000                0.00137 0.00126          Pounds
# 1086534 0.00000                0.00070 0.00070          Pounds
# ...         ...                    ...     ...             ...
# 2739119 0.00000                0.00062 0.00062          Pounds
# 2739221 0.00000                0.00053 0.00053          Pounds
# 2739320 0.00002                0.00002 0.00000          Pounds
# 2739400 0.00000                0.00163 0.00163          Pounds
# 2739429 0.00000                0.00088 0.00088          Pounds
#
# [21529 rows x 19 columns]

# %%
# append converted records back to tri dataframe
tri_filter.append(grams)

# redefine tri_filter dataframe as records measured in pounds
tri_filter = tri_filter[tri_filter['UNIT_OF_MEASURE'] == 'Pounds']

tri_filter
# Out:
#          YEAR            TRIFD                                FACILITY_NAME  \
# 0        1987  94304QLTYT3400H                                 QUALITY TECH
# 1        1987  45377NLNDD480ND  DELPHI ENERGY & CHASSIS VANDALIA OPERATIONS
# 2        1987  27215PRKVN1821N             GLEN RAVEN TECHNICAL FABRICS LLC
# 3        1987  70058VNSCP1255P      GREIF USA (DBA GREIF HARVEY DCS HARVEY)
# 4        1987  55425VTCNC2401E                          VTC INC RIVER RIDGE
# ...       ...              ...                                          ...
# 2739472  2018  42366PRMML5680O                          HINES PRECISION INC
# 2739473  2018  37066STVGL1499S                 US TVA GALLATIN FOSSIL PLANT
# 2739474  2018  6416WPNNYS861NE                              PENNYS CONCRETE
# 2739475  2018  46368BTSTL6500S                                 NLMK INDIANA
# 2739476  2018  63115KLLRK3940M                                      KILLARK
#
#                      STREET_ADDRESS         CITY            COUNTY  ST    ZIP  \
# 0                 3400 HILLVIEW AVE    PALO ALTO       SANTA CLARA  CA  94304
# 1                    480 N DIXIE DR     VANDALIA        MONTGOMERY  OH  45377
# 2                   1821 N PARK AVE   BURLINGTON          ALAMANCE  NC  27217
# 3                    1255 PETERS RD       HARVEY  JEFFERSON PARISH  LA  70058
# 4                    2401 E 28TH ST  BLOOMINGTON          HENNEPIN  MN  55425
# ...                             ...          ...               ...  ..    ...
# 2739472              5680 OLD KY 54      PHILPOT           DAVIESS  KY  42366
# 2739473         1499 STEAM PLANT RD     GALLATIN            SUMNER  TN  37066
# 2739474         8601 NE 38TH STREET  KANSAS CITY              CLAY  MO  64161
# 2739475          6500 S BOUNDARY RD      PORTAGE            PORTER  IN  46368
# 2739476  3940 MARTIN LUTHER KING DR  SAINT LOUIS   ST LOUIS (CITY)  MO  63113
#
#          BIA TRIBE  LATITUDE  LONGITUDE                    INDUSTRY_SECTOR  \
# 0        nan   NaN  37.40348 -122.14600  Computers and Electronic Products
# 1        nan   NaN  39.90040  -84.19882           Transportation Equipment
# 2        nan   NaN  36.10932  -79.46178                           Textiles
# 3        nan   NaN  29.88758  -90.07416                  Fabricated Metals
# 4        nan   NaN  44.95979  -93.23143  Computers and Electronic Products
# ...      ...   ...       ...        ...                                ...
# 2739472  nan   NaN  37.73491  -87.00282                  Fabricated Metals
# 2739473  nan   NaN  36.32460  -86.40260                 Electric Utilities
# 2739474  nan   NaN  39.16218  -94.48128        Nonmetallic Mineral Product
# 2739475  nan   NaN  41.62152  -87.16148                     Primary Metals
# 2739476  nan   NaN  38.65141  -90.23342               Electrical Equipment
#
#                            PARENT_CO_NAME  \
# 0                            QUALITY TECH
# 1           DELPHI AUTOMOTIVE SYSTEMS LLC
# 2        GLEN RAVEN TECHNICAL FABRICS LLC
# 3                               GREIF USA
# 4                       CONTROL DATA CORP
# ...                                   ...
# 2739472                               NaN
# 2739473     US TENNESSEE VALLEY AUTHORITY
# 2739474                   PENNYS CONCRETE
# 2739475                               NaN
# 2739476                       HUBBELL INC
#
#                                                   CHEMICAL   WATER  \
# 0                                          PHOSPHORIC ACID 0.00000
# 1        SULFURIC ACID (1994 AND AFTER ACID AEROSOLS" O... 0.00000
# 2                              AMMONIUM SULFATE (SOLUTION) 0.00000
# 3                                N-NITROSODI-N-PROPYLAMINE 0.00000
# 4        SULFURIC ACID (1994 AND AFTER ACID AEROSOLS" O... 0.00000
# ...                                                    ...     ...
# 2739472                                           CHROMIUM 0.00000
# 2739473                      POLYCYCLIC AROMATIC COMPOUNDS 0.00000
# 2739474                                  NITRATE COMPOUNDS 0.00000
# 2739475                                             COPPER 5.92000
# 2739476                                      DIISOCYANATES 0.00000
#
#          ON_SITE_RELEASE_TOTAL        AIR UNIT_OF_MEASURE
# 0                    250.00000  250.00000          Pounds
# 1                      0.00000    0.00000          Pounds
# 2                      0.00000    0.00000          Pounds
# 3                   2700.00000 2700.00000          Pounds
# 4                      0.00000    0.00000          Pounds
# ...                        ...        ...             ...
# 2739472                0.00000    0.00000          Pounds
# 2739473                9.40000    3.70000          Pounds
# 2739474                0.00000    0.00000          Pounds
# 2739475                6.02000    0.10000          Pounds
# 2739476                0.00000    0.00000          Pounds
#
# [2717948 rows x 19 columns]

# %%
# export tri filter dataframe to csv 
# will use this to explore specific chemicals in another notebook
tri_filter.to_csv("../../all_tri_records.csv")

# %% [markdown]
# ## Wrangle data to get total releases per year

# %%
# now reduce filtered dataframe to find one record per facility
# use group by TRIFID field, and only keep the identifying fields about each facility
# will use this to join to after performing pivot table operations
all_tri = tri_filter.fillna('').groupby('TRIFD').agg({'FACILITY_NAME':'first',
                             'STREET_ADDRESS':'first',
                             'CITY':'first',
                             'COUNTY':'first',
                             'ST':'first',
                             'ZIP':'first',
                             'BIA':'first',
                             'TRIBE':'first',
                             'LATITUDE':'first',
                             'LONGITUDE':'first',
                             'INDUSTRY_SECTOR':'first',
                             'PARENT_CO_NAME': 'first'
                                               }).reset_index()

all_tri
# Out:
#                  TRIFD                                 FACILITY_NAME  \
# 0      00602BXTRF111CO            BAXTER HEALTHCARE CORP, FENWAL DIV
# 1      00602BXTRHRD115                    DADE DIAGNOSTICS OF PR INC
# 2      00602DSCFPPOBOA                 DSC OF PUERTO RICO INC BLDG 9
# 3      00602DSCFPPOBOX                 DSC OF PUERTO RICO INC BLDG 1
# 4      00602GRNGRAGUAD                 DSC OF PUERTO RICO INC BLDG 8
# ...                ...                                           ...
# 60523  99901LSKSH381TN                                  VIGOR ALASKA
# 60524  99901SCSTG1300S                 US COAST GUARD BASE KETCHIKAN
# 60525  99901TSRLS1010S          TESORO ALASKA CO. KETCHIKAN TERMINAL
# 60526  9990WCRWLY9STED  CROWLEY KETCHIKAN BULK FUEL STORAGE FACILITY
# 60527  99929TRDNT641SH                              TRIDENT SEAFOODS
#
#                     STREET_ADDRESS       CITY                     COUNTY  ST  \
# 0                     111 COLON ST     AGUADA           AGUADA MUNICIPIO  PR
# 1                    RD 115 KM 226     AGUADA           AGUADA MUNICIPIO  PR
# 2                W INDUSTRIAL SITE     AGUADA           AGUADA MUNICIPIO  PR
# 3      AGUADA WEST INDUSTRIAL SITE     AGUADA           AGUADA MUNICIPIO  PR
# 4                W INDUSTRIAL SITE     AGUADA           AGUADA MUNICIPIO  PR
# ...                            ...        ...                        ...  ..
# 60523             3801 TONGASS AVE  KETCHIKAN  KETCHIKAN GATEWAY BOROUGH  AK
# 60524              1300 STEDMAN ST  KETCHIKAN  KETCHIKAN GATEWAY BOROUGH  AK
# 60525             1010 STEDMAN ST.  KETCHIKAN  KETCHIKAN GATEWAY BOROUGH  AK
# 60526               900 STEDMAN ST  KETCHIKAN  KETCHIKAN GATEWAY BOROUGH  AK
# 60527                641 SHAKES ST   WRANGELL  WRANGELL CITY AND BOROUGH  AK
#
#            ZIP BIA TRIBE  LATITUDE  LONGITUDE  \
# 0          602            18.37983  -67.18453
# 1          602            18.38080  -67.19130
# 2      6020580            18.37101  -67.20758
# 3      6020580            18.37101  -67.20758
# 4      6020580            18.37101  -67.20758
# ...        ...  ..   ...       ...        ...
# 60523    99901            55.35597 -131.69834
# 60524    99901            55.33373 -131.62533
# 60525    99901            55.33501 -131.62795
# 60526    99901            55.33760 -131.63331
# 60527    99929            56.46719 -132.38214
#
#                          INDUSTRY_SECTOR                      PARENT_CO_NAME
# 0                              Chemicals                   BAXTER SALES CORP
# 1                    Plastics and Rubber              DADE INTERNATIONAL INC
# 2      Computers and Electronic Products              DSC COMMUNICATION CORP
# 3      Computers and Electronic Products              DSC COMMUNICATION CORP
# 4      Computers and Electronic Products              DSC COMMUNICATION CORP
# ...                                  ...                                 ...
# 60523           Transportation Equipment                        VIGOR MARINE
# 60524           Transportation Equipment  US DEPARTMENT OF HOMELAND SECURITY
# 60525           Petroleum Bulk Terminals                    TESORO ALASKA CO
# 60526           Petroleum Bulk Terminals                   CROWLEY FUELS LLC
# 60527                               Food               TRIDENT SEAFOODS CORP
#
# [60528 rows x 13 columns]

# %%
# create pivot table summing totals to create records per facility per year, with total releases
pivot = pd.pivot_table(tri_filter,index=['YEAR', 'TRIFD'], values=['ON_SITE_RELEASE_TOTAL'],aggfunc=np.sum)
pivot
# Out:
#                       ON_SITE_RELEASE_TOTAL
# YEAR TRIFD
# 1987 00602BXTRHRD115                0.00000
#      00602DSCFPPOBOX            21862.00000
#      00602GRNGRAGUAD            14723.00000
#      00605BRNQNPR467                0.00000
#      00605VNMRBMONTA            19147.00000
# ...                                     ...
# 2018 99801CRLSK331CL          2212952.20000
#      99801KNNCT13401         55589597.00000
#      9980WCRWLY176JA             2185.28000
#      99901SCSTG1300S                0.80000
#      9990WCRWLY9STED             1397.34000
#
# [747975 rows x 1 columns]

# %%
# rename columns to simplify names
pivot = pivot.rename(columns={'ON_SITE_RELEASE_TOTAL':'TOTAL'})
pivot
# Out:
#                               TOTAL
# YEAR TRIFD
# 1987 00602BXTRHRD115        0.00000
#      00602DSCFPPOBOX    21862.00000
#      00602GRNGRAGUAD    14723.00000
#      00605BRNQNPR467        0.00000
#      00605VNMRBMONTA    19147.00000
# ...                             ...
# 2018 99801CRLSK331CL  2212952.20000
#      99801KNNCT13401 55589597.00000
#      9980WCRWLY176JA     2185.28000
#      99901SCSTG1300S        0.80000
#      9990WCRWLY9STED     1397.34000
#
# [747975 rows x 1 columns]

# %%
# unstack pivot table to create columns for release type for each year
amountsUnstacked = pivot.unstack(level=0)
amountsUnstacked
# Out:
#                       TOTAL                                                 \
# YEAR                   1987        1988        1989        1990       1991
# TRIFD
# 00602BXTRF111CO         nan 11700.00000 12000.00000         nan        nan
# 00602BXTRHRD115     0.00000   250.00000     0.00000     0.00000    0.00000
# 00602DSCFPPOBOA         nan         nan 17447.00000  4086.00000        nan
# 00602DSCFPPOBOX 21862.00000         nan 17717.00000 14730.00000        nan
# 00602GRNGRAGUAD 14723.00000         nan 22349.00000 25133.00000 4900.00000
# ...                     ...         ...         ...         ...        ...
# 99901LSKSH381TN         nan         nan         nan         nan        nan
# 99901SCSTG1300S         nan         nan         nan         nan        nan
# 99901TSRLS1010S         nan         nan         nan         nan        nan
# 9990WCRWLY9STED         nan         nan         nan         nan        nan
# 99929TRDNT641SH         nan         nan         nan         nan        nan
#
#                                                          ...                  \
# YEAR               1992    1993    1994    1995    1996  ...    2009    2010
# TRIFD                                                    ...
# 00602BXTRF111CO     nan     nan     nan     nan     nan  ...     nan     nan
# 00602BXTRHRD115 0.00000 0.00000 0.00000 0.00000 0.00000  ...     nan     nan
# 00602DSCFPPOBOA     nan     nan     nan     nan     nan  ...     nan     nan
# 00602DSCFPPOBOX     nan     nan     nan     nan     nan  ...     nan     nan
# 00602GRNGRAGUAD     nan     nan     nan     nan     nan  ...     nan     nan
# ...                 ...     ...     ...     ...     ...  ...     ...     ...
# 99901LSKSH381TN     nan     nan     nan     nan     nan  ...     nan     nan
# 99901SCSTG1300S     nan     nan     nan     nan     nan  ... 0.00000 0.00000
# 99901TSRLS1010S     nan     nan     nan     nan     nan  ...     nan     nan
# 9990WCRWLY9STED     nan     nan     nan     nan     nan  ...     nan     nan
# 99929TRDNT641SH     nan     nan     nan     nan     nan  ... 0.00000     nan
#
#                                                                      \
# YEAR                  2011       2012    2013       2014       2015
# TRIFD
# 00602BXTRF111CO        nan        nan     nan        nan        nan
# 00602BXTRHRD115        nan        nan     nan        nan        nan
# 00602DSCFPPOBOA        nan        nan     nan        nan        nan
# 00602DSCFPPOBOX        nan        nan     nan        nan        nan
# 00602GRNGRAGUAD        nan        nan     nan        nan        nan
# ...                    ...        ...     ...        ...        ...
# 99901LSKSH381TN 9362.00000 1534.00000     nan 8043.31460        nan
# 99901SCSTG1300S    0.00000    0.00000 0.49320    0.29320    0.10520
# 99901TSRLS1010S        nan        nan     nan        nan        nan
# 9990WCRWLY9STED        nan        nan     nan 1769.95000 1825.74000
# 99929TRDNT641SH        nan        nan     nan        nan        nan
#
#
# YEAR                  2016       2017       2018
# TRIFD
# 00602BXTRF111CO        nan        nan        nan
# 00602BXTRHRD115        nan        nan        nan
# 00602DSCFPPOBOA        nan        nan        nan
# 00602DSCFPPOBOX        nan        nan        nan
# 00602GRNGRAGUAD        nan        nan        nan
# ...                    ...        ...        ...
# 99901LSKSH381TN        nan        nan        nan
# 99901SCSTG1300S    0.14120    0.11410    0.80000
# 99901TSRLS1010S        nan        nan        nan
# 9990WCRWLY9STED 1474.49000 1412.03000 1397.34000
# 99929TRDNT641SH        nan        nan        nan
#
# [60528 rows x 32 columns]

# %%
# rename columns to reflect year and release type
amountsUnstacked.columns = [''.join(str(s).strip() for s in col if s) for col in amountsUnstacked.columns]
amountsUnstacked
# Out:
#                   TOTAL1987   TOTAL1988   TOTAL1989   TOTAL1990  TOTAL1991  \
# TRIFD
# 00602BXTRF111CO         nan 11700.00000 12000.00000         nan        nan
# 00602BXTRHRD115     0.00000   250.00000     0.00000     0.00000    0.00000
# 00602DSCFPPOBOA         nan         nan 17447.00000  4086.00000        nan
# 00602DSCFPPOBOX 21862.00000         nan 17717.00000 14730.00000        nan
# 00602GRNGRAGUAD 14723.00000         nan 22349.00000 25133.00000 4900.00000
# ...                     ...         ...         ...         ...        ...
# 99901LSKSH381TN         nan         nan         nan         nan        nan
# 99901SCSTG1300S         nan         nan         nan         nan        nan
# 99901TSRLS1010S         nan         nan         nan         nan        nan
# 9990WCRWLY9STED         nan         nan         nan         nan        nan
# 99929TRDNT641SH         nan         nan         nan         nan        nan
#
#                  TOTAL1992  TOTAL1993  TOTAL1994  TOTAL1995  TOTAL1996  ...  \
# TRIFD                                                                   ...
# 00602BXTRF111CO        nan        nan        nan        nan        nan  ...
# 00602BXTRHRD115    0.00000    0.00000    0.00000    0.00000    0.00000  ...
# 00602DSCFPPOBOA        nan        nan        nan        nan        nan  ...
# 00602DSCFPPOBOX        nan        nan        nan        nan        nan  ...
# 00602GRNGRAGUAD        nan        nan        nan        nan        nan  ...
# ...                    ...        ...        ...        ...        ...  ...
# 99901LSKSH381TN        nan        nan        nan        nan        nan  ...
# 99901SCSTG1300S        nan        nan        nan        nan        nan  ...
# 99901TSRLS1010S        nan        nan        nan        nan        nan  ...
# 9990WCRWLY9STED        nan        nan        nan        nan        nan  ...
# 99929TRDNT641SH        nan        nan        nan        nan        nan  ...
#
#                  TOTAL2009  TOTAL2010  TOTAL2011  TOTAL2012  TOTAL2013  \
# TRIFD
# 00602BXTRF111CO        nan        nan        nan        nan        nan
# 00602BXTRHRD115        nan        nan        nan        nan        nan
# 00602DSCFPPOBOA        nan        nan        nan        nan        nan
# 00602DSCFPPOBOX        nan        nan        nan        nan        nan
# 00602GRNGRAGUAD        nan        nan        nan        nan        nan
# ...                    ...        ...        ...        ...        ...
# 99901LSKSH381TN        nan        nan 9362.00000 1534.00000        nan
# 99901SCSTG1300S    0.00000    0.00000    0.00000    0.00000    0.49320
# 99901TSRLS1010S        nan        nan        nan        nan        nan
# 9990WCRWLY9STED        nan        nan        nan        nan        nan
# 99929TRDNT641SH    0.00000        nan        nan        nan        nan
#
#                  TOTAL2014  TOTAL2015  TOTAL2016  TOTAL2017  TOTAL2018
# TRIFD
# 00602BXTRF111CO        nan        nan        nan        nan        nan
# 00602BXTRHRD115        nan        nan        nan        nan        nan
# 00602DSCFPPOBOA        nan        nan        nan        nan        nan
# 00602DSCFPPOBOX        nan        nan        nan        nan        nan
# 00602GRNGRAGUAD        nan        nan        nan        nan        nan
# ...                    ...        ...        ...        ...        ...
# 99901LSKSH381TN 8043.31460        nan        nan        nan        nan
# 99901SCSTG1300S    0.29320    0.10520    0.14120    0.11410    0.80000
# 99901TSRLS1010S        nan        nan        nan        nan        nan
# 9990WCRWLY9STED 1769.95000 1825.74000 1474.49000 1412.03000 1397.34000
# 99929TRDNT641SH        nan        nan        nan        nan        nan
#
# [60528 rows x 32 columns]

# %%
# change facility outlier for 1987 to 0
amountsUnstacked.at['93562KRRMC13200', 'TOTAL1987'] = 0

# %%
amountsUnstacked = amountsUnstacked.fillna(0)
amountsUnstacked.loc['TOTAL_RELEASE']= amountsUnstacked.sum()
amountsUnstacked
# Out:
#                         TOTAL1987        TOTAL1988        TOTAL1989  \
# TRIFD
# 00602BXTRF111CO           0.00000      11700.00000      12000.00000
# 00602BXTRHRD115           0.00000        250.00000          0.00000
# 00602DSCFPPOBOA           0.00000          0.00000      17447.00000
# 00602DSCFPPOBOX       21862.00000          0.00000      17717.00000
# 00602GRNGRAGUAD       14723.00000          0.00000      22349.00000
# ...                           ...              ...              ...
# 99901SCSTG1300S           0.00000          0.00000          0.00000
# 99901TSRLS1010S           0.00000          0.00000          0.00000
# 9990WCRWLY9STED           0.00000          0.00000          0.00000
# 99929TRDNT641SH           0.00000          0.00000          0.00000
# TOTAL_RELEASE   12266349933.00000 5680148075.00000 4452091324.00000
#
#                        TOTAL1990        TOTAL1991        TOTAL1992  \
# TRIFD
# 00602BXTRF111CO          0.00000          0.00000          0.00000
# 00602BXTRHRD115          0.00000          0.00000          0.00000
# 00602DSCFPPOBOA       4086.00000          0.00000          0.00000
# 00602DSCFPPOBOX      14730.00000          0.00000          0.00000
# 00602GRNGRAGUAD      25133.00000       4900.00000          0.00000
# ...                          ...              ...              ...
# 99901SCSTG1300S          0.00000          0.00000          0.00000
# 99901TSRLS1010S          0.00000          0.00000          0.00000
# 9990WCRWLY9STED          0.00000          0.00000          0.00000
# 99929TRDNT641SH          0.00000          0.00000          0.00000
# TOTAL_RELEASE   3753465237.00000 3496917822.96000 3318950504.64000
#
#                        TOTAL1993        TOTAL1994        TOTAL1995  \
# TRIFD
# 00602BXTRF111CO          0.00000          0.00000          0.00000
# 00602BXTRHRD115          0.00000          0.00000          0.00000
# 00602DSCFPPOBOA          0.00000          0.00000          0.00000
# 00602DSCFPPOBOX          0.00000          0.00000          0.00000
# 00602GRNGRAGUAD          0.00000          0.00000          0.00000
# ...                          ...              ...              ...
# 99901SCSTG1300S          0.00000          0.00000          0.00000
# 99901TSRLS1010S          0.00000          0.00000          0.00000
# 9990WCRWLY9STED          0.00000          0.00000          0.00000
# 99929TRDNT641SH          0.00000          0.00000          0.00000
# TOTAL_RELEASE   2909276729.72000 2365597221.36000 2387160808.09000
#
#                        TOTAL1996  ...        TOTAL2009        TOTAL2010  \
# TRIFD                             ...
# 00602BXTRF111CO          0.00000  ...          0.00000          0.00000
# 00602BXTRHRD115          0.00000  ...          0.00000          0.00000
# 00602DSCFPPOBOA          0.00000  ...          0.00000          0.00000
# 00602DSCFPPOBOX          0.00000  ...          0.00000          0.00000
# 00602GRNGRAGUAD          0.00000  ...          0.00000          0.00000
# ...                          ...  ...              ...              ...
# 99901SCSTG1300S          0.00000  ...          0.00000          0.00000
# 99901TSRLS1010S          0.00000  ...          0.00000          0.00000
# 9990WCRWLY9STED          0.00000  ...          0.00000          0.00000
# 99929TRDNT641SH          0.00000  ...          0.00000          0.00000
# TOTAL_RELEASE   2318409398.65000  ... 3038737468.64420 3401823195.53792
#
#                        TOTAL2011        TOTAL2012        TOTAL2013  \
# TRIFD
# 00602BXTRF111CO          0.00000          0.00000          0.00000
# 00602BXTRHRD115          0.00000          0.00000          0.00000
# 00602DSCFPPOBOA          0.00000          0.00000          0.00000
# 00602DSCFPPOBOX          0.00000          0.00000          0.00000
# 00602GRNGRAGUAD          0.00000          0.00000          0.00000
# ...                          ...              ...              ...
# 99901SCSTG1300S          0.00000          0.00000          0.49320
# 99901TSRLS1010S          0.00000          0.00000          0.00000
# 9990WCRWLY9STED          0.00000          0.00000          0.00000
# 99929TRDNT641SH          0.00000          0.00000          0.00000
# TOTAL_RELEASE   3701652530.05003 3232491920.86028 3727353563.30422
#
#                        TOTAL2014        TOTAL2015        TOTAL2016  \
# TRIFD
# 00602BXTRF111CO          0.00000          0.00000          0.00000
# 00602BXTRHRD115          0.00000          0.00000          0.00000
# 00602DSCFPPOBOA          0.00000          0.00000          0.00000
# 00602DSCFPPOBOX          0.00000          0.00000          0.00000
# 00602GRNGRAGUAD          0.00000          0.00000          0.00000
# ...                          ...              ...              ...
# 99901SCSTG1300S          0.29320          0.10520          0.14120
# 99901TSRLS1010S          0.00000          0.00000          0.00000
# 9990WCRWLY9STED       1769.95000       1825.74000       1474.49000
# 99929TRDNT641SH          0.00000          0.00000          0.00000
# TOTAL_RELEASE   3544714287.81079 2972866487.44393 3134064227.29282
#
#                        TOTAL2017        TOTAL2018
# TRIFD
# 00602BXTRF111CO          0.00000          0.00000
# 00602BXTRHRD115          0.00000          0.00000
# 00602DSCFPPOBOA          0.00000          0.00000
# 00602DSCFPPOBOX          0.00000          0.00000
# 00602GRNGRAGUAD          0.00000          0.00000
# ...                          ...              ...
# 99901SCSTG1300S          0.11410          0.80000
# 99901TSRLS1010S          0.00000          0.00000
# 9990WCRWLY9STED       1412.03000       1397.34000
# 99929TRDNT641SH          0.00000          0.00000
# TOTAL_RELEASE   3541607790.97415 3367991070.30157
#
# [60529 rows x 32 columns]

# %% [markdown]
# ### Create csv for total release by all facilities per year, to use in D3 chart
#
# I want to display a D3 chart in my map story that shows the total amount released each year by all facilities. I need to create a simple csv for this.

# %%
yearTotal = amountsUnstacked.tail(1)
yearTotal
# Out:
#                       TOTAL1987        TOTAL1988        TOTAL1989  \
# TRIFD
# TOTAL_RELEASE 12266349933.00000 5680148075.00000 4452091324.00000
#
#                      TOTAL1990        TOTAL1991        TOTAL1992  \
# TRIFD
# TOTAL_RELEASE 3753465237.00000 3496917822.96000 3318950504.64000
#
#                      TOTAL1993        TOTAL1994        TOTAL1995  \
# TRIFD
# TOTAL_RELEASE 2909276729.72000 2365597221.36000 2387160808.09000
#
#                      TOTAL1996  ...        TOTAL2009        TOTAL2010  \
# TRIFD                           ...
# TOTAL_RELEASE 2318409398.65000  ... 3038737468.64420 3401823195.53792
#
#                      TOTAL2011        TOTAL2012        TOTAL2013  \
# TRIFD
# TOTAL_RELEASE 3701652530.05003 3232491920.86028 3727353563.30422
#
#                      TOTAL2014        TOTAL2015        TOTAL2016  \
# TRIFD
# TOTAL_RELEASE 3544714287.81079 2972866487.44393 3134064227.29282
#
#                      TOTAL2017        TOTAL2018
# TRIFD
# TOTAL_RELEASE 3541607790.97415 3367991070.30157
#
# [1 rows x 32 columns]

# %%
yearTotal = yearTotal.transpose()
yearTotal.reset_index(level=0, inplace=True)
yearTotal = yearTotal.rename(columns={'index':'YEAR'})
yearTotal['YEAR'] = yearTotal['YEAR'].str[-4:]

yearTotal
# Out:
# TRIFD  YEAR     TOTAL_RELEASE
# 0      1987 12266349933.00000
# 1      1988  5680148075.00000
# 2      1989  4452091324.00000
# 3      1990  3753465237.00000
# 4      1991  3496917822.96000
# 5      1992  3318950504.64000
# 6      1993  2909276729.72000
# 7      1994  2365597221.36000
# 8      1995  2387160808.09000
# 9      1996  2318409398.65000
# 10     1997  2281871053.82142
# 11     1998  6728946097.18158
# 12     1999  6793943773.91012
# 13     2000  6174977465.07631
# 14     2001  5119343140.05840
# 15     2002  4289782067.24116
# 16     2003  3985853445.83413
# 17     2004  3733208144.19877
# 18     2005  3842195100.63946
# 19     2006  3801739639.43404
# 20     2007  3580395800.26552
# 21     2008  3401547270.72674
# 22     2009  3038737468.64420
# 23     2010  3401823195.53792
# 24     2011  3701652530.05003
# 25     2012  3232491920.86028
# 26     2013  3727353563.30422
# 27     2014  3544714287.81079
# 28     2015  2972866487.44393
# 29     2016  3134064227.29282
# 30     2017  3541607790.97415
# 31     2018  3367991070.30157

# %%
# export to csv
yearTotal.to_csv('../data/year-totals.csv', index=False)

# %% [markdown]
# ### Find the top releasing facilities each year
#
# I cannot keep all records for each year as it is too large for a web map, so I am going to select the top 4000 rows from each year to visualize on the map.

# %%
# create empty dataframe
topRows = pd.DataFrame()

# create list of column names
columns = list(amountsUnstacked.columns)

# loop through each column
# finding the 4000 largest values in each
# and appending to empty topRows dataframe
for column in columns:
    topValues = amountsUnstacked.nlargest(4000, column)
    topRows = topRows.append(topValues)

topRows
# Out:
#                         TOTAL1987        TOTAL1988        TOTAL1989  \
# TRIFD
# TOTAL_RELEASE   12266349933.00000 5680148075.00000 4452091324.00000
# 77978LMNMCSTATE   468874750.00000   10700650.00000      30250.00000
# 76567LMNMCSANDO   329112650.00000    4683150.00000    1448233.00000
# 70094MRCNC10800   217298702.00000  176386400.00000  192340500.00000
# 70079SHLLL1205R   194620655.00000  159304466.00000    4960010.00000
# ...                           ...              ...              ...
# 51459WSTCN461ST           0.00000          0.00000          0.00000
# 46516CPLSN435HA           0.00000       2620.00000       3095.00000
# 4816WVNTWR111BR           0.00000          0.00000          0.00000
# 51020QDCNT65915           0.00000          0.00000          0.00000
# 14572GNLCKONEGU      281250.00000     230500.00000     275100.00000
#
#                        TOTAL1990        TOTAL1991        TOTAL1992  \
# TRIFD
# TOTAL_RELEASE   3753465237.00000 3496917822.96000 3318950504.64000
# 77978LMNMCSTATE      19605.00000      10855.00000       8513.00000
# 76567LMNMCSANDO    1440839.00000    1214510.00000     978813.00000
# 70094MRCNC10800  162030982.00000  142009076.00000  147088590.00000
# 70079SHLLL1205R    3859415.00000    1282081.00000    1432122.00000
# ...                          ...              ...              ...
# 51459WSTCN461ST          0.00000          0.00000          0.00000
# 46516CPLSN435HA       2647.00000       2050.00000       3000.00000
# 4816WVNTWR111BR          0.00000          0.00000          0.00000
# 51020QDCNT65915          0.00000          0.00000          0.00000
# 14572GNLCKONEGU     191900.00000     159123.00000     187192.00000
#
#                        TOTAL1993        TOTAL1994        TOTAL1995  \
# TRIFD
# TOTAL_RELEASE   2909276729.72000 2365597221.36000 2387160808.09000
# 77978LMNMCSTATE       2086.00000        458.00000       1046.00000
# 76567LMNMCSANDO     780927.00000    1177274.00000     914029.00000
# 70094MRCNC10800  120149724.00000   20514100.00000   29534568.00000
# 70079SHLLL1205R    1804493.00000    1940255.00000    2422358.00000
# ...                          ...              ...              ...
# 51459WSTCN461ST          0.00000          0.00000          0.00000
# 46516CPLSN435HA       3680.00000       3709.00000       2577.00000
# 4816WVNTWR111BR          0.00000          0.00000          0.00000
# 51020QDCNT65915          0.00000          0.00000          0.00000
# 14572GNLCKONEGU     156000.00000     200500.00000      92900.00000
#
#                        TOTAL1996  ...        TOTAL2009        TOTAL2010  \
# TRIFD                             ...
# TOTAL_RELEASE   2318409398.65000  ... 3038737468.64420 3401823195.53792
# 77978LMNMCSTATE        961.00000  ...     104538.00000     178771.10000
# 76567LMNMCSANDO    1908875.00000  ...     180854.27000     264000.00000
# 70094MRCNC10800   28561121.00000  ...   14033632.00000   15611971.00000
# 70079SHLLL1205R    2208232.00000  ...     909879.54060     962606.12280
# ...                          ...  ...              ...              ...
# 51459WSTCN461ST          0.00000  ...       6264.00000       3244.00000
# 46516CPLSN435HA       2371.00000  ...       5335.85000       4952.00000
# 4816WVNTWR111BR          0.00000  ...          0.00000          0.00000
# 51020QDCNT65915          0.00000  ...       4354.00000       4072.00000
# 14572GNLCKONEGU      76150.00000  ...      21755.10000          0.00000
#
#                        TOTAL2011        TOTAL2012        TOTAL2013  \
# TRIFD
# TOTAL_RELEASE   3701652530.05003 3232491920.86028 3727353563.30422
# 77978LMNMCSTATE     199796.00000     188280.10000     215479.80000
# 76567LMNMCSANDO     353000.00000     159422.00000     133398.00000
# 70094MRCNC10800   12514975.00000   13033799.00000    9981778.00000
# 70079SHLLL1205R     877825.43200    1078932.34504    1117847.63374
# ...                          ...              ...              ...
# 51459WSTCN461ST       8130.00000       7600.00000      14120.00000
# 46516CPLSN435HA       5965.00000       5482.00000       6860.00000
# 4816WVNTWR111BR          0.00000          0.00000          0.00000
# 51020QDCNT65915       4487.00000       4126.00000       2541.00000
# 14572GNLCKONEGU          0.00000          0.00000          0.00000
#
#                        TOTAL2014        TOTAL2015        TOTAL2016  \
# TRIFD
# TOTAL_RELEASE   3544714287.81079 2972866487.44393 3134064227.29282
# 77978LMNMCSTATE     229453.30000     235630.60000      31152.40000
# 76567LMNMCSANDO      62416.00000          0.00000          0.00000
# 70094MRCNC10800   11626902.87000   12079217.00000   12144943.00000
# 70079SHLLL1205R    1088839.50070     890730.06000    1037026.85000
# ...                          ...              ...              ...
# 51459WSTCN461ST      11640.00000      11640.00000      11540.00000
# 46516CPLSN435HA       7422.00000       6756.00000       8243.00000
# 4816WVNTWR111BR      38940.00000      20550.18000      16005.00000
# 51020QDCNT65915       6023.00000       6592.00000      13333.69000
# 14572GNLCKONEGU      10394.00000      13886.00000      11797.00000
#
#                        TOTAL2017        TOTAL2018
# TRIFD
# TOTAL_RELEASE   3541607790.97415 3367991070.30157
# 77978LMNMCSTATE          0.00000          0.00000
# 76567LMNMCSANDO          0.00000          0.00000
# 70094MRCNC10800   11604350.00000   14758762.00000
# 70079SHLLL1205R     955726.85000    1200867.95450
# ...                          ...              ...
# 51459WSTCN461ST      11660.00000      11660.00000
# 46516CPLSN435HA       8123.00000      11655.00000
# 4816WVNTWR111BR       3605.64000      11649.00000
# 51020QDCNT65915      13049.00000      11643.00000
# 14572GNLCKONEGU      13168.00000      11641.00000
#
# [128000 rows x 32 columns]

# %%
# many facilities made it into the top list for multiple years
# so now I will drop any duplicates
topRows = topRows.drop_duplicates()
topRows
# Out:
#                         TOTAL1987        TOTAL1988        TOTAL1989  \
# TRIFD
# TOTAL_RELEASE   12266349933.00000 5680148075.00000 4452091324.00000
# 77978LMNMCSTATE   468874750.00000   10700650.00000      30250.00000
# 76567LMNMCSANDO   329112650.00000    4683150.00000    1448233.00000
# 70094MRCNC10800   217298702.00000  176386400.00000  192340500.00000
# 70079SHLLL1205R   194620655.00000  159304466.00000    4960010.00000
# ...                           ...              ...              ...
# 5264WMDWST21WWA           0.00000          0.00000          0.00000
# 44301KRNPN1390F        1000.00000       1500.00000       2000.00000
# 75090TXSNS6400H       56900.00000      88160.00000      63520.00000
# 0306WWRTHN34CEL           0.00000          0.00000          0.00000
# 46516CPLSN435HA           0.00000       2620.00000       3095.00000
#
#                        TOTAL1990        TOTAL1991        TOTAL1992  \
# TRIFD
# TOTAL_RELEASE   3753465237.00000 3496917822.96000 3318950504.64000
# 77978LMNMCSTATE      19605.00000      10855.00000       8513.00000
# 76567LMNMCSANDO    1440839.00000    1214510.00000     978813.00000
# 70094MRCNC10800  162030982.00000  142009076.00000  147088590.00000
# 70079SHLLL1205R    3859415.00000    1282081.00000    1432122.00000
# ...                          ...              ...              ...
# 5264WMDWST21WWA          0.00000          0.00000          0.00000
# 44301KRNPN1390F          0.00000       3500.00000      21350.00000
# 75090TXSNS6400H      66500.00000      61005.00000      36220.00000
# 0306WWRTHN34CEL          0.00000          0.00000          0.00000
# 46516CPLSN435HA       2647.00000       2050.00000       3000.00000
#
#                        TOTAL1993        TOTAL1994        TOTAL1995  \
# TRIFD
# TOTAL_RELEASE   2909276729.72000 2365597221.36000 2387160808.09000
# 77978LMNMCSTATE       2086.00000        458.00000       1046.00000
# 76567LMNMCSANDO     780927.00000    1177274.00000     914029.00000
# 70094MRCNC10800  120149724.00000   20514100.00000   29534568.00000
# 70079SHLLL1205R    1804493.00000    1940255.00000    2422358.00000
# ...                          ...              ...              ...
# 5264WMDWST21WWA          0.00000          0.00000          0.00000
# 44301KRNPN1390F       9650.00000       5050.00000      12531.00000
# 75090TXSNS6400H      38295.00000      25448.00000      23133.00000
# 0306WWRTHN34CEL          0.00000          0.00000          0.00000
# 46516CPLSN435HA       3680.00000       3709.00000       2577.00000
#
#                        TOTAL1996  ...        TOTAL2009        TOTAL2010  \
# TRIFD                             ...
# TOTAL_RELEASE   2318409398.65000  ... 3038737468.64420 3401823195.53792
# 77978LMNMCSTATE        961.00000  ...     104538.00000     178771.10000
# 76567LMNMCSANDO    1908875.00000  ...     180854.27000     264000.00000
# 70094MRCNC10800   28561121.00000  ...   14033632.00000   15611971.00000
# 70079SHLLL1205R    2208232.00000  ...     909879.54060     962606.12280
# ...                          ...  ...              ...              ...
# 5264WMDWST21WWA          0.00000  ...          0.00000          0.00000
# 44301KRNPN1390F      15003.00000  ...       6820.14000       9237.19000
# 75090TXSNS6400H       7986.00000  ...       5483.00000       7832.00000
# 0306WWRTHN34CEL          0.00000  ...          0.00000          0.00000
# 46516CPLSN435HA       2371.00000  ...       5335.85000       4952.00000
#
#                        TOTAL2011        TOTAL2012        TOTAL2013  \
# TRIFD
# TOTAL_RELEASE   3701652530.05003 3232491920.86028 3727353563.30422
# 77978LMNMCSTATE     199796.00000     188280.10000     215479.80000
# 76567LMNMCSANDO     353000.00000     159422.00000     133398.00000
# 70094MRCNC10800   12514975.00000   13033799.00000    9981778.00000
# 70079SHLLL1205R     877825.43200    1078932.34504    1117847.63374
# ...                          ...              ...              ...
# 5264WMDWST21WWA          0.00000          0.00000       5783.16000
# 44301KRNPN1390F      10546.17000       9793.00000      10995.00000
# 75090TXSNS6400H       8368.00000       7853.00000       8589.00000
# 0306WWRTHN34CEL          0.00000          0.00000       5664.00000
# 46516CPLSN435HA       5965.00000       5482.00000       6860.00000
#
#                        TOTAL2014        TOTAL2015        TOTAL2016  \
# TRIFD
# TOTAL_RELEASE   3544714287.81079 2972866487.44393 3134064227.29282
# 77978LMNMCSTATE     229453.30000     235630.60000      31152.40000
# 76567LMNMCSANDO      62416.00000          0.00000          0.00000
# 70094MRCNC10800   11626902.87000   12079217.00000   12144943.00000
# 70079SHLLL1205R    1088839.50070     890730.06000    1037026.85000
# ...                          ...              ...              ...
# 5264WMDWST21WWA       6742.15000      12112.23000       2845.91000
# 44301KRNPN1390F       4513.00000      10058.07000       8358.02000
# 75090TXSNS6400H      12182.00000      10126.00000      11139.00000
# 0306WWRTHN34CEL       6531.00000       7301.00000       8976.00000
# 46516CPLSN435HA       7422.00000       6756.00000       8243.00000
#
#                        TOTAL2017        TOTAL2018
# TRIFD
# TOTAL_RELEASE   3541607790.97415 3367991070.30157
# 77978LMNMCSTATE          0.00000          0.00000
# 76567LMNMCSANDO          0.00000          0.00000
# 70094MRCNC10800   11604350.00000   14758762.00000
# 70079SHLLL1205R     955726.85000    1200867.95450
# ...                          ...              ...
# 5264WMDWST21WWA       1301.50000      11852.00000
# 44301KRNPN1390F       9168.05000      11740.06000
# 75090TXSNS6400H      10484.00000      11717.00000
# 0306WWRTHN34CEL      10425.00000      11707.00000
# 46516CPLSN435HA       8123.00000      11655.00000
#
# [13515 rows x 32 columns]

# %%
# merge topRows dataframe to reduced dataframe with one record per facility, with lat/long values
merged = all_tri.merge(topRows, on='TRIFD')
merged
# Out:
#                  TRIFD                              FACILITY_NAME  \
# 0      00603HWLTTSTATE             HEWLETT-PACKARD CARIBE BV SITE
# 1      00608DCRBNRD3KM                             IDI CARIBE INC
# 2      00610BXTRHROAD4       EDWARDS LIFESCIENCES TECHNOLOGY SARL
# 3      00610LLRGNGPOBO                    ALLERGAN MEDICAL OPTICS
# 4      00612PRPCMPR681  PREPA-CAMBALACHE COMBUSTION TURBINE PLANT
# ...                ...                                        ...
# 13509  99752RDDGP90MIL                         RED DOG OPERATIONS
# 13510  99801CRLSK331CL   COEUR ALASKA INC KENSINGTON GOLD PROJECT
# 13511  99801KNNCT13401               HECLA GREENS CREEK MINING CO
# 13512  99835LSKPLMILE6                           ALASKA PULP CORP
# 13513  99901KTCHKMILE7                          KETCHIKAN PULP CO
#
#                                           STREET_ADDRESS       CITY  \
# 0                                       HWY 110 N KM 5.1  AGUADILLA
# 1                                   PR3 KM 151.8 AGUIRRE    SALINAS
# 2      STATE RD 402 KM 1.4 N LAS MARIAS IND US TRIAL ...     ANASCO
# 3                         RD 402 LAS MARIAS GPO BOX 1408     ANASCO
# 4                                          PR-681 KM 0.5    ARECIBO
# ...                                                  ...        ...
# 13509                             90 MILES N OF KOTZEBUE   KOTZEBUE
# 13510                                    3031 CLINTON DR     JUNEAU
# 13511                                  13401 GLACIER HWY     JUNEAU
# 13512                              4600 SAWMILL CREEK RD      SITKA
# 13513                                 7559 N TONGASS HWY  KETCHIKAN
#
#                           COUNTY  ST        ZIP BIA TRIBE  LATITUDE  ...  \
# 0            AGUADILLA MUNICIPIO  PR        603            18.43460  ...
# 1              SALINAS MUNICIPIO  PR        751            17.97278  ...
# 2               ANASCO MUNICIPIO  PR        610            18.29390  ...
# 3               ANASCO MUNICIPIO  PR    6104108            18.28629  ...
# 4              ARECIBO MUNICIPIO  PR        612            18.47110  ...
# ...                          ...  ..        ...  ..   ...       ...  ...
# 13509   NORTHWEST ARCTIC BOROUGH  AK      99752            68.06151  ...
# 13510             JUNEAU BOROUGH  AK      99801            58.86749  ...
# 13511             JUNEAU BOROUGH  AK      99801            58.08180  ...
# 13512                      SITKA  AK  998359798            57.04764  ...
# 13513  KETCHIKAN GATEWAY BOROUGH  AK      99901            55.40838  ...
#
#             TOTAL2009       TOTAL2010       TOTAL2011       TOTAL2012  \
# 0         19063.53000      4749.17000      6432.61000      5638.60000
# 1         12557.38000     12583.38000     13235.38000     14263.38000
# 2          1000.00000      1000.00000      1000.00000      1473.00000
# 3             0.00000         0.00000         0.00000         0.00000
# 4           114.40000        78.50000        63.50000        24.90000
# ...               ...             ...             ...             ...
# 13509 637521196.30000 777395652.60300 989392511.30300 814003310.83000
# 13510       387.83000     94205.30000     12737.46000   1080831.30000
# 13511  47242868.62000  47185465.74000  47043841.64000  48754931.74000
# 13512         0.00000         0.00000         0.00000         0.00000
# 13513         0.00000         0.00000         0.00000         0.00000
#
#             TOTAL2013        TOTAL2014       TOTAL2015       TOTAL2016  \
# 0          6801.90000       1046.20000         0.10000         0.20000
# 1         16190.38000      15288.38000     15540.38000     14768.38000
# 2          1411.00000       1580.16000      1702.87000      2297.09000
# 3             0.00000          0.00000         0.00000         0.00000
# 4            31.60000         55.90000        82.10000        51.80000
# ...               ...              ...             ...             ...
# 13509 906385793.10200 1124384868.58200 561222144.59200 776973928.58100
# 13510   2010958.46000    1985383.17000   2169999.02000   1951776.90000
# 13511  50615872.74000   41557030.50000  29951062.50000  41780361.00000
# 13512         0.00000          0.00000         0.00000         0.00000
# 13513         0.00000          0.00000         0.00000         0.00000
#
#              TOTAL2017       TOTAL2018
# 0              0.00000         0.00000
# 1          13726.38000     13143.38000
# 2            599.00000       580.00000
# 3              0.00000         0.00000
# 4             95.60000        42.20000
# ...                ...             ...
# 13509 1082414482.97500 885682874.24200
# 13510    2226975.40000   2212952.20000
# 13511   58696349.90000  55589597.00000
# 13512          0.00000         0.00000
# 13513          0.00000         0.00000
#
# [13514 rows x 45 columns]

# %% [markdown]
# ### Convert to geodataframe and export to geojson

# %%
# cast lat/long columns to float
merged['LATITUDE'] = merged['LATITUDE'].astype(float)
merged['LONGITUDE'] = merged['LONGITUDE'].astype(float)

# create geodataframe using Latitude and Longitude columns
gdf = gpd.GeoDataFrame(merged, geometry=gpd.points_from_xy(merged.LONGITUDE, merged.LATITUDE))

# define crs for geodataframe
gdf.crs = {'init' :'epsg:4326'}

gdf.head()
# Out:
#              TRIFD                              FACILITY_NAME  \
# 0  00603HWLTTSTATE             HEWLETT-PACKARD CARIBE BV SITE
# 1  00608DCRBNRD3KM                             IDI CARIBE INC
# 2  00610BXTRHROAD4       EDWARDS LIFESCIENCES TECHNOLOGY SARL
# 3  00610LLRGNGPOBO                    ALLERGAN MEDICAL OPTICS
# 4  00612PRPCMPR681  PREPA-CAMBALACHE COMBUSTION TURBINE PLANT
#
#                                       STREET_ADDRESS       CITY  \
# 0                                   HWY 110 N KM 5.1  AGUADILLA
# 1                               PR3 KM 151.8 AGUIRRE    SALINAS
# 2  STATE RD 402 KM 1.4 N LAS MARIAS IND US TRIAL ...     ANASCO
# 3                     RD 402 LAS MARIAS GPO BOX 1408     ANASCO
# 4                                      PR-681 KM 0.5    ARECIBO
#
#                 COUNTY  ST      ZIP BIA TRIBE  LATITUDE  ...   TOTAL2010  \
# 0  AGUADILLA MUNICIPIO  PR      603            18.43460  ...  4749.17000
# 1    SALINAS MUNICIPIO  PR      751            17.97278  ... 12583.38000
# 2     ANASCO MUNICIPIO  PR      610            18.29390  ...  1000.00000
# 3     ANASCO MUNICIPIO  PR  6104108            18.28629  ...     0.00000
# 4    ARECIBO MUNICIPIO  PR      612            18.47110  ...    78.50000
#
#     TOTAL2011   TOTAL2012   TOTAL2013   TOTAL2014   TOTAL2015   TOTAL2016  \
# 0  6432.61000  5638.60000  6801.90000  1046.20000     0.10000     0.20000
# 1 13235.38000 14263.38000 16190.38000 15288.38000 15540.38000 14768.38000
# 2  1000.00000  1473.00000  1411.00000  1580.16000  1702.87000  2297.09000
# 3     0.00000     0.00000     0.00000     0.00000     0.00000     0.00000
# 4    63.50000    24.90000    31.60000    55.90000    82.10000    51.80000
#
#     TOTAL2017   TOTAL2018                    geometry
# 0     0.00000     0.00000  POINT (-67.15519 18.43460)
# 1 13726.38000 13143.38000  POINT (-66.23194 17.97278)
# 2   599.00000   580.00000  POINT (-67.13660 18.29390)
# 3     0.00000     0.00000  POINT (-67.13591 18.28629)
# 4    95.60000    42.20000  POINT (-66.69940 18.47110)
#
# [5 rows x 46 columns]

# %%
# export geodataframe to geojson
gdf.to_file("../data/top-tri-releases.geojson", driver='GeoJSON', encoding='utf-8')
