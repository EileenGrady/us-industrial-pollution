# %% [markdown]
# # Explore Superfund site data

# %% [markdown]
# Now that I have wrangled the data into a usable format, I am going to explore further to try and pick out some intersting case studies.

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
from shapely.geometry import Polygon
from shapely.geometry import mapping

import warnings
warnings.simplefilter(action='ignore')

# %%
#change default figure size
plt.rcParams['figure.figsize'] = (20, 10)

# %%
#read superfund site data in
superfund = gpd.read_file('../data/superfund-sites-new.geojson')
superfund.head()
# Out:
#     SEMS_EPA_ID                           SITE_NAME  \
# 0  AK4170024323         ADAK NAVAL AIR STATION SITE
# 1  AKD004904215  ALASKA BATTERY ENTERPRISES CLEANUP
# 2  AKD980983241                ALASKA RAILROAD CORP
# 3  AKD980988158                      ARCTIC SURPLUS
# 4  AK1570028646              EIELSON AIR FORCE BASE
#
#                  NPL_STATUS_x  LATITUDE  LONGITUDE       CITY  \
# 0  Currently on the Final NPL  51.87750 -176.65250       ADAK
# 1  Deleted from the Final NPL  64.82030 -147.70380  FAIRBANKS
# 2              Not on the NPL  61.22236 -149.88825  ANCHORAGE
# 3  Deleted from the Final NPL  64.81220 -147.56430  FAIRBANKS
# 4  Currently on the Final NPL  64.67145 -147.04920  FAIRBANKS
#
#                  COUNTY STATE                          STREET_ADDRESS  \
# 0        [Blank County]    AK                                 ADAK IS
# 1  FAIRBANKS NORTH STAR    AK              157 OLD RICHARDSON HIGHWAY
# 2             ANCHORAGE    AK                              1ST AVENUE
# 3        [Blank County]    AK  BADGER RD AND OLD RICHARDSON WAY MI. 6
# 4  FAIRBANKS NORTH STAR    AK       HIGHWAY 2 - 16 MI SE OF FAIRBANKS
#
#   ZIP_CODE  ... SITE_WIDE_READY_FOR_ANTICIPATED_USE  \
# 0   99546   ...                                  No
# 1   99701   ...                                  No
# 2   99501   ...                                  No
# 3   99701   ...                                 Yes
# 4   99702   ...                                  No
#
#   HUMAN_EXPOSURE_UNDER_CONTROL GROUNDWATER_MIGRATION_UNDER_CONTROL  \
# 0                          Yes                                 Yes
# 1                          Yes                                 Yes
# 2                          Yes                   Insufficient Data
# 3                          Yes                                 Yes
# 4                          Yes                   Insufficient Data
#
#   CONSTRUCTION_COMPLETION_DATE         SITE_TYPE NATIVE_AMERICAN_INTEREST  \
# 0                         None             Other                       No
# 1                     3/2/1993         Recycling                       No
# 2                         None             Other                       No
# 3                    4/18/2005  Waste Management                       No
# 4                    9/30/1998  Waste Management                       No
#
#   INDIAN_ENTITY HRS_SCORE                    SUPERFUND_SITE_PROFILE_PAGE_URL  \
# 0          None     51.37                     www.epa.gov/superfund/adak-nas
# 1          None       NaN               www.epa.gov/superfund/alaska-battery
# 2          None       NaN  www.epa.gov/superfund/alaska-railroad-anchorag...
# 3          None       NaN               www.epa.gov/superfund/arctic-surplus
# 4          None     48.14                  www.epa.gov/superfund/eielson-afb
#
#                       geometry
# 0  POINT (-176.65250 51.87750)
# 1  POINT (-147.70380 64.82030)
# 2  POINT (-149.88825 61.22236)
# 3  POINT (-147.56430 64.81220)
# 4  POINT (-147.04920 64.67145)
#
# [5 rows x 23 columns]

# %%
# review available attributes
list(superfund.columns)
# Out:
# ['SEMS_EPA_ID',
#  'SITE_NAME',
#  'NPL_STATUS_x',
#  'LATITUDE',
#  'LONGITUDE',
#  'CITY',
#  'COUNTY',
#  'STATE',
#  'STREET_ADDRESS',
#  'ZIP_CODE',
#  'REGION',
#  'NPL_STATUS_y',
#  'SUPERFUND_ALTERNATIVE_APPROACH',
#  'SITE_WIDE_READY_FOR_ANTICIPATED_USE',
#  'HUMAN_EXPOSURE_UNDER_CONTROL',
#  'GROUNDWATER_MIGRATION_UNDER_CONTROL',
#  'CONSTRUCTION_COMPLETION_DATE',
#  'SITE_TYPE',
#  'NATIVE_AMERICAN_INTEREST',
#  'INDIAN_ENTITY',
#  'HRS_SCORE',
#  'SUPERFUND_SITE_PROFILE_PAGE_URL',
#  'geometry']

# %% [markdown]
# Besides exploring the general distribution/location of Superfund sites, I'd also like to explore HRS (hazard ranking system) score and native american interest/indian entity. The other attributes describing the site location and site profile page URL can possibly be used in a popup in the final map.

# %%
# plot historgram of HRS scores to view distrbution
plot = superfund['HRS_SCORE'].hist(bins=40)
plot.set(xlabel='HRS Score', ylabel='Count', title='Distribution of HRS scores for Superfund NPL sites');

# %%
# view HRS score descriptive statistics
superfund['HRS_SCORE'].describe()
# Out:
# count    1012.000000
# mean       44.362609
# std         9.982082
# min         0.000000
# 25%        35.570000
# 50%        45.965000
# 75%        50.000000
# max        84.910000
# Name: HRS_SCORE, dtype: float64

# %% [markdown]
# I already know that to be eligible for the NPL a site must have a HRS score of at least 28.5. The minimum score is 0, this must be sites that had null values for the HRS column. The majority of superfund sites on the NPL have a score of around 50, 75% of sites have a score of of 50 and below. Only 25% of sites on the NPL have a score above 50. There are some sites that really stand out as having a higher HRS score than others, it looks like maybe only one has a score above 80, at the max score of 84.91.

# %%
# view top 5 sites with highest HRS score
high_scores = superfund.sort_values(by=['HRS_SCORE'], ascending=False)
high_scores.head()
# Out:
#        SEMS_EPA_ID                                       SITE_NAME  \
# 804   MOD981126899  BIG RIVER MINE TAILINGS/ST. JOE MINERALS CORP.
# 837   MON000705032     WASHINGTON COUNTY LEAD DISTRICT - RICHWOODS
# 835   MON000705027     WASHINGTON COUNTY LEAD DISTRICT - OLD MINES
# 1031  NJD980505416                                 LIPARI LANDFILL
# 111   CAD009106527                   MCCORMICK & BAXTER CREOSOTING
#
#                     NPL_STATUS_x   LATITUDE   LONGITUDE       CITY  \
# 804   Currently on the Final NPL  37.878097  -90.539344    DESLOGE
# 837   Currently on the Final NPL  38.166150  -90.814264  RICHWOODS
# 835   Currently on the Final NPL  38.075278  -90.738333  OLD MINES
# 1031  Currently on the Final NPL  39.720281  -75.141939     PITMAN
# 111   Currently on the Final NPL  37.947851 -121.306635   STOCKTON
#
#             COUNTY STATE                           STREET_ADDRESS ZIP_CODE  \
# 804   ST. FRANCOIS    MO           SECTION 25 26 35 & 36 T37N R4E   63601
# 837     WASHINGTON    MO  21 ACRES IN NORTHEAST WASHINGTON COUNTY   63071
# 835     WASHINGTON    MO       INTERSECTION OF HIGHWAYS 21 AND 47   63630
# 1031    GLOUCESTER    NJ                                   RT 322   08071
# 111    SAN JOAQUIN    CA                     1214 W WASHINGTON ST   95203
#
#       ... SITE_WIDE_READY_FOR_ANTICIPATED_USE HUMAN_EXPOSURE_UNDER_CONTROL  \
# 804   ...                                  No                           No
# 837   ...                                  No                           No
# 835   ...                                  No                           No
# 1031  ...                                  No                          Yes
# 111   ...                                  No                          Yes
#
#      GROUNDWATER_MIGRATION_UNDER_CONTROL CONSTRUCTION_COMPLETION_DATE  \
# 804               Not a Groundwater Site                         None
# 837                    Insufficient Data                         None
# 835                    Insufficient Data                         None
# 1031                                 Yes                    9/26/2018
# 111                                  Yes                         None
#
#                                  SITE_TYPE NATIVE_AMERICAN_INTEREST  \
# 804                       Waste Management                       No
# 837                                 Mining                       No
# 835                                 Mining                       No
# 1031                      Waste Management                       No
# 111   Manufacturing/Processing/Maintenance                       No
#
#      INDIAN_ENTITY HRS_SCORE                  SUPERFUND_SITE_PROFILE_PAGE_URL  \
# 804           None     84.91               www.epa.gov/superfund/bigrivermine
# 837           None     76.81  www.epa.gov/superfund/washingtoncountyrichwoods
# 835           None     76.81   www.epa.gov/superfund/washingtoncountyoldmines
# 1031          None     75.60                     www.epa.gov/superfund/lipari
# 111           None     74.86           www.epa.gov/superfund/mccormick-baxter
#
#                          geometry
# 804    POINT (-90.53934 37.87810)
# 837    POINT (-90.81426 38.16615)
# 835    POINT (-90.73833 38.07528)
# 1031   POINT (-75.14194 39.72028)
# 111   POINT (-121.30663 37.94785)
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Missouri's Old Lead Belt
#
# The top three sites with the highest HRS score are located in Missouri, two of which are in the same county. I can see that the two in the same county are both part of Washington County Lead District. After inspecting these sites further in QGIS, I found this area is known as Missouri's Old Lead Belt and that it contains seven Superfund sites. I also discovered that the true area encompassed by a Superfund site is often much larger than a single point location. The seven superfund sites in Missouri's Old Lead Belt cover four entire counties: Washington, Jefferson, St. Francois, and Madison. I already know that three of these sites have the highest hazard ranking scores out of any in the US. I want to see where the other four rank.

# %%
# filter columns for easier viewing of HRS score rankings
# view top 20 scores
high_scores.filter(['SITE_NAME', 'COUNTY', 'STATE', 'HRS_SCORE']).head(20)
# Out:
#                                            SITE_NAME        COUNTY STATE  \
# 804   BIG RIVER MINE TAILINGS/ST. JOE MINERALS CORP.  ST. FRANCOIS    MO
# 837      WASHINGTON COUNTY LEAD DISTRICT - RICHWOODS    WASHINGTON    MO
# 835      WASHINGTON COUNTY LEAD DISTRICT - OLD MINES    WASHINGTON    MO
# 1031                                 LIPARI LANDFILL    GLOUCESTER    NJ
# 111                    MCCORMICK & BAXTER CREOSOTING   SAN JOAQUIN    CA
# 1009                           HELEN KRAMER LANDFILL    GLOUCESTER    NJ
# 598                            INDUSTRIPLEX NPL SITE     MIDDLESEX    MA
# 1336               PACIFIC WOOD PRESERVING OF OREGON       YAMHILL    OR
# 151                      STOKER CHEMICAL COMPANY (1)      IMPERIAL    CA
# 355            JOINT BASE PEARL HARBOR-HICKAM HAWAII      HONOLULU    HI
# 1328                                    FEDEX GROUND     MULTNOMAH    OR
# 592    GE PITTSFIELD HOUSATONIC RIVER SUPERFUND SITE     BERKSHIRE    MA
# 415          EXXON MOBIL MINING AND MINERALS COMPANY        BUREAU    IL
# 1441                        SAFETY LIGHT CORPORATION      COLUMBIA    PA
# 826                SOUTHWEST JEFFERSON COUNTY MINING     JEFFERSON    MO
# 280                         KERR-MCGEE CHEMICAL CORP         DUVAL    FL
# 877                                   BARBER ORCHARD       HAYWOOD    NC
# 1461                         WATSON JOHNSON LANDFILL         BUCKS    PA
# 912                     US MARINE CORPS CHERRY POINT        CRAVEN    NC
# 406                            CIRCLE SMELTING CORP.       CLINTON    IL
#
#       HRS_SCORE
# 804       84.91
# 837       76.81
# 835       76.81
# 1031      75.60
# 111       74.86
# 1009      72.66
# 598       72.42
# 1336      71.78
# 151       70.94
# 355       70.82
# 1328      70.71
# 592       70.71
# 415       70.71
# 1441      70.71
# 826       70.71
# 280       70.71
# 877       70.71
# 1461      70.71
# 912       70.71
# 406       70.71

# %% [markdown]
# Another of Missouri's Old Lead Belt sites is in the top 20 sites, Southwest Jefferson County Mining. It has a score of 70.71 which is shared by ten of the top twenty sites. Now I want to filter just the sites in Missouri's Old Lead Belt to see what their scores are.

# %%
# select sites in Missouri's Old Lead Belt and sort descending by HRS score
# the last site, MINKER/STOUT/ROMAINE CREEK, is not part of Missouri's Old Lead Belt
MO = superfund.loc[(superfund['STATE'] == 'MO')]
MO = MO.loc[(MO['COUNTY'] == 'S.sort_values(by=['HRS_SCORE'], ascending=False)T. FRANCOIS') | (MO['COUNTY'] == 'WASHINGTON') | (MO['COUNTY'] == 'MADISON') | (MO['COUNTY'] == 'JEFFERSON')]
MO
# Out:
#       SEMS_EPA_ID                                        SITE_NAME  \
# 804  MOD981126899   BIG RIVER MINE TAILINGS/ST. JOE MINERALS CORP.
# 835  MON000705027      WASHINGTON COUNTY LEAD DISTRICT - OLD MINES
# 837  MON000705032      WASHINGTON COUNTY LEAD DISTRICT - RICHWOODS
# 826  MON000705443                SOUTHWEST JEFFERSON COUNTY MINING
# 802  MOD098633415                          ANSCHUTZ - MADISON MINE
# 834  MON000705842  WASHINGTON COUNTY LEAD DISTRICT - FURNACE CREEK
# 836  MON000705023         WASHINGTON COUNTY LEAD DISTRICT - POTOSI
# 813  MOD980741912                       MINKER/STOUT/ROMAINE CREEK
#
#                    NPL_STATUS_x   LATITUDE  LONGITUDE              CITY  \
# 804  Currently on the Final NPL  37.878097 -90.539344           DESLOGE
# 835  Currently on the Final NPL  38.075278 -90.738333         OLD MINES
# 837  Currently on the Final NPL  38.166150 -90.814264         RICHWOODS
# 826  Currently on the Final NPL  38.186794 -90.758975  JEFFERSON COUNTY
# 802  Currently on the Final NPL  37.546111 -90.276111     FREDERICKTOWN
# 834  Currently on the Final NPL  37.840531 -90.799556         CALEDONIA
# 836  Currently on the Final NPL  37.939900 -90.772400            POTOSI
# 813  Currently on the Final NPL  38.440000 -90.480000          IMPERIAL
#
#            COUNTY STATE                           STREET_ADDRESS ZIP_CODE  \
# 804  ST. FRANCOIS    MO           SECTION 25 26 35 & 36 T37N R4E   63601
# 835    WASHINGTON    MO       INTERSECTION OF HIGHWAYS 21 AND 47   63630
# 837    WASHINGTON    MO  21 ACRES IN NORTHEAST WASHINGTON COUNTY   63071
# 826     JEFFERSON    MO  SLVR LK TRL & THNDR RDG RD,.5M W HWY WW   63023
# 802       MADISON    MO                    401 N MINE LAMOTTE ST   63645
# 834    WASHINGTON    MO    2 MI. N OF INT. OF BIG RIVER & HWY 21   63631
# 836    WASHINGTON    MO   500 FT EAST OF BELL ST AND VALLEY ROAD   63664
# 813     JEFFERSON    MO           4037 W ROCK CREEK RD & SWALLER   63052
#
#      ... SITE_WIDE_READY_FOR_ANTICIPATED_USE HUMAN_EXPOSURE_UNDER_CONTROL  \
# 804  ...                                  No                           No
# 835  ...                                  No                           No
# 837  ...                                  No                           No
# 826  ...                                  No                           No
# 802  ...                                  No                           No
# 834  ...                                  No                           No
# 836  ...                                  No                           No
# 813  ...                                 Yes                          Yes
#
#     GROUNDWATER_MIGRATION_UNDER_CONTROL CONSTRUCTION_COMPLETION_DATE  \
# 804              Not a Groundwater Site                         None
# 835                   Insufficient Data                         None
# 837                   Insufficient Data                         None
# 826                                  No                         None
# 802                   Insufficient Data                         None
# 834                   Insufficient Data                         None
# 836                   Insufficient Data                         None
# 813              Not a Groundwater Site                    9/30/1997
#
#                                              SITE_TYPE  \
# 804                                   Waste Management
# 835                                             Mining
# 837                                             Mining
# 826                                             Mining
# 802                                             Mining
# 834  Manufacturing/Processing/Maintenance, Mining, ...
# 836                                             Mining
# 813                                              Other
#
#     NATIVE_AMERICAN_INTEREST INDIAN_ENTITY HRS_SCORE  \
# 804                       No          None     84.91
# 835                       No          None     76.81
# 837                       No          None     76.81
# 826                       No          None     70.71
# 802                       No          None     58.41
# 834                       No          None     50.00
# 836                       No          None     50.00
# 813                       No          None     36.78
#
#                        SUPERFUND_SITE_PROFILE_PAGE_URL  \
# 804                 www.epa.gov/superfund/bigrivermine
# 835     www.epa.gov/superfund/washingtoncountyoldmines
# 837    www.epa.gov/superfund/washingtoncountyrichwoods
# 826  www.epa.gov/superfund/southwestjeffersoncounty...
# 802           www.epa.gov/superfund/madisoncountymines
# 834  www.epa.gov/superfund/washingtoncountyfurnacec...
# 836       www.epa.gov/superfund/washingtoncountypotosi
# 813      www.epa.gov/superfund/minkerstoutromainecreek
#
#                        geometry
# 804  POINT (-90.53934 37.87810)
# 835  POINT (-90.73833 38.07528)
# 837  POINT (-90.81426 38.16615)
# 826  POINT (-90.75898 38.18679)
# 802  POINT (-90.27611 37.54611)
# 834  POINT (-90.79956 37.84053)
# 836  POINT (-90.77240 37.93990)
# 813  POINT (-90.48000 38.44000)
#
# [8 rows x 23 columns]

# %% [markdown]
# So all seven of the Superfund sites in Missouri's Old Lead Belt have an HRS score of 50 and above, putting all seven in the 75th percentile.
#
# I would like to explore this case study in the final map. The map could first show all counties affected, and then guide the user through each site/county with specifics. _Look at census data/CDC SVI tracts/TRI facilities in this area?_
#
# 1. BIG RIVER MINE TAILINGS/ST. JOE MINERALS CORP.
# 2. WASHINGTON COUNTY LEAD DISTRICT - OLD MINES
# 3. WASHINGTON COUNTY LEAD DISTRICT - RICHWOODS
# 4. SOUTHWEST JEFFERSON COUNTY MINING: this site encompasses the entire county because mining waste has been transported by the Big River and manually relocated to other areas throughout the county.
# 5. ANSCHUTZ - MADISON MINE
# 6. WASHINGTON COUNTY LEAD DISTRICT - FURNACE CREEK
# 7. WASHINGTON COUNTY LEAD DISTRICT - POTOSI

# %% [markdown]
# ## Superfund sites on tribal land
#
# The exploration below attempts to learn if Native Americans are disproportionately exposed to higher risk Superfund sites.

# %%
# filter superfund sites to see which ones are of interest to native americans
tribe = superfund.loc[(superfund['NATIVE_AMERICAN_INTEREST'] == 'Yes')]
tribe
# Out:
#        SEMS_EPA_ID                                       SITE_NAME  \
# 6     AK0001897602                                 SALT CHUCK MINE
# 46    AZD094524097                       CYPRUS TOHONO COPPER MINE
# 53    AZD980737530               TUCSON INTERNATIONAL AIRPORT AREA
# 70    CAD980638860                           CELTOR CHEMICAL WORKS
# 74    CAD980638225                               COPPER BLUFF MINE
# ...            ...                                             ...
# 1330  ORD095003687                                           GOULD
# 1332  ORD009020603  MCCORMICK AND BAXTER CREOSOTING SUPERFUND SITE
# 1333  ORN001002476                             NORTH RIDGE ESTATES
# 1336  ORD009042532               PACIFIC WOOD PRESERVING OF OREGON
# 1337  ORSFN1002155                                 PORTLAND HARBOR
#
#                     NPL_STATUS_x   LATITUDE   LONGITUDE           CITY  \
# 6     Currently on the Final NPL  55.626442 -132.558853     THORNE BAY
# 46                Not on the NPL  32.528611 -111.916111    CASA GRANDE
# 53    Currently on the Final NPL  32.105561 -110.933300         TUCSON
# 70    Deleted from the Final NPL  41.102700 -123.691100          HOOPA
# 74    Currently on the Final NPL  41.109972 -123.686000          HOOPA
# ...                          ...        ...         ...            ...
# 1330  Deleted from the Final NPL  45.569200 -122.748300       PORTLAND
# 1332  Currently on the Final NPL  45.579443 -122.739440       PORTLAND
# 1333  Currently on the Final NPL  42.264800 -121.746500  KLAMATH FALLS
# 1336  Currently on the Final NPL  45.097222 -123.426944       SHERIDAN
# 1337  Currently on the Final NPL  45.615278 -122.793056       PORTLAND
#
#               COUNTY STATE                           STREET_ADDRESS ZIP_CODE  \
# 6     [Blank County]    AK  4 MI SW CY, T72S R84E S17, COPPER RIVER   99919
# 46             PINAL    AZ                    INDIAN ROAD NUMBER 15
# 53              PIMA    AZ                              NOGALES HWY   85734
# 70          HUMBOLDT    CA            BETW NORTON FLD & TRINITY RIV   95546
# 74          HUMBOLDT    CA   OFF HIGHWAY 96, APPROXIMATELY 0.9 MILE   95546
# ...              ...   ...                                      ...      ...
# 1330       MULTNOMAH    OR                          5909 NW 61ST AV   97208
# 1332       MULTNOMAH    OR                    6900 N EDGEWATER ROAD   97203
# 1333         KLAMATH    OR      OLD FORT ROAD AND NORTH RIDGE DRIVE   97601
# 1336         YAMHILL    OR          22125 SOUTHWEST ROCK CREEK ROAD   97378
# 1337       MULTNOMAH    OR      BETWEEN RM 1.9 AND 11.8 IN PORTLAND   97231
#
#       ... SITE_WIDE_READY_FOR_ANTICIPATED_USE HUMAN_EXPOSURE_UNDER_CONTROL  \
# 6     ...                                  No                          Yes
# 46    ...                                  No                          Yes
# 53    ...                                  No                          Yes
# 70    ...                                 Yes                          Yes
# 74    ...                                  No                           No
# ...   ...                                 ...                          ...
# 1330  ...                                 Yes                          Yes
# 1332  ...                                  No                          Yes
# 1333  ...                                  No                           No
# 1336  ...                                 Yes                          Yes
# 1337  ...                                  No                           No
#
#      GROUNDWATER_MIGRATION_UNDER_CONTROL CONSTRUCTION_COMPLETION_DATE  \
# 6                                    Yes                         None
# 46                     Insufficient Data                         None
# 53                                    No                         None
# 70                Not a Groundwater Site                    9/29/1989
# 74                    Not yet designated                         None
# ...                                  ...                          ...
# 1330                                 Yes                    9/28/2000
# 1332                                 Yes                    9/27/2005
# 1333              Not a Groundwater Site                         None
# 1336                                 Yes                    9/24/2008
# 1337                                  No                         None
#
#                                  SITE_TYPE NATIVE_AMERICAN_INTEREST  \
# 6                                   Mining                      Yes
# 46                                  Mining                      Yes
# 53    Manufacturing/Processing/Maintenance                      Yes
# 70                               Recycling                      Yes
# 74                           Mining, Other                      Yes
# ...                                    ...                      ...
# 1330                             Recycling                      Yes
# 1332  Manufacturing/Processing/Maintenance                      Yes
# 1333                      Waste Management                      Yes
# 1336  Manufacturing/Processing/Maintenance                      Yes
# 1337                                 Other                      Yes
#
#                                           INDIAN_ENTITY HRS_SCORE  \
# 6                           Organized Village of Kasaan     50.00
# 46                     Tohono O'odham Nation of Arizona       NaN
# 53                     Tohono O'odham Nation of Arizona     57.80
# 70                       Hoopa Valley Tribe, California       NaN
# 74                       Hoopa Valley Tribe, California     50.00
# ...                                                 ...       ...
# 1330  Confederated Tribes and Bands of the Yakama Na...       NaN
# 1332  Confederated Tribes and Bands of the Yakama Na...     50.00
# 1333                                     Klamath Tribes      0.00
# 1336  Confederated Tribes of the Grand Ronde Communi...     71.78
# 1337  Confederated Tribes and Bands of the Yakama Na...     50.00
#
#                       SUPERFUND_SITE_PROFILE_PAGE_URL  \
# 6               www.epa.gov/superfund/salt-chuck-mine
# 46                 www.epa.gov/superfund/cyprustohono
# 53                www.epa.gov/superfund/tucsonairport
# 70               www.epa.gov/superfund/celtorchemical
# 74            www.epa.gov/superfund/copper-bluff-mine
# ...                                               ...
# 1330                      www.epa.gov/superfund/gould
# 1332  www.epa.gov/superfund/mccormick-baxter-portland
# 1333        www.epa.gov/superfund/north-ridge-estates
# 1336              www.epa.gov/superfund/taylor-lumber
# 1337            www.epa.gov/superfund/portland-harbor
#
#                          geometry
# 6     POINT (-132.55885 55.62644)
# 46    POINT (-111.91611 32.52861)
# 53    POINT (-110.93330 32.10556)
# 70    POINT (-123.69110 41.10270)
# 74    POINT (-123.68600 41.10997)
# ...                           ...
# 1330  POINT (-122.74830 45.56920)
# 1332  POINT (-122.73944 45.57944)
# 1333  POINT (-121.74650 42.26480)
# 1336  POINT (-123.42694 45.09722)
# 1337  POINT (-122.79306 45.61528)
#
# [75 rows x 23 columns]

# %%
# plot historgram of HRS scores on tribal lands to view distrbution
plot = tribe['HRS_SCORE'].hist(bins=40)
plot.set(xlabel='HRS Score', ylabel='Count', title='Distribution of HRS scores for Superfund NPL sites of interest to Native Americans');

# %%
# view descriptive statistics for HRS scores on tribal lands
tribe['HRS_SCORE'].describe()
# Out:
# count    58.000000
# mean     48.291724
# std      11.906130
# min       0.000000
# 25%      43.940000
# 50%      50.000000
# 75%      52.507500
# max      71.780000
# Name: HRS_SCORE, dtype: float64

# %% [markdown]
# According to the filtered subset above, there are 75 Superfund sites that are of interest to Native Americans. So out of the 1470 Superfund sites on the NPL in the US, only 5.1%  are of interest to Native Americans.
#
# Out of all the sites in the US, any HRS score above 50 puts the site in the 75th percentile. Out of the 5.1% of sites of interest to Native Americans, 50% of these have a score above 50, putting them in the 75th percentile for HRS scores.
#
# Does this indicate that Native Americans are disproportionately exposed to higher risk Superfund sites?
