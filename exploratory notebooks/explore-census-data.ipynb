# %% [markdown]
# # Explore Census Data

# %%
import pandas as pd

import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# ### Explore age group data

# %%
age_in = pd.read_csv('data/2018-age-populations.csv', encoding='latin-1', header=1)

# %%
age_in.head()
# Out:
#                Id   Id2                Geography  \
# 0  0500000US01001  1001  Autauga County, Alabama
# 1  0500000US01003  1003  Baldwin County, Alabama
# 2  0500000US01005  1005  Barbour County, Alabama
# 3  0500000US01007  1007     Bibb County, Alabama
# 4  0500000US01009  1009   Blount County, Alabama
#
#    April 1, 2010 - Census - Both Sexes; Total  \
# 0                                       54571
# 1                                      182265
# 2                                       27457
# 3                                       22915
# 4                                       57322
#
#    April 1, 2010 - Census - Male; Total  \
# 0                                 26569
# 1                                 89196
# 2                                 14576
# 3                                 12301
# 4                                 28362
#
#    April 1, 2010 - Census - Female; Total  \
# 0                                   28002
# 1                                   93069
# ...

# %%
age_groups = age_in.copy()
list(age_groups.columns)
# Out:
# ['Id',
#  'Id2',
#  'Geography',
#  'April 1, 2010 - Census - Both Sexes; Total',
#  'April 1, 2010 - Census - Male; Total',
#  'April 1, 2010 - Census - Female; Total',
#  'April 1, 2010 - Estimates Base - Both Sexes; Total',
#  'April 1, 2010 - Estimates Base - Male; Total',
#  'April 1, 2010 - Estimates Base - Female; Total',
#  'Population Estimate (as of July 1) - 2010 - Both Sexes; Total',
#  'Population Estimate (as of July 1) - 2010 - Male; Total',
#  'Population Estimate (as of July 1) - 2010 - Female; Total',
#  'Population Estimate (as of July 1) - 2011 - Both Sexes; Total',
#  'Population Estimate (as of July 1) - 2011 - Male; Total',
#  'Population Estimate (as of July 1) - 2011 - Female; Total',
#  'Population Estimate (as of July 1) - 2012 - Both Sexes; Total',
#  'Population Estimate (as of July 1) - 2012 - Male; Total',
#  'Population Estimate (as of July 1) - 2012 - Female; Total',
#  'Population Estimate (as of July 1) - 2013 - Both Sexes; Total',
# ...

# %%
# filter columns to only keep data from 2017 and 2018, and identifying fields
colNames = age_groups.columns.str.contains('2018|Id|Id2|Geography', case=False)
age_groups = age_groups.iloc[:, colNames]
age_groups.head()
# Out:
#                Id   Id2                Geography  \
# 0  0500000US01001  1001  Autauga County, Alabama
# 1  0500000US01003  1003  Baldwin County, Alabama
# 2  0500000US01005  1005  Barbour County, Alabama
# 3  0500000US01007  1007     Bibb County, Alabama
# 4  0500000US01009  1009   Blount County, Alabama
#
#    Population Estimate (as of July 1) - 2018 - Both Sexes; Total  \
# 0                                              55601
# 1                                             218022
# 2                                              24881
# 3                                              22400
# 4                                              57840
#
#    Population Estimate (as of July 1) - 2018 - Male; Total  \
# 0                                              26995
# 1                                             105657
# 2                                              13133
# 3                                              11921
# 4                                              28500
#
# ...

# %%
# further filter for both sexes, still keeping idenitifying fields
colNames = age_groups.columns.str.contains('Both Sexes|Id|Id2|Geography', case=False)
age_groups = age_groups.iloc[:, colNames]
age_groups.head()
# Out:
#                Id   Id2                Geography  \
# 0  0500000US01001  1001  Autauga County, Alabama
# 1  0500000US01003  1003  Baldwin County, Alabama
# 2  0500000US01005  1005  Barbour County, Alabama
# 3  0500000US01007  1007     Bibb County, Alabama
# 4  0500000US01009  1009   Blount County, Alabama
#
#    Population Estimate (as of July 1) - 2018 - Both Sexes; Total  \
# 0                                              55601
# 1                                             218022
# 2                                              24881
# 3                                              22400
# 4                                              57840
#
#    Population Estimate (as of July 1) - 2018 - Both Sexes; Total - Under 5 years  \
# 0                                               3364
# 1                                              11955
# 2                                               1284
# 3                                               1285
# ...

# %% [markdown]
# Young children under 5 are the most vulnerable population, because they "are more heavily exposed to toxins in proportion to their body weight, and have more years of life ahead of them in which they may suffer long-term effects from early exposure" [PRB.org](https://www.prb.org/childrensenvironmentalhealthrisksandremedies/). Elderly people over 65 are also vulnerable.
#
# So for now, I will only keep the columns for under 5 years, under 18 years, and 65 years and older.

# %%
age = age_groups[['Id2',
                  'Id',
                  'Geography',
                  'Population Estimate (as of July 1) - 2018 - Both Sexes; Total',
                  'Population Estimate (as of July 1) - 2018 - Both Sexes; Total - Under 5 years',
                  'Population Estimate (as of July 1) - 2018 - Both Sexes; Under 18 years',
                  'Population Estimate (as of July 1) - 2018 - Both Sexes; 65 years and over',]]
age.head()
# Out:
#     Id2              Id                Geography  \
# 0  1001  0500000US01001  Autauga County, Alabama
# 1  1003  0500000US01003  Baldwin County, Alabama
# 2  1005  0500000US01005  Barbour County, Alabama
# 3  1007  0500000US01007     Bibb County, Alabama
# 4  1009  0500000US01009   Blount County, Alabama
#
#    Population Estimate (as of July 1) - 2018 - Both Sexes; Total  \
# 0                                              55601
# 1                                             218022
# 2                                              24881
# 3                                              22400
# 4                                              57840
#
#    Population Estimate (as of July 1) - 2018 - Both Sexes; Total - Under 5 years  \
# 0                                               3364
# 1                                              11955
# 2                                               1284
# 3                                               1285
# ...

# %%
# rename columns
age = age.rename(columns={'Geography': 'name',
                                        'Population Estimate (as of July 1) - 2018 - Both Sexes; Total': 'totalPop',
                                        'Population Estimate (as of July 1) - 2018 - Both Sexes; Total - Under 5 years': 'under5yr',
                                        'Population Estimate (as of July 1) - 2018 - Both Sexes; Under 18 years': 'under18yr',
                                        'Population Estimate (as of July 1) - 2018 - Both Sexes; 65 years and over': 'over65yr'})
age.head()
# Out:
#     Id2              Id                     name  totalPop  under5yr  \
# 0  1001  0500000US01001  Autauga County, Alabama     55601      3364
# 1  1003  0500000US01003  Baldwin County, Alabama    218022     11955
# 2  1005  0500000US01005  Barbour County, Alabama     24881      1284
# 3  1007  0500000US01007     Bibb County, Alabama     22400      1285
# 4  1009  0500000US01009   Blount County, Alabama     57840      3460
#
#    under18yr  over65yr
# 0      13163      8653
# 1      47110     44571
# 2       5192      4832
# 3       4587      3690
# 4      13392     10548

# %%
# export wrangled table to csv
age.to_csv('data/age-groups.csv')

# %% [markdown]
# ### Explore income data

# %%
income_in = pd.read_csv('data/2018-5yr-income-estimates.csv', encoding='latin-1', header=1)

# %%
income_in.head()
# Out:
#                id     Geographic Area Name  Estimate!!Households!!Total  \
# 0  0500000US01001  Autauga County, Alabama                      21115.0
# 1  0500000US01003  Baldwin County, Alabama                      78622.0
# 2  0500000US01005  Barbour County, Alabama                       9186.0
# 3  0500000US01007     Bibb County, Alabama                       6840.0
# 4  0500000US01009   Blount County, Alabama                      20600.0
#
#    Margin of Error!!Households MOE!!Total  Estimate!!Families!!Total  \
# 0                                   383.0                    15161.0
# 1                                  1183.0                    51359.0
# 2                                   280.0                     6030.0
# 3                                   321.0                     4947.0
# 4                                   396.0                    15104.0
#
#    Margin of Error!!Families MOE!!Total  \
# 0                                 488.0
# ...

# %%
# make a copy of the data to play with
income = income_in.copy()

# inspect columns in data
list(income.columns)
# Out:
# ['id',
#  'Geographic Area Name',
#  'Estimate!!Households!!Total',
#  'Margin of Error!!Households MOE!!Total',
#  'Estimate!!Families!!Total',
#  'Margin of Error!!Families MOE!!Total',
#  'Estimate!!Married-couple families!!Total',
#  'Margin of Error!!Married-couple families MOE!!Total',
#  'Estimate!!Nonfamily households!!Total',
#  'Margin of Error!!Nonfamily households MOE!!Total',
#  'Estimate!!Households!!Total!!Less than $10,000',
#  'Margin of Error!!Households MOE!!Total!!Less than $10,000',
#  'Estimate!!Families!!Total!!Less than $10,000',
#  'Margin of Error!!Families MOE!!Total!!Less than $10,000',
#  'Estimate!!Married-couple families!!Total!!Less than $10,000',
#  'Margin of Error!!Married-couple families MOE!!Total!!Less than $10,000',
#  'Estimate!!Nonfamily households!!Total!!Less than $10,000',
#  'Margin of Error!!Nonfamily households MOE!!Total!!Less than $10,000',
#  'Estimate!!Households!!Total!!$10,000 to $14,999',
# ...

# %% [markdown]
# There are several measures of income here, I am going to focus just on the household income category as this is the most commonly used measure to compare across areas.

# %%
# the easiest way to retain only the household category, is to eliminate all the columns that mention family or families
# first create list of all columns containing a family category                         
familyCols = income.columns.str.contains('Families|family|Family', case=False)
families = income.iloc[:, familyCols]
colNames = list(families.columns)

#then drop all those categories creating a new household dataframe
households = income.drop(colNames, axis=1)
households.head()
# Out:
#                id     Geographic Area Name  Estimate!!Households!!Total  \
# 0  0500000US01001  Autauga County, Alabama                      21115.0
# 1  0500000US01003  Baldwin County, Alabama                      78622.0
# 2  0500000US01005  Barbour County, Alabama                       9186.0
# 3  0500000US01007     Bibb County, Alabama                       6840.0
# 4  0500000US01009   Blount County, Alabama                      20600.0
#
#    Margin of Error!!Households MOE!!Total  \
# 0                                   383.0
# 1                                  1183.0
# 2                                   280.0
# 3                                   321.0
# 4                                   396.0
#
#    Estimate!!Households!!Total!!Less than $10,000  \
# 0                                             7.1
# 1                                             5.4
# 2                                            13.3
# 3                                             6.4
# ...

# %%
# eliminate margin of error columns by just keeping the estimates
colNames = households.columns.str.contains('id|Geographic Area Name|Estimate', case=False)
households = households.iloc[:, colNames]
list(households.columns)
# Out:
# ['id',
#  'Geographic Area Name',
#  'Estimate!!Households!!Total',
#  'Estimate!!Households!!Total!!Less than $10,000',
#  'Estimate!!Households!!Total!!$10,000 to $14,999',
#  'Estimate!!Households!!Total!!$15,000 to $24,999',
#  'Estimate!!Households!!Total!!$25,000 to $34,999',
#  'Estimate!!Households!!Total!!$35,000 to $49,999',
#  'Estimate!!Households!!Total!!$50,000 to $74,999',
#  'Estimate!!Households!!Total!!$75,000 to $99,999',
#  'Estimate!!Households!!Total!!$100,000 to $149,999',
#  'Estimate!!Households!!Total!!$150,000 to $199,999',
#  'Estimate!!Households!!Total!!$200,000 or more',
#  'Estimate!!Households!!Median income (dollars)',
#  'Estimate!!Households!!Mean income (dollars)',
#  'Estimate!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months']

# %%
# rename columns
household_income = households.rename(columns={'Geographic Area Name': 'full_name',
                                        'Estimate!!Households!!Total': 'totalHouseholds',
                                        'Estimate!!Households!!Total!!Less than $10,000': 'less_than_10000',
                                        'Estimate!!Households!!Total!!$10,000 to $14,999': '10000_to_14999',
                                        'Estimate!!Households!!Total!!$15,000 to $24,999': '15000_to_24999',
                                        'Estimate!!Households!!Total!!$25,000 to $34,999': '25000_to_34999',
                                        'Estimate!!Households!!Total!!$35,000 to $49,999': '35000_to_49999',
                                        'Estimate!!Households!!Total!!$50,000 to $74,999': '50000_to_74999',
                                        'Estimate!!Households!!Total!!$75,000 to $99,999': '75000_to_99999',
                                        'Estimate!!Households!!Total!!$100,000 to $149,999': '100000_to_149999',
                                        'Estimate!!Households!!Total!!$150,000 to $199,999': '150000_to_199999',
                                        'Estimate!!Households!!Total!!$200,000 or more': '200000_or_more',
                                        'Estimate!!Households!!Median income (dollars)': 'median_income',
                                        'Estimate!!Households!!Mean income (dollars)': 'mean_income',
                                        'Estimate!!Households!!PERCENT ALLOCATED!!Household income in the past 12 months': 'percent_allocated',})
household_income.head()
# Out:
#                id                full_name  totalHouseholds  less_than_10000  \
# 0  0500000US01001  Autauga County, Alabama          21115.0              7.1
# 1  0500000US01003  Baldwin County, Alabama          78622.0              5.4
# 2  0500000US01005  Barbour County, Alabama           9186.0             13.3
# 3  0500000US01007     Bibb County, Alabama           6840.0              6.4
# 4  0500000US01009   Blount County, Alabama          20600.0              8.4
#
#    10000_to_14999  15000_to_24999  25000_to_34999  35000_to_49999  \
# 0             5.8            10.1             7.9            11.9
# 1             5.2             9.2            11.0            13.5
# 2             8.9            16.5            12.1            14.2
# 3             8.2            12.9            11.1            15.0
# 4             5.6            11.4            12.6            13.1
#
#    50000_to_74999  75000_to_99999  100000_to_149999  150000_to_199999  \
# ...

# %%
# export wrangled data to csv
household_income.to_csv('data/household-income.csv')

# %% [markdown]
# ### Join income dataframe with age group and population

# %%
age.head()
# Out:
#     Id2              Id                     name  totalPop  under5yr  \
# 0  1001  0500000US01001  Autauga County, Alabama     55601      3364
# 1  1003  0500000US01003  Baldwin County, Alabama    218022     11955
# 2  1005  0500000US01005  Barbour County, Alabama     24881      1284
# 3  1007  0500000US01007     Bibb County, Alabama     22400      1285
# 4  1009  0500000US01009   Blount County, Alabama     57840      3460
#
#    under18yr  over65yr
# 0      13163      8653
# 1      47110     44571
# 2       5192      4832
# 3       4587      3690
# 4      13392     10548

# %%
household_income.head()
# Out:
#                id                full_name  totalHouseholds  less_than_10000  \
# 0  0500000US01001  Autauga County, Alabama          21115.0              7.1
# 1  0500000US01003  Baldwin County, Alabama          78622.0              5.4
# 2  0500000US01005  Barbour County, Alabama           9186.0             13.3
# 3  0500000US01007     Bibb County, Alabama           6840.0              6.4
# 4  0500000US01009   Blount County, Alabama          20600.0              8.4
#
#    10000_to_14999  15000_to_24999  25000_to_34999  35000_to_49999  \
# 0             5.8            10.1             7.9            11.9
# 1             5.2             9.2            11.0            13.5
# 2             8.9            16.5            12.1            14.2
# 3             8.2            12.9            11.1            15.0
# 4             5.6            11.4            12.6            13.1
#
#    50000_to_74999  75000_to_99999  100000_to_149999  150000_to_199999  \
# ...

# %%
# join into one dataframe
census_data = pd.merge(age, household_income, left_on='Id', right_on='id', how='left')
census_data.head()
# Out:
#     Id2              Id                     name  totalPop  under5yr  \
# 0  1001  0500000US01001  Autauga County, Alabama     55601      3364
# 1  1003  0500000US01003  Baldwin County, Alabama    218022     11955
# 2  1005  0500000US01005  Barbour County, Alabama     24881      1284
# 3  1007  0500000US01007     Bibb County, Alabama     22400      1285
# 4  1009  0500000US01009   Blount County, Alabama     57840      3460
#
#    under18yr  over65yr              id                full_name  \
# 0      13163      8653  0500000US01001  Autauga County, Alabama
# 1      47110     44571  0500000US01003  Baldwin County, Alabama
# 2       5192      4832  0500000US01005  Barbour County, Alabama
# 3       4587      3690  0500000US01007     Bibb County, Alabama
# 4      13392     10548  0500000US01009   Blount County, Alabama
#
#    totalHouseholds  ...  25000_to_34999  35000_to_49999  50000_to_74999  \
# 0          21115.0  ...             7.9            11.9            18.1
# ...

# %%
list(census_data.columns)
# Out:
# ['Id2',
#  'Id',
#  'name',
#  'totalPop',
#  'under5yr',
#  'under18yr',
#  'over65yr',
#  'id',
#  'full_name',
#  'totalHouseholds',
#  'less_than_10000',
#  '10000_to_14999',
#  '15000_to_24999',
#  '25000_to_34999',
#  '35000_to_49999',
#  '50000_to_74999',
#  '75000_to_99999',
#  '100000_to_149999',
#  '150000_to_199999',
#  '200000_or_more',
#  'median_income',
#  'mean_income',
#  'percent_allocated']

# %%
# drop duplicate columns
census_data = census_data.drop(['id'], axis=1)
census_data.head()
# Out:
#     Id2              Id                     name  totalPop  under5yr  \
# 0  1001  0500000US01001  Autauga County, Alabama     55601      3364
# 1  1003  0500000US01003  Baldwin County, Alabama    218022     11955
# 2  1005  0500000US01005  Barbour County, Alabama     24881      1284
# 3  1007  0500000US01007     Bibb County, Alabama     22400      1285
# 4  1009  0500000US01009   Blount County, Alabama     57840      3460
#
#    under18yr  over65yr                full_name  totalHouseholds  \
# 0      13163      8653  Autauga County, Alabama          21115.0
# 1      47110     44571  Baldwin County, Alabama          78622.0
# 2       5192      4832  Barbour County, Alabama           9186.0
# 3       4587      3690     Bibb County, Alabama           6840.0
# 4      13392     10548   Blount County, Alabama          20600.0
#
#    less_than_10000  ...  25000_to_34999  35000_to_49999  50000_to_74999  \
# 0              7.1  ...             7.9            11.9            18.1
# ...

# %% [markdown]
# ### Join census data to county shapefile for visualization and analysis

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point
from shapely.geometry import Polygon
from shapely.geometry import mapping
from shapely import wkt

import warnings
warnings.simplefilter(action='ignore')

# %%
# read counties in
counties = gpd.read_file('data/us-counties/tl_2019_us_county.shp')

# %%
counties.plot()

# %%
# check crs
counties.crs
# Out:
# {'init': 'epsg:4269'}

# %%
# project to WGS84 and check results
counties = counties.to_crs(epsg=4326)
counties.crs
# Out:
# {'init': 'epsg:4326', 'no_defs': True}

# %%
counties.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS  GEOID       NAME          NAMELSAD LSAD CLASSFP  \
# 0      31      039  00835841  31039     Cuming     Cuming County   06      H1
# 1      53      069  01513275  53069  Wahkiakum  Wahkiakum County   06      H1
# 2      35      011  00933054  35011    De Baca    De Baca County   06      H1
# 3      31      109  00835876  31109  Lancaster  Lancaster County   06      H1
# 4      31      129  00835886  31129   Nuckolls   Nuckolls County   06      H1
#
#    MTFCC CSAFP CBSAFP METDIVFP FUNCSTAT       ALAND    AWATER     INTPTLAT  \
# 0  G4020  None   None     None        A  1477652222  10690952  +41.9158651
# 1  G4020  None   None     None        A   680962890  61582307  +46.2946377
# 2  G4020  None   None     None        A  6016819475  29089486  +34.3592729
# 3  G4020   339  30700     None        A  2169270569  22849484  +40.7835474
# 4  G4020  None   None     None        A  1489645188   1718484  +40.1764918
#
# ...

# %%
list(counties.columns)
# Out:
# ['STATEFP',
#  'COUNTYFP',
#  'COUNTYNS',
#  'GEOID',
#  'NAME',
#  'NAMELSAD',
#  'LSAD',
#  'CLASSFP',
#  'MTFCC',
#  'CSAFP',
#  'CBSAFP',
#  'METDIVFP',
#  'FUNCSTAT',
#  'ALAND',
#  'AWATER',
#  'INTPTLAT',
#  'INTPTLON',
#  'geometry']

# %%
# drop extra columns
counties = counties.drop(['LSAD', 'CLASSFP', 'MTFCC', 'CSAFP', 'CBSAFP', 'METDIVFP', 'FUNCSTAT', 'INTPTLAT', 'INTPTLON'], axis=1)

# %%
# convert columns used to join to strings
counties.GEOID = counties.GEOID.astype(str)
census_data.Id2 = census_data.Id2.astype(str)

# %%
# add leading zero to Id2 field to match the GEOID field from the county shapefile
census_data['Id2'] = census_data['Id2'].str.zfill(5)

# %%
# merge age group pop data with counties
counties = pd.merge(counties, census_data, left_on='GEOID', right_on="Id2", how='left')
counties.sample(10)
# Out:
#      STATEFP COUNTYFP  COUNTYNS  GEOID         NAME            NAMELSAD  \
# 2614      31      177  00835910  31177   Washington   Washington County
# 1289      21      081  00516887  21081        Grant        Grant County
# 1254      51      019  01674818  51019      Bedford      Bedford County
# 3133      55      078  01581099  55078    Menominee    Menominee County
# 1682      39      101  01074063  39101       Marion       Marion County
# 2362      72      035  01804497  72035        Cayey     Cayey Municipio
# 1040      46      055  01266988  46055       Haakon       Haakon County
# 541       13      079  00342918  13079     Crawford     Crawford County
# 1909      27      141  00659515  27141    Sherburne    Sherburne County
# 2834      51      175  01480171  51175  Southampton  Southampton County
#
#            ALAND    AWATER                                           geometry  \
# 2614  1009985093   8388605  POLYGON ((-96.40594 41.48046, -96.40716 41.480...
# ...

# %%
list(counties.columns)
# Out:
# ['STATEFP',
#  'COUNTYFP',
#  'COUNTYNS',
#  'GEOID',
#  'NAME',
#  'NAMELSAD',
#  'ALAND',
#  'AWATER',
#  'geometry',
#  'Id2',
#  'Id',
#  'totalPop',
#  'under5yr',
#  'under18yr',
#  'over65yr',
#  'full_name',
#  'totalHouseholds',
#  'less_than_10000',
#  '10000_to_14999',
#  '15000_to_24999',
#  '25000_to_34999',
#  '35000_to_49999',
#  '50000_to_74999',
#  '75000_to_99999',
#  '100000_to_149999',
#  '150000_to_199999',
#  '200000_or_more',
#  'median_income',
#  'mean_income',
#  'percent_allocated']

# %%
# drop duplicate name column
counties = counties.drop(['name'], axis=1)

# %%
# export file to geojson
counties.to_file('data/counties-joined.geojson', driver='GeoJSON')

# %% [markdown]
# Run mapshaper from command line to simplify geojson:
#
# `mapshaper counties-joined.geojson -simplify dp 20% -o format=geojson counties-joined-simplified.geojson`

# %%
# import folium

# %%
# m = folium.Map(location=[37, -102], zoom_start=4)

# bins = list(age['2018_totalPop'].quantile([0, 0.25, 0.5, 0.75, 1]))

# choropleth = folium.Choropleth(
#  geo_data=counties_equal,
#  name='choropleth',
#  data=age,
#  columns=['GEOID', '2018_totalPop'],
#  key_on='feature.properties.GEOID',
#  fill_color='BuGn',
#  fill_opacity=0.7,
#  line_opacity=0.2,
#  legend_name='2018 Total Population',
#  bins = bins
# ).add_to(m)
# # folium.LayerControl().add_to(m)

# choropleth.geojson.add_child(
#     folium.features.GeoJsonTooltip(['NAME', '2018_totalPop'])
# )
# m
